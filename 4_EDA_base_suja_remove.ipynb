# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from Funcoes_auxiliares.func_aux import *
from sklearn.impute import KNNImputer

# %% [markdown]
# # Knowing the dataset
# At first, no cleaning will be applied to the dataset, later we will apply all cleaning and make a new EDA

# %%
#Import dataset
df = pd.read_csv('base_suja/base_unificada_suja.csv')
variaveis = [
    'data_evento', 'ano_evento', 'TIPOBITO', 'evento_MUNNOMEX',
    'res_MUNNOMEX', 'evento_CAPITAL', 'res_CAPITAL', 'evento_REGIAO',
    'res_REGIAO', 'evento_SIGLA_UF', 'res_SIGLA_UF', 'IDADEMAE',
    'idademae_faixa', 'ESCMAE2010', 'escolaridade_mae', 'OBITOGRAV',
    'GRAVIDEZ', 'tipo_gravidez', 'SEMAGESTAC', 'idade_gestacao_faixa',
    'SEXO', 'def_sexo', 'PESO', 'peso_faixa', 'OBITOPARTO',
    'def_obito_parto', 'CAUSABAS', 'causabas_capitulo',
    'causabas_categoria', 'causabas_grupo', 'causabas_subcategoria',
    'FLAG_BASE', 'sum_CENTROBS', 'sum_QTINST34', 'sum_QTINST35',
    'sum_QTINST36', 'sum_QTINST37', 'sum_QTLEIT34', 'sum_QTLEIT38',
    'sum_QTLEIT39', 'sum_QTLEIT40', 'sum_CENTRNEO','TP_UNID_5', 'TP_UNID_7',
    'TP_UNID_15', 'TP_UNID_36', 'TP_UNID_61'
]
df = df[variaveis]
# Out:
# <ipython-input-2-5c667751b380>:2: DtypeWarning: Columns (25,26,27,28,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('base_suja/base_unificada_suja.csv')

# %%
# Configuration to show more rows and columns
# pd.set_option('display.max_rows', None)  # Show all rows
# pd.set_option('display.max_columns', None)  # Show all columns

# %%
url_dicionario = 'https://docs.google.com/spreadsheets/d/1QFy_F2o81ULglNx8knNqg6oI7v3RARaUAaLLwOQr7K4/edit?usp=sharing'
f"""The dataset has {len(df)} lines and {len(df.columns)} columns. More details can be consulted in the dictionary {url_dicionario}. Below the type of variables and the 'face' from the dataset"""

# %%
df.info()

# %%
df.head()

# %% [markdown]
# #  Checking data quality

# %% [markdown]
# ### Duplicates

# %%
# Duplicate data 
duplicados = df.duplicated()
soma = duplicados.sum()
f"""The dataset has {soma} duplicate rows, which represents {round((soma/len(df)) * 100, 2)} %"""

# %%
# Frequency of duplicates by FLAG_BASE, res_SIGLA_UF and ano_evento
df_duplicados = df[duplicados]
df_duplicados.value_counts(['FLAG_BASE', 'ano_evento', 'res_SIGLA_UF'])

# There is no concentration of missing items that indicates a structural problem with filling in the data, whether by year or 
# UF of residence

# %% [markdown]
# ### Missing

# %%
# Counting missing values
df_sim_dofet = df[df['FLAG_BASE']=='SIM_DOFET']
missing_count_sim_dofet = df_sim_dofet.isnull().sum()  # counts the null values in each column
missing_percent_sim_dofet = round((missing_count_sim_dofet / len(df_sim_dofet)) * 100,2)  # calculates the percentage of null values
missing_data_sim_dofet = pd.DataFrame({'Missing Count': missing_count_sim_dofet, 'Missing Percentage': missing_percent_sim_dofet})
missing_data_sim_dofet.index.name = 'Variable'  # sets the index name to 'Variable'
missing_data_sim_dofet.reset_index(inplace=True)  # resets the index to make 'Variable' a column
missing_data_sim_dofet['BASE'] = 'SIM_DOFET'

df_sinasc = df[df['FLAG_BASE']=='SINASC']
missing_count_sinasc = df_sinasc.isnull().sum()  # counts the null values in each column
missing_percent_sinasc = round((missing_count_sinasc / len(df_sinasc)) * 100,2)  # calculates the percentage of null values
missing_data_sinasc = pd.DataFrame({'Missing Count': missing_count_sinasc, 'Missing Percentage': missing_percent_sinasc})
missing_data_sinasc.index.name = 'Variable'  # sets the index name to 'Variable'
missing_data_sinasc.reset_index(inplace=True)  # resets the index to make 'Variable' a column
missing_data_sinasc['BASE'] = 'SINASC'

# appending
missing_data = pd.concat([missing_data_sim_dofet, missing_data_sinasc])

# Sorting the DataFrame by the highest missing frequencies
missing_data_sorted = missing_data.sort_values(by=['BASE', 'Missing Count'], ascending=False)

missing_data_sorted[missing_data_sorted['Missing Percentage'] > 0]

# Some variables are not filled in the sinasc dataset. For EDA it will be used in SIM_DOFET, but in the model it will not be removed
# 'OBITOGRAV' no padding at the base
# Missing points for other variables will be removed, keeping the variables in the study

# %%
del missing_data_sorted, missing_data, df_sim_dofet, df_sinasc

# %%
# Checking if there is any pattern in the missing data looking at year and 'res_SIGLA_UF'
lista = ['ESCMAE2010', 'SEMAGESTAC', 'PESO', 'IDADEMAE']
for i in lista:
    print(f"""Variável {i}\n\n{df.loc[df[i].isnull(), ['FLAG_BASE', 'ano_evento', 'res_SIGLA_UF']].value_counts()}""")

# Some UF's have very high values, but compared to the total UF it is less than 10%
# len(df.loc[(df['res_SIGLA_UF']=='CE') & (df['ano_evento']==2021) & (df['FLAG_BASE']=='SINASC')])
# Out:
# Variável IDADEMAE
#
# FLAG_BASE  ano_evento  res_SIGLA_UF
# SIM_DOFET  2021        SP              505
#            2018        SP              474
#            2020        SP              469
#            2019        SP              400
#            2022        SP              389
#            2018        BA              251
#            2020        BA              238
#            2019        MG              233
#            2020        MG              231
#            2021        MG              231
#            2018        MG              230
#            2019        BA              225
#            2021        BA              202
#            2022        MG              198
#                        BA              190
#            2018        PE              174
#                        RJ              158
#            2019        RJ              157
#                        PE              155
#            2020        RJ              132
#            2021        RJ              128
#            2018        PA              112
#            2019        RS              104
#            2021        MA              104
#                        PE              101
#            2020        PA               97
#            2018        RS               94
#            2022        RJ               94
#            2020        RS               92
#            2018        MA               90
#            2020        PE               88
#            2022        PE               87
#            2021        PA               86
#                        RS               85
#            2020        MA               81
#            2019        PA               77
#            2022        GO               72
#            2020        AL               72
#            2022        RS               72
#            2018        AL               72
#            2022        MA               71
#            2018        ES               68
#            2021        CE               66
#                        GO               66
#            2020        CE               66
#            2019        ES               64
#            2018        GO               63
#            2022        PA               62
#            2020        GO               62
#                        ES               59
#            2018        CE               58
#            2020        PB               58
#            2019        MA               56
#            2021        AL               51
#                        PB               48
#            2019        CE               48
#            2020        PR               48
#            2022        SC               48
#                        AL               47
#            2018        AM               46
#                        RN               46
#            2021        PR               44
#            2019        GO               43
#            2018        PB               43
#            2021        AM               42
#            2019        AL               42
#            2018        SC               41
#            2021        SC               40
#            2019        PB               36
#            2022        PR               35
#            2020        SC               35
#            2018        RO               34
#            2019        PR               34
#            2018        DF               33
#            2019        SC               33
# SINASC     2021        AC               32
# SIM_DOFET  2022        PB               32
#            2018        PR               31
#            2022        CE               31
#            2018        PI               30
#            2021        PI               30
#                        RN               29
# SINASC     2018        RR               29
# SIM_DOFET  2020        PI               26
#            2019        RN               25
#            2018        AP               23
#            2020        AC               23
#                        AP               23
#                        RN               23
#            2019        MS               22
#            2020        RO               22
# SINASC     2019        RR               22
# SIM_DOFET  2018        MT               22
#            2021        MT               22
#                        AC               22
#            2019        PI               21
#            2021        TO               21
#                        ES               21
#            2022        RN               20
#                        AM               20
#            2021        DF               20
#            2019        AM               20
#            2022        MS               19
#            2019        MT               18
#            2018        MS               18
#            2021        MS               18
#            2020        AM               18
#            2021        AP               18
#            2020        MS               18
#            2019        DF               18
#                        AP               17
#                        RO               17
#            2020        MT               17
#                        TO               16
#            2018        TO               16
#            2022        PI               16
#                        ES               15
#            2020        DF               15
#            2022        AC               14
#            2019        TO               14
#            2021        RR               13
# SINASC     2022        AC               13
# SIM_DOFET  2020        SE               12
#            2021        RO               11
#            2019        AC               11
# SINASC     2018        AM               10
# SIM_DOFET  2018        AC               10
#            2021        SE               10
#            2018        SE               10
#            2022        DF                9
#                        AP                9
#                        TO                9
# SINASC     2020        RR                9
#                        AM                9
#            2019        AM                8
# SIM_DOFET  2022        RO                8
# SINASC     2020        AP                7
# SIM_DOFET  2019        SE                7
#            2022        MT                6
# SINASC     2020        PA                6
#            2022        AM                5
# SIM_DOFET  2018        RR                5
# SINASC     2021        AP                5
#            2022        RR                5
# SIM_DOFET  2022        RR                5
#                        SE                4
#            2020        RR                4
# SINASC     2018        AC                4
#            2021        AM                3
#                        PA                3
#            2019        PA                3
# SIM_DOFET  2019        RR                3
# SINASC     2020        AC                2
#            2022        PA                2
#            2021        MT                2
#            2022        MT                1
#            2021        RR                1
#            2019        AP                1
#                        AC                1
#            2018        AP                1
#                        PA                1
#                        PI                1
#                        RN                1
#            2019        MT                1
# dtype: int64

# %% [markdown]
# ### Ignorado

# %%
df_ignorado = df.loc[(df['ESCMAE2010']==9) | (df['GRAVIDEZ']==9) |
                     (df['idade_gestacao_faixa']=='Ignorado') | (df['SEXO']==0)]
df_ignorado['FLAG_BASE'].value_counts()

# %% [markdown]
# ### Categorical variables

# %%
lista_cat = [
'ano_evento'
, 'TIPOBITO'       
, 'evento_MUNNOMEX'
, 'res_MUNNOMEX'
, 'evento_CAPITAL'
, 'res_CAPITAL'
, 'evento_REGIAO'
, 'res_REGIAO'
, 'evento_SIGLA_UF'
, 'res_SIGLA_UF'
, 'idademae_faixa'
, 'ESCMAE2010'
, 'escolaridade_mae'
, 'OBITOGRAV'
, 'GRAVIDEZ'
, 'tipo_gravidez'
, 'idade_gestacao_faixa'
, 'SEXO'
, 'def_sexo'
, 'peso_faixa'
, 'OBITOPARTO'
, 'def_obito_parto'
, 'CAUSABAS'
, 'causabas_capitulo'
, 'causabas_categoria'
, 'causabas_grupo'
, 'causabas_subcategoria'
, 'FLAG_BASE'
            ]
for col in lista_cat:
    print(f'\nPercentual de valores únicos para {col}:')
    print(round((df[col].value_counts()/len(df)) * 100, 2))
# Out:
# Ensino_medio        51.67
# Fundamental         24.39
# Ensino_superior     21.51
# Ignorado             2.04
# Sem_escolaridade     0.39
# Name: escolaridade_mae, dtype: float64
#
# Percentual de valores únicos para OBITOGRAV:
# 9.0    0.0
# 1.0    0.0
# 2.0    0.0
# Name: OBITOGRAV, dtype: float64
#
# Percentual de valores únicos para GRAVIDEZ:
# 1.0    97.65
# 2.0     2.17
# 9.0     0.12
# 3.0     0.05
# Name: GRAVIDEZ, dtype: float64
#
# Percentual de valores únicos para tipo_gravidez:
# Unica       97.65
# Multipla     2.22
# Ignorado     0.13
# Name: tipo_gravidez, dtype: float64
#
# Percentual de valores únicos para idade_gestacao_faixa:
# entre_37_39    58.65
# entre_40_42    27.37
# entre_28_36    11.05
# Ignorado        2.05
# entre_22_27     0.75
# menor_22        0.13
# Name: idade_gestacao_faixa, dtype: float64
#
# Percentual de valores únicos para SEXO:
# 1    51.19
# 2    48.77
# 0     0.04
# Name: SEXO, dtype: float64
#
# Percentual de valores únicos para def_sexo:
# Masculino    51.19
# Feminino     48.77
# Ignorado      0.04
# Name: def_sexo, dtype: float64
#
# Percentual de valores únicos para peso_faixa:
# entre_2500_3500     64.24
# entre_3500_3999     21.23
# entre_1500_2499      7.55
# maior_igual_4000     4.99
# entre_500_1499       1.66
# menor_500            0.25
# Ignorado             0.09
# Name: peso_faixa, dtype: float64
#
# Percentual de valores únicos para OBITOPARTO:
# 1.0    0.94
# 2.0    0.05
# 9.0    0.05
# Name: OBITOPARTO, dtype: float64
#
# Percentual de valores únicos para def_obito_parto:
# Antes       0.94
# Ignorado    0.05
# Durante     0.05
# Name: def_obito_parto, dtype: float64
#
# Percentual de valores únicos para CAUSABAS:
# P95     0.23
# P209    0.13
# P000    0.12
# P200    0.08
# P021    0.07
# P022    0.06
# P002    0.03
# P025    0.02
# P011    0.02
# P027    0.02
# P001    0.02
# P700    0.01
# Q899    0.01
# A502    0.01
# P010    0.01
# P008    0.01
# Q897    0.01
# P012    0.01
# Q000    0.01
# P969    0.01
# P059    0.01
# P015    0.01
# P701    0.01
# P832    0.01
# P020    0.01
# P038    0.01
# P024    0.01
# Q249    0.01
# P072    0.01
# P201    0.00
# P026    0.00
# P009    0.00
# P005    0.00
# P029    0.00
# P035    0.00
# P023    0.00
# Q913    0.00
# P018    0.00
# P013    0.00
# P003    0.00
# P039    0.00
# P019    0.00
# P044    0.00
# P031    0.00
# P569    0.00
# P042    0.00
# P964    0.00
# P028    0.00
# A500    0.00
# Q793    0.00
# P968    0.00
# P004    0.00
# Q917    0.00
# Q999    0.00
# P017    0.00
# Q039    0.00
# Q049    0.00
#
# Percentual de valores únicos para causabas_capitulo:
# XVI. Algumas afec originadas no período perinatal    0.96
# XVII.Malf cong deformid e anomalias cromossômicas    0.07
# I.   Algumas doenças infecciosas e parasitárias      0.02
# Name: causabas_capitulo, dtype: float64
#
# Percentual de valores únicos para causabas_categoria:
# P95   Morte fetal de causa NE                         0.23
# P20   Hipoxia intra-uterina                           0.21
# P02   Fet rec-nasc afet compl plac cord umb membr     0.19
# P00   Fet rec-nasc afet afec mat n obr rel grav at    0.19
# P01   Fet rec-nasc afet complic maternas gravidez     0.06
# Q89   Outr malformacoes congen NCOP                   0.03
# P70   Trans transit metab carboid esp fet rec-nasc    0.02
# A50   Sifilis congen                                  0.02
# P03   Fet rec-nasc afet out compl trab parto parto    0.02
# P96   Outr afeccoes originadas periodo perinatal      0.01
# P05   Crescimento fetal retard e desnutric fetal      0.01
# Q00   Anencefalia e malformacoes similares            0.01
# P83   Outr afecc compr tegum espec feto rec-nasc      0.01
# Q24   Outr malformacoes congen do coracao             0.01
# Q91   Sindr de Edwards e sindr de Patau               0.01
# P04   Fet rec-nasc infl af noc trans plac leit mat    0.01
# P07   Transt rel gest curt dur peso baix nasc NCOP    0.01
# Q79   Malformacoes congen sist osteomuscular NCOP     0.00
# P56   Hidropsia fetal dev doenc hemolitica            0.00
# Q04   Outr malformacoes congen do cerebro             0.00
# P39   Outr infecc especificas do periodo perinatal    0.00
# P55   Doenc hemolitica do feto e do recem-nascido     0.00
# Q03   Hidrocefalia congen                             0.00
# Q99   Outr anomalias dos cromossomos NCOP             0.00
# Q60   Agenesia renal e outr defeitos reducao rim      0.00
# Q33   Malformacoes congen do pulmao                   0.00
# Q90   Sindr de Down                                   0.00
# P37   Outr doenc infecc e parasit congen              0.00
# P29   Transt cardiovasc orig periodo perinatal        0.00
# Q87   Outr sindr c/malform cong q acomet mult sist    0.00
# Q21   Malformacoes congen dos septos cardiacos        0.00
# Q75   Outr malformacoes congen ossos cranio e face    0.00
# Q07   Outr malformacoes congen do sist nervoso        0.00
# P50   Perda sanguinea fetal                           0.00
# Q96   Sindr de Turner                                 0.00
# Q01   Encefalocele                                    0.00
# Q92   Outr trissomias e trissom parc autoss NCOP      0.00
# Q20   Malform congen camaras e comunicacoes card      0.00
# Q61   Doenc cisticas do rim                           0.00
# Q05   Espinha bifida                                  0.00
# Q77   Osteocondr c/anom cresc ossos long col vert     0.00
# Q27   Outr malformacoes congen sist vasc perif        0.00
# Q64   Outr malformacoes congen aparelho urinario      0.00
# P15   Outr traum de parto                             0.00
# P35   Doenc virais congen                             0.00
# Q22   Malform congen valvas pulmonar tricuspide       0.00
# Q23   Malformacoes congen valvas aortica e mitral     0.00
# P52   Hemorragia intracran nao-traum feto rec-nasc    0.00
# Q63   Outr malformacoes congen do rim                 0.00
# P26   Hemorragia pulmonar orig periodo perinatal      0.00
# Q78   Outr osteocondrodisplasias                      0.00
# Q02   Microcefalia                                    0.00
# Q25   Malformacoes congen das grandes arterias        0.00
# Q28   Outr malform congen aparelho circulatorio       0.00
# P78   Outr transt ap digestivo periodo perinatal      0.00
# Q43   Outr malformacoes congen do intestino           0.00
# P54   Outr hemorragias neonatais                      0.00
# Q45   Outr malformacoes congen aparelho digestivo     0.00
# Q62   Anom cong obstr pelv renal malf cong ureter     0.00
# Q18   Outr malformacoes congen da face e pescoco      0.00
# Q34   Outr malformacoes congen aparelho respirat      0.00
# P60   Coagulacao intravasc dissem feto rec-nasc       0.00
# Q74   Outr malformacoes congen dos membros            0.00
# P08   Transt relac gest prolong peso elevado nasc     0.00
# Q44   Malform congen vesic biliar via biliar figad    0.00
# Q39   Malformacoes congen do esofago                  0.00
# Q41   Ausencia atresia estenose congen intest delg    0.00
# Q56   Sexo indeterminado e pseudo-hermafroditismo     0.00
# Q40   Outr malform congen trato digestivo super       0.00
# P13   Lesoes do esqueleto dev traum de parto          0.00
# P10   Laceracao intracran hemorrag dev traum parto    0.00
# P25   Enfisema interst afecc corr orig per perinat    0.00
# P11   Outr traum de parto do sist nervoso central     0.00
# Q37   Fenda labial c/fenda palatina                   0.00
# Q93   Monossomias e delecoes dos autossomos NCOP      0.00
# Q36   Fenda labial                                    0.00
# Q35   Fenda palatina                                  0.00
# P77   Enterocolite necrotizante do feto e rec-nasc    0.00
# Q51   Malformacoes congen utero e do colo do utero    0.00
# Q06   Outr malformacoes congen da medula espinhal     0.00
# Q97   Outr anom cromoss sexuais fenotipo fem NCOP     0.00
# Q86   Sindr c/malf cong dev causas exog conh NCOP     0.00
# Q42   Ausencia atresia e estenose congen do colon     0.00
# Q76   Malform congen coluna vertebral ossos torax     0.00
# P53   Doenc hemorragica do feto e do recem-nascido    0.00
# Q26   Malformacoes congen das grandes veias           0.00
# P12   Lesao do couro cabeludo dev traum de parto      0.00
# Q85   Facomatoses NCOP                                0.00
# Q31   Malformacoes congen da laringe                  0.00
# Q30   Malformacao congen do nariz                     0.00
# Q32   Malformacoes congen traqueia e bronquios        0.00
# P93   Reacoes e intox dev drog admin feto rec-nasc    0.00
# Q38   Outr malform congen lingua boca e faringe       0.00
# Q67   Deform osteom cong cabeca face coluna torax     0.00
# Q66   Deform congen do pe                             0.00
# Q54   Hipospadias                                     0.00
# P28   Outr afeccoes respirat orig per perinatal       0.00
# Q55   Outr malformacoes congen org genitais masc      0.00
# Q95   Rearranjos equilibr e marcadores estrut NCOP    0.00
# Q69   Polidactilia                                    0.00
# Q52   Outr malformacoes congen org genitais femin     0.00
# Name: causabas_categoria, dtype: float64
#
# Percentual de valores únicos para causabas_grupo:
# Fet rec-nasc afet fat mat e compl grav, trab parto    0.46
# Outros transtornos originados no período perinatal    0.24
# Transt respirat e cardiovasc específ per perinatal    0.21
# Outras malformações congênitas                        0.03
# Transt endócr e metaból trans espec fet e rec-nasc    0.02
# Infecções de transmissão predominantemente sexual     0.02
# Transt relac com a duração gestação e cresc fetal     0.01
# Malformações congênitas do sistema nervoso            0.01
# Anomalias cromossômicas NCOP                          0.01
# Malformações congênitas do aparelho circulatório      0.01
# Afecç comprom tegument e reg térm fet e recém-nasc    0.01
# Transt hemorrág e hematológ feto e recém-nascido      0.00
# Malform e deform congênit do sistema osteomuscular    0.00
# Infecções específicas do período perinatal            0.00
# Malformações congênitas do aparelho urinário          0.00
# Malformações congênitas do aparelho respiratório      0.00
# Outras malformações congênitas aparelho digestivo     0.00
# Traumatismo de parto                                  0.00
# Transt aparelho digestivo do feto ou recém-nascido    0.00
# Fenda labial e fenda palatina                         0.00
# Malformações congênitas dos órgãos genitais           0.00
# Malform congênitas do olho, ouvido, face e pescoço    0.00
# Name: causabas_grupo, dtype: float64
#
# Percentual de valores únicos para causabas_subcategoria:
# P95   Morte fetal de causa NE                         0.23
# P20.9 Hipoxia intra-uterina NE                        0.13
# P00.0 Fet rec-nasc afet transt mat hipertensivos      0.12
# P20.0 Hipoxia intra-uter diagn ant inic trab parto    0.08
# P02.1 Fet rec-nasc afet outr form desc plac hemorr    0.07
# P02.2 Fet rec-nasc afet out anor morf func plac NE    0.06
# P00.2 Fet rec-nasc afet doenc infecc parasit mae      0.03
# P02.5 Fet rec-nasc afet outr compr cord umbilical     0.02
# P01.1 Fet rec-nasc afet ruptura prematura membr       0.02
# P02.7 Fet rec-nasc afetados p/corioamnionite          0.02
# P00.1 Fet rec-nasc afet doenc mat renais vias urin    0.02
# P70.0 Sindr do filho de mae c/diabetes gestacional    0.01
# Q89.9 Malformacoes congen NE                          0.01
# A50.2 Sifilis congen precoce NE                       0.01
# P01.0 Fet rec-nasc afet incompetencia colo uterino    0.01
# P00.8 Fet rec-nasc afet outr afeccoes maternas        0.01
# Q89.7 Malformacoes congen mult NCOP                   0.01
# P01.2 Fet rec-nasc afetados p/oligohidramnio          0.01
# Q00.0 Anencefalia                                     0.01
# P96.9 Afeccoes originadas no periodo perinatal NE     0.01
# P05.9 Retardo NE do crescimento fetal                 0.01
# P01.5 Fet rec-nasc afetados p/gravidez mult           0.01
# P70.1 Sindr do filho de mae diabetica                 0.01
# P83.2 Hidropsia fetal nao-dev doenc hemolitica        0.01
# P02.0 Fet rec-nasc afetados p/placenta previa         0.01
# P03.8 Fet rec-nasc afet out comp esp trb part part    0.01
# P02.4 Fet rec-nasc afet prolapso cordao umbilical     0.01
# Q24.9 Malformacao NE do coracao                       0.01
# P07.2 Imaturidade extrema                             0.01
# P20.1 Hipoxia intra-uter diagn dur trab parto part    0.00
# P02.6 Fet rec-nasc afet outr afecc cordao umb NE      0.00
# P00.9 Fet rec-nasc afetados p/afeccao materna NE      0.00
# P00.5 Fet rec-nasc afetados p/traum materno           0.00
# P02.9 Fet rec-nasc afet anormalidade NE membranas     0.00
# P03.5 Fet rec-nasc afetados p/parto precipitado       0.00
# P02.3 Fet rec-nasc afet sindr transf placentaria      0.00
# Q91.3 Sindr de Edwards NE                             0.00
# P01.8 Fet rec-nasc afet outr complic mat gravidez     0.00
# P01.3 Fet rec-nasc afetados p/polihidramnio           0.00
# P00.3 Fet rec-nasc afet outr doenc circ resp mat      0.00
# P03.9 Fet rec-nasc afet compl NE trab parto parto     0.00
# P01.9 Fet rec-nasc afet afecc maternas gravidez NE    0.00
# P04.4 Fet rec-nasc afet uso drogaq causam dep mae     0.00
# P03.1 Fet rec-nasc afet out apres anor ma-pos desp    0.00
# P56.9 Hidropsia fetal dev outr doenc hemolit e NE     0.00
# P04.2 Fet rec-nasc afetados p/uso de fumo p/mae       0.00
# P96.4 Interrupcao de gravidez afet feto rec-nasc      0.00
# P02.8 Fet rec-nasc afet outr anorm membranas          0.00
# A50.0 Sifilis congen precoce sintomatica              0.00
# Q79.3 Gastrosquise                                    0.00
# P96.8 Outr afeccoes espec orig periodo perinatal      0.00
# P00.4 Fet rec-nasc afet transt nutricionais matern    0.00
# Q91.7 Sindr de Patau NE                               0.00
# Q99.9 Anomalia cromossomica NE                        0.00
# P01.7 Fet rec-nasc afet apres anor antes trab part    0.00
# Q03.9 Hidrocefalia congen NE                          0.00
# Q04.9 Malformacao congen NE do encefalo               0.00
# Q89.8 Outr malformacoes congen espec                  0.00
# P05.1 Pequeno p/a idade gestacional                   0.00
# P55.0 Isoimunizacao Rh do feto e do recem-nascido     0.00
# Q90.9 Sindr de Down NE                                0.00
# P03.0 Fet rec-nasc afet parto e extracao pelvicas     0.00
# Q33.6 Hipoplasia e displasia do pulmao                0.00
# P39.2 Infecc intra-amniotica do feto NCOP             0.00
# Q24.8 Outr malformacoes congen espec do coracao       0.00
# P37.1 Toxoplasmose congen                             0.00
# Q60.1 Agenesia bilateral do rim                       0.00
# P03.6 Fet rec-nasc afet contracoes uterinas anorm     0.00
# P39.9 Infecc propria do periodo perinatal NE          0.00
# Q96.9 Sindr de Turner NE                              0.00
# Q75.9 Malform congen NE dos ossos cranio e face       0.00
# Q79.2 Exonfalia                                       0.00
# Q07.9 Malformacao congen NE do sist nervoso           0.00
# P29.9 Transt cardiovasc NE orig periodo perinatal     0.00
# Q04.2 Holoprosencefalia                               0.00
# Q79.5 Outr malformacoes congen da parede abdominal    0.00
# Q87.8 Outr sindr c/malformacoes congen espec NCOP     0.00
# P04.3 Fet rec-nasc afetados p/uso de alcool p/mae     0.00
# P01.6 Fet rec-nasc afetados p/morte materna           0.00
# P55.9 Doenc hemolitica NE do feto e recem-nascido     0.00
# P29.8 Outr transt cardiovasc orig periodo perinat     0.00
# Q91.2 Trissomia 18 translocacao                       0.00
# Q89.4 Reuniao de gemeos                               0.00
# P04.9 Fet rec-nasc afet infl nocivas maternas NE      0.00
# P56.0 Hidropsia fetal dev isoimunizacao               0.00
# Q05.9 Espinha bifida NE                               0.00
# Q79.0 Hernia diafragmatica congen                     0.00
# P04.1 Fet rec-nasc afet outr medic utiliz p/mae       0.00
# Q01.9 Encefalocele NE                                 0.00
# Q60.2 Agenesia renal NE                               0.00
# Q03.1 Atresia fendas Luschka e foramen Magendie       0.00
# Q21.3 Tetralogia de Fallot                            0.00
# Q60.6 Sindr de Potter                                 0.00
# Q25.7 Outr malformacoes congen da arteria pulmonar    0.00
# P70.8 Out trans transit metab carboid fet rec-nasc    0.00
# Q25.4 Outr malformacoes congen da aorta               0.00
# P53   Doenc hemorragica do feto e do recem-nascido    0.00
# P52.3 Hemorragia intraventr NE feto recem-nascido     0.00
# Q64.5 Ausencia congen da bexiga e da uretra           0.00
# Q96.0 Cariotipo 45 X                                  0.00
# Q87.1 Sindr c/malform congen assoc predom nanismo     0.00
# Q92.8 Outr trissomias espec e trissom parc autoss     0.00
# Q87.2 Sindr c/malform congen afetando predom membr    0.00
# Q40.9 Malformacao congen NE trato digestivo super     0.00
# Q22.6 Sindr do coracao direito hipoplasico            0.00
# P50.3 Hemorragia p/a circulacao do outr gemeo         0.00
# Q91.4 Trissomia 13 nao-disjuncao meiotica             0.00
# Q23.0 Estenose congen da valva aortica                0.00
# P10.9 Lacerac hemorr intracran NE dev traum parto     0.00
# Q04.6 Cistos cerebrais congen                         0.00
# Q20.4 Ventriculo c/dupla via de entrada               0.00
# Q89.0 Malformacoes congen do baco                     0.00
# P52.8 Outr hemorrag intracranianas feto rec-nasc      0.00
# P11.5 Traum de parto da coluna e medula espinhal      0.00
# Q64.7 Outr malformacoes congen da bexiga e uretra     0.00
# P11.0 Edema cerebral dev traum de parto               0.00
# Q89.2 Malformacoes congen de outr gland endocrinas    0.00
# P03.2 Fet rec-nasc afetados p/parto p/forceps         0.00
# Q51.3 Utero bicorneo                                  0.00
# Q42.9 Ausenc atresia estenose congen part NE colon    0.00
# Q76.4 Out malf cong coluna vert n-assoc escoliose     0.00
# Q79.1 Outr malformacoes congen do diafragma           0.00
# Q89.1 Malformacoes congen das supra-renais            0.00
# Q75.0 Craniossinostose                                0.00
# Q64.2 Valvulas uretrais posteriores congen            0.00
# Q01.0 Encefalocele frontal                            0.00
# P04.0 Fet rec-nasc afet anest analg mat grav parto    0.00
# Q60.4 Hipoplasia renal bilateral                      0.00
# P50.8 Outr perdas sanguineas fetais                   0.00
# Q39.9 Malformacao congen NE do esofago                0.00
# Q43.8 Outr malformacoes congen espec do intestino     0.00
# Q90.2 Trissomia 21 translocacao                       0.00
# Q20.1 Ventriculo direito c/dupla via de saida         0.00
# Q00.1 Craniorraquisquise                              0.00
# Q86.8 Outr sindr c/malf cong dev causas exog conh     0.00
# Q20.6 Isomerismo dos apendices atriais                0.00
# Q28.3 Outr malformacoes dos vasos cerebrais           0.00
# Q74.0 Out malform cong membr super incl cint escap    0.00
# Q31.8 Outr malformacoes congen da laringe             0.00
# P52.5 Hemorragia subaracnoidea feto recem-nascido     0.00
# Q40.3 Malformacao congen NE do estomago               0.00
# Q24.0 Dextrocardia                                    0.00
# Q92.0 Trissomia cromoss inteiro n-disjuncao meiot     0.00
# Q51.9 Malformacao congen NE utero colo utero SOE      0.00
# Q30.9 Malformacao congen NE do nariz                  0.00
# Q25.6 Estenose da arteria pulmonar                    0.00
# P25.1 Pneumotorax originado no periodo perinatal      0.00
# Q92.1 Trissomia cromoss inteiro mosaicismo cromoss    0.00
# Q76.5 Costela cervical                                0.00
# Q92.6 Cromossomos marcadores suplementares            0.00
# Q96.4 Mosaic crom 45 X/out linh cel crom sex anorm    0.00
# P52.6 Hemorr cerebel fossa posterior feto rec-nasc    0.00
# Q28.2 Malform arteriovenosa dos vasos cerebrais       0.00
# Q86.2 Dismorfismo dev Warfarin                        0.00
# Q85.8 Outr facomatoses NCOP                           0.00
# P11.9 Traum de parto NE do sist nervoso central       0.00
# P25.0 Enfisema interst originado periodo perinatal    0.00
# Q36.0 Fenda labial bilateral                          0.00
# Q55.9 Malform congen NE dos orgaos genitais masc      0.00
# Q24.1 Levocardia                                      0.00
# P10.1 Hemorragia cerebral dev traum de parto          0.00
# Q37.8 Fenda do palato c/fenda labial bilateral NE     0.00
# Q95.9 Rearranjos e marcadores equilibrados NE         0.00
# Q39.3 Estenose congen e estreit congen esofago        0.00
# Name: causabas_subcategoria, dtype: float64
#
# Percentual de valores únicos para FLAG_BASE:
# SINASC       98.95
# SIM_DOFET     1.05
# Name: FLAG_BASE, dtype: float64

# %% [markdown]
# ### Numerical variables

# %%
# Basic Statistics for Numeric Variables
lista_numerica = [
'IDADEMAE'
, 'SEMAGESTAC'
, 'PESO'
, 'sum_CENTROBS'
, 'sum_QTINST34'
, 'sum_QTINST35'
, 'sum_QTINST36'
, 'sum_QTINST37'
, 'sum_QTLEIT34'
, 'sum_QTLEIT38'
, 'sum_QTLEIT39'
, 'sum_QTLEIT40'
, 'sum_CENTRNEO'
, 'TP_UNID_5'
, 'TP_UNID_7'
, 'TP_UNID_15'
, 'TP_UNID_36'
, 'TP_UNID_61'
]
estatisticas_numericas = df[lista_numerica].describe()
estatisticas_numericas

# %% [markdown]
# ### Outlier

# %%
def detectar_outliers(col):
    q1 = col.quantile(0.25)
    q3 = col.quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    outliers = col[(col < lower_bound) | (col > upper_bound)]
    return outliers

outliers_numericos = df[lista_numerica].apply(detectar_outliers)

for i in lista_numerica:
    print(outliers_numericos.loc[~outliers_numericos[i].isna(), [i]].describe())

# %%
for i in lista_numerica:
    x1 = df.loc[df['ano_evento'] == 2019, i]
    x2 = df.loc[df['ano_evento'] == 2020, i]
    x3 = df.loc[df['ano_evento'] == 2021, i]
    x4 = df.loc[df['ano_evento'] == 2022, i]

    # Normalize
    kwargs = dict(alpha=0.5, bins=100, density=True, stacked=True)

    # Plot
    plt.figure()  # Creates a new figure for each iteration
    plt.hist(x1, **kwargs, color='g', label='2019')
    plt.hist(x2, **kwargs, color='b', label='2020')
    plt.hist(x3, **kwargs, color='r', label='2021')
    plt.hist(x4, **kwargs, color='y', label='2022')
    plt.gca().set(title=f'Histograma {i}', ylabel='Probability')
    # plt.xlim(50, 75)
    plt.legend()

    # Show or save the figure here if needed
    # plt.savefig(f'histograma_{i}.png')

    plt.show()  # Show the graph

# %% [markdown]
# ### Cause of death

# %%
contingency_table = pd.crosstab(index=df['CAUSABAS'], columns=df['ano_evento'])#, normalize='index')
contingency_table = contingency_table.reset_index()
contingency_table.loc[contingency_table['CAUSABAS'].isin(['P200', 'P95'])]
# Out:
# ano_evento CAUSABAS  2018  2019  2020  2021  2022
# 74             P200  2635  2674  1842  1712  1843
# 141             P95  6094  6172  6634  6701  5793

# %% [markdown]
# ### Births by municipality per year

# %%
df_sinasc = df.loc[df['FLAG_BASE']=='SINASC']
pd.crosstab(index=df_sinasc['evento_MUNNOMEX'], columns=df_sinasc['ano_evento'])
# Out:
# ano_evento                          2018    2019    2020    2021    2022
# evento_MUNNOMEX
# ABADIA DE GOIAS                        2       5       5       2       6
# ABADIA DOS DOURADOS                    1       2       0       1       0
# ABADIANIA                              1       3       5       5       9
# ABAETE                               218     196     203     164     160
# ABAETETUBA                          2496    2133    2480    2861    2836
# ABAIARA                                1       1       2       5       5
# ABAIRA                                 6       4       3       3       4
# ABARE                                103      96     115     107      88
# ABATIA                                 0       2       0       1       0
# ABDON BATISTA                          0       0       1       0       1
# ABEL FIGUEIREDO                       89      61      32     102      90
# ABELARDO LUZ                         132     165     157     182     139
# ABRE CAMPO                           101     111     141     179     248
# ABREU E LIMA                        1429    1360    1044     354     228
# ABREULANDIA                            2       3       0       1       2
# ACAIACA                                0       1       1       0       0
# ACAILANDIA                          1673    1684    1728    1856    1549
# ACAJUTIBA                             10       8      11       7       6
# ACARA                                336     284     251     335     397
# ACARAPE                                1       1       1       2       2
# ACARAU                              2268    2313    2103    2064    1812
# ACARI                                 46      22      29      62      35
# ACEGUA                                99      78     101     117      84
# ACOPIARA                             573     700     661     578     576
# ACORIZAL                               1       0       0       0       1
# ACRELANDIA                            21       7      14      18      11
# ACREUNA                               99      87     121      90      60
# ACU                                  831     444     153      82      25
# ACUCENA                                1       1       0       0       1
# ADAMANTINA                           627     640     645     623     649
# ADELANDIA                              0       0       0       1       0
# ADRIANOPOLIS                           2       1       0       2       3
# ADUSTINA                               1       2       2       6      11
# AFOGADOS DA INGAZEIRA               2466    2683    2519    2464    2425
# AFONSO BEZERRA                        13       2       2       2       1
# AFONSO CLAUDIO                       395     316     340     350     330
# AFONSO CUNHA                           6       7       6      12       3
# AFRANIO                              103      99     110     123     115
# AFUA                                 290     296     341     390     391
# AGRESTINA                            292     365     456     443     425
# AGRICOLANDIA                           0       0       2       0       0
# AGROLANDIA                             1       1       1       0       0
# AGRONOMICA                             0       2       0       0       1
# AGUA AZUL DO NORTE                   137     123      91     147     150
# AGUA BOA                             974     948    1001    1023    1159
# AGUA BRANCA                          460     476     295     213     151
# AGUA CLARA                           218     217     188     208     191
# AGUA COMPRIDA                          0       0       0       0       1
# AGUA DOCE                             44      11       4       4       1
# AGUA DOCE DO MARANHAO                  4       4       2       6      13
# AGUA DOCE DO NORTE                     1       0       2       1       0
# AGUA FRIA                             77      68      81      60      67
# AGUA FRIA DE GOIAS                     1       5       7       3       1
# AGUA PRETA                             1      25      69     233      10
# BAIXA GRANDE DO RIBEIRO              250     286     253     276     196
# BAIXIO                                 0       1       0       1       0
# BAIXO GUANDU                         170      91      48       9       3
# BALDIM                                 1       0       0       0       0
# BALIZA                                 1       0       2       0       0
# BALNEARIO ARROIO DO SILVA              0       0       3       0       1
# BALNEARIO BARRA DO SUL                 0       1       0       2       3
# BALNEARIO CAMBORIU                  5417    5353    5595    5292    5230
# BALNEARIO PICARRAS                     4       6      10      13      21
# BALNEARIO PINHAL                       4       3       2       3       1
# BALNEARIO RINCAO                       1       0       0       1       0
# BALSA NOVA                             2       2       1       0       3
# BALSAMO                                0       1       0       1       2
# BALSAS                              3024    3166    3004    3183    3280
# BAMBUI                               199     210     241     188     182
# BANABUIU                              43      66      56      35      20
# BANANAL                                3       2       1       4       3
# BANANEIRAS                            16       8      16      14      67
# BANDEIRA DO SUL                        1       0       1       0       0
# BANDEIRANTES                         482     485     433     452     422
# BANDEIRANTES DO TOCANTINS              0       1       0       0       0
# BANNACH                                8       4       4       6       0
# BANZAE                                 9       3       3      13      18
# BARAO                                  1       0       0       0       0
# BARAO DE COCAIS                      197     229     192     230     205
# BARAO DE COTEGIPE                      1       3       0       0       0
# BARAO DE GRAJAU                        1       1       1       6       2
# BARAO DE MELGACO                       1       0       1       1       2
# BARAO DO TRIUNFO                       2       0       1       1       0
# BARAUNA                                5       3       2       2       4
# BARBACENA                           2559    2725    2672    2560    2341
# BARBALHA                            3559    3380    3172    2896    2710
# BARBOSA FERRAZ                        68      63      62      30       0
# BARCARENA                           1719    2738    2673    2621    2453
# BARCELONA                              2       0       3       3       1
# BARCELOS                             565     542     492     496     381
# BARIRI                               308     334     306     337     301
# BARRA                               1320    1291    1098    1157    1012
# BARRA BONITA                         344     322     280     240     193
# BARRA D'ALCANTARA                      0       0       0       1       1
# BARRA DA ESTIVA                      717     538     625     571     570
# BARRA DE GUABIRABA                     6      10       7      31      11
# BARRA DE SANTA ROSA                    1       0       2       1       4
# BARRA DE SANTANA                       3       1       1       1       2
# BARRA DE SANTO ANTONIO                 4       2       3       1       3
# BARRA DE SAO FRANCISCO              1034     950     928     831     777
# BARRA DE SAO MIGUEL                    1       0       0       0       1
# BARRA DO BUGRES                      614     631     360       2      98
# BARRA DO CHAPEU                        0       0       0       2       1
# BARRA DO CHOCA                       207     189     214     161     102
# BARRA DO CORDA                      2101    1946    1901    2008    1861
# BARRA DO GARCAS                     1394    1423    1346    1408    1331
# BARRA DO MENDES                      118      91      63      72      76
# BARRA DO OURO                          5       5       2       3       4
# BARRA DO PIRAI                       693     695     675     719     591
# BARRA DO RIBEIRO                       5      11      10       4       2
# BARRA DO RIO AZUL                      0       0       0       1       0
# BARRA DO ROCHA                         0       1       1       0       1
# BARRA DO TURVO                         2       0       7       6       2
# BARRA DOS COQUEIROS                    1       1       6       7       4
# BARRA LONGA                            0       2       0       1       0
# BARRA MANSA                         1936    1718    1760    1588    1639
# BARRA VELHA                           16      10      11       8      22
# BARRACAO                               0       0       1       0       2
# BEZERROS                             436     481     543     275     201
# BIAS FORTES                            0       1       4       1       1
# BICAS                                  2      12      12      14      15
# BIGUACU                              290    1158    1396    1534    1502
# BILAC                                  0       0       3       1       1
# BIRIGUI                             2031    1900    1723    1628    1527
# BIRITIBA-MIRIM                         4       5       1       6       1
# BIRITINGA                             82     102      88      87      63
# BITURUNA                             227     218     193     165     148
# BLUMENAU                            5460    5291    5289    5287    5380
# BOA ESPERANCA                        555     558     500     443     483
# BOA ESPERANCA DO SUL                   3       5       3       3       8
# BOA HORA                               0       1       0       0       0
# BOA NOVA                               5       5       3       6       5
# BOA VIAGEM                           599     371     400     382     447
# BOA VISTA                          10747   11797   10861   11018   10604
# BOA VISTA DA APARECIDA                 5       8       7       6       6
# BOA VISTA DO GURUPI                   10       8       5      12      13
# BOA VISTA DO RAMOS                   283     283     278     271     258
# BOA VISTA DO SUL                       0       0       1       0       0
# BOA VISTA DO TUPIM                    54      61      70      86      72
# BOCA DA MATA                          91      99      73      82      63
# BOCA DO ACRE                         540     527     536     548     524
# BOCAINA                                1       0       0       1       1
# BOCAINA DE MINAS                       0       1       2       1       0
# BOCAINA DO SUL                         2       0       2       1       0
# BOCAIUVA                             602     607     619     626     498
# BOCAIUVA DO SUL                        2       1       2       1       4
# BODO                                   0       0       1       0       0
# BODOCO                                85      72      63      67      38
# BODOQUENA                            101     114      80      64      53
# BOFETE                                 1       1       1       3       2
# BOITUVA                              659     701     714     750     742
# BOM CONSELHO                         204     118      88     119     134
# BOM DESPACHO                         743     684     684     652     641
# BOM JARDIM                           896     460     847     857     772
# BOM JARDIM DA SERRA                    2       2       0       2       0
# BOM JARDIM DE GOIAS                  127     109     120     128     102
# BOM JARDIM DE MINAS                    0       0       2       3       5
# BOM JESUS                           1295    1285    1105    1330    1268
# BOM JESUS DA LAPA                   1419    1466    1600    1526    1444
# BOM JESUS DA SERRA                    76      67      51      72      61
# BOM JESUS DAS SELVAS                 253     248     262     262     176
# BOM JESUS DE GOIAS                   128     188     149     179     183
# BOM JESUS DO AMPARO                    1       1       1       1       0
# BOM JESUS DO ARAGUAIA                  1       2       0       2       4
# BOM JESUS DO GALHO                    37       3       0       0       3
# BOM JESUS DO ITABAPOANA              569     563     645     800     859
# BOM JESUS DO TOCANTINS               181     186     175     159     139
# BOM JESUS DOS PERDOES                  6       6       7       6      10
# BOM LUGAR                              0       1       0       1       0
# BOM PRINCIPIO                          3       4       3       2       1
# BOM PRINCIPIO DO PIAUI                 2       1       0       4       1
# BOM REPOUSO                            1       0       0       3       0
# BOM RETIRO                             6       0       1       0       0
# BOM RETIRO DO SUL                     80      85      86      76      73
# BOM SUCESSO                           72      16      34      32      15
# BOM SUCESSO DE ITARARE                 1       0       0       0       1
# BOMBINHAS                              8      14       6      16      11
# BONFIM                               114     121     121     125     112
# BONFIM DO PIAUI                        0       0       1       1       0
# BONFINOPOLIS                           0       1       0       0       0
# BONFINOPOLIS DE MINAS                  3       2       2       0       3
# %% [markdown]
# # Cleaning data missing the dataset

# %% [markdown]
# ### Remoção

# %%
# Removing columns with a high frequency of missings

#df_limpo = df_limpo.drop(columns=['OBITOGRAV', 'causabas_categoria', 'TIPOBITO', 'causabas_capitulo', 'CAUSABAS'
#                                  , 'def_obito_parto', 'OBITOPARTO', 'causabas_subcategoria', 'causabas_grupo'])

# %%
# Removing duplicates SINASC
tam_inicial = len(df)
df_limpo = df.drop_duplicates()
tam_depois=len(df_limpo)
print(f'Remove duplicates {tam_inicial - tam_depois} rows')
# Out:
# Remove duplicates 3908 rows

# %%
def count_missing_values(df, columns, group_by):
    """
    Conta a quantidade de valores ausentes para cada coluna especificada, separado por grupos de uma coluna.
    
    Parâmetros:
        df (pd.DataFrame): DataFrame de entrada.
        columns (list): Lista de colunas para contar os valores ausentes.
        group_by (str): Nome da coluna para agrupar os resultados.
        
    Retorna:
        pd.DataFrame: DataFrame com a contagem de valores ausentes por grupo.
    """
    return df.groupby(group_by)[columns].apply(lambda x: x.isnull().sum())

# %%
lista_missing = [
    'ESCMAE2010','SEMAGESTAC','PESO','IDADEMAE','GRAVIDEZ', 'res_MUNNOMEX', 'res_CAPITAL', 'res_SIGLA_UF'
    , 'evento_MUNNOMEX', 'evento_CAPITAL', 'evento_REGIAO', 'evento_SIGLA_UF'
]
missing_counts = count_missing_values(df_limpo, lista_missing,  group_by='FLAG_BASE')

# %%
print(missing_counts)
# Out:
#            ESCMAE2010  SEMAGESTAC  PESO  IDADEMAE  GRAVIDEZ  res_MUNNOMEX  \
# FLAG_BASE
# SIM_DOFET       13267        8293  8703      9794       581           233
# SINASC         182552      171267  3275       188         0             0
#
#            res_CAPITAL  res_SIGLA_UF  evento_MUNNOMEX  evento_CAPITAL  \
# FLAG_BASE
# SIM_DOFET          233           233              227             227
# SINASC               0             0                0               0
#
#            evento_REGIAO  evento_SIGLA_UF
# FLAG_BASE
# SIM_DOFET            227              227
# SINASC                 0                0

# %%
# Removendo os missing SINASC

#lista_missing_sim = [
#   'sum_CENTROBS','sum_QTINST34','sum_QTINST35','sum_QTINST36','sum_QTINST37','TP_UNID_5'
#    ,'TP_UNID_7','TP_UNID_15','TP_UNID_36','TP_UNID_61', 'res_MUNNOMEX', 'res_CAPITAL', 'res_SIGLA_UF'
#    , 'evento_MUNNOMEX', 'evento_CAPITAL', 'evento_REGIAO', 'evento_SIGLA_UF', 'causabas_capitulo', 'causabas_categoria'
#    , 'causabas_grupo', 'causabas_subcategoria'
#]

lista_missing = [
    'ESCMAE2010','SEMAGESTAC','PESO','IDADEMAE','sum_CENTROBS','sum_QTINST34','sum_QTINST35','sum_QTINST36','sum_QTINST37'
    ,'sum_QTLEIT34','sum_QTLEIT38','sum_QTLEIT39','sum_QTLEIT40','sum_CENTRNEO','TP_UNID_5'
    ,'TP_UNID_7','TP_UNID_15','TP_UNID_36','TP_UNID_61', 'GRAVIDEZ', 'res_MUNNOMEX', 'res_CAPITAL', 'res_SIGLA_UF'
    , 'evento_MUNNOMEX', 'evento_CAPITAL', 'evento_REGIAO', 'evento_SIGLA_UF'
]
tam_antes = len(df_limpo)
#df_limpo_sim = df_limpo_sim.dropna(subset = lista_missing_sim)
df_limpo = df_limpo.dropna(subset = lista_missing)
df_limpo = df_limpo.reset_index(drop=True)
tam_depois=len(df_limpo)
print(f'Remove missing {tam_antes - tam_depois} rows')
# Out:
# Remove missing 364271 rows

# %%
# Remove ignored class SINASC
tam_antes = len(df_limpo) 
df_limpo['evento_MUNNOMEX'] = df_limpo['evento_MUNNOMEX'].astype(str).fillna('IGNORADO')
df_limpo = df_limpo.loc[~df_limpo['evento_MUNNOMEX'].str.contains('IGNORADO')]
tam_depois=len(df_limpo)
print(f'Remove ignored evento_MUNNOMEX {tam_antes - tam_depois} rows')
# Out:
# Remove ignored evento_MUNNOMEX 0 rows

# %%
tam_antes = len(df_limpo)
df_limpo = df_limpo.loc[~df_limpo['res_MUNNOMEX'].str.contains('IGNORADO')]
tam_depois=len(df_limpo)
print(f'Remove ignored res_MUNNOMEX {tam_antes - tam_depois} rows')
# Out:
# Remove ignored res_MUNNOMEX 487 rows

# %%
tam_antes = len(df_limpo)
df_limpo = df_limpo.loc[df_limpo['idademae_faixa']!='Ignorado']
tam_depois=len(df_limpo)
print(f'Remove ignored idademae_faixa {tam_antes - tam_depois} rows')
# Out:
# Remove ignored idademae_faixa 0 rows

# %%
tam_antes = len(df_limpo)
df_limpo = df_limpo.loc[df_limpo['ESCMAE2010']!=9]
tam_depois=len(df_limpo)
print(f'Remove ignored ESCMAE2010 {tam_antes - tam_depois} rows')
# Out:
# Remove ignored ESCMAE2010 72739 rows

# %%
tam_antes = len(df_limpo)
df_limpo = df_limpo.loc[df_limpo['GRAVIDEZ']!=9]
tam_depois=len(df_limpo)
print(f'Remove ignored GRAVIDEZ {tam_antes - tam_depois} rows')
# Out:
# Remove ignored GRAVIDEZ 6911 rows

# %%
tam_antes = len(df_limpo)
df_limpo = df_limpo.loc[df_limpo['idade_gestacao_faixa']!='Ignorado']
tam_depois=len(df_limpo)
print(f'Remove ignored idade_gestacao_faixa {tam_antes - tam_depois} rows')
# Out:
# Remove ignored idade_gestacao_faixa 102524 rows

# %%
tam_antes = len(df_limpo)
df_limpo = df_limpo.loc[df_limpo['SEXO']!=0]
tam_depois=len(df_limpo)
print(f'Remove ignored SEXO {tam_antes - tam_depois} rows')
# Out:
# Remove ignored SEXO 4558 rows

# %%
tam_antes = len(df_limpo)
df_limpo = df_limpo.loc[df_limpo['peso_faixa']!='Ignorado']
tam_depois=len(df_limpo)
print(f'Remove ignored peso_faixa {tam_antes - tam_depois} rows')
# Out:
# Remove ignored peso_faixa 0 rows

# %%
# Mother's age
# Remover somente em SINASC
tam_antes = len(df_limpo)
df_limpo = df_limpo.loc[(df_limpo['IDADEMAE']>=10) & (df_limpo['IDADEMAE']<=50)]
tam_depois=len(df_limpo)
print(f'Remove IDADEMAE <10 or >50 {tam_antes - tam_depois} rows')
# Out:
# Remove IDADEMAE <10 or >50 1454 rows

# %%
# Weight
std_peso = np.std(df['PESO'])
media_peso = np.mean(df['PESO'])
lim_inf = media_peso - (6 * std_peso)
lim_sup = media_peso + (6 * std_peso)
tam_antes = len(df_limpo)
df_limpo = df_limpo.loc[df_limpo['PESO']>0]
df_limpo = df_limpo.loc[(df_limpo['PESO']>=lim_inf) & (df_limpo['PESO']<=lim_sup)]
tam_depois=len(df_limpo)
print(f'Remove PESO 6 std {tam_antes - tam_depois} rows')
# Out:
# Remove PESO 6 std 71 rows

# %%
# Weeks of pregnancy less than 22 are not considered deaths, but rather miscarriages. SIM e SINASC
tam_antes = len(df_limpo)
df_limpo = df_limpo.loc[df_limpo['idade_gestacao_faixa']!='menor_22']
tam_depois=len(df_limpo)
print(f'Remove idade_gestacao_faixa menor_22 {tam_antes - tam_depois} rows')
# Out:
# Remove idade_gestacao_faixa menor_22 14547 rows

# %%
tam_depois = len(df)
print(f'Total remove {tam_inicial - tam_depois} rows')
# Out:
# Total remove 0 rows

# %%
df_limpo = df_limpo.reset_index(drop=True)

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13337283 entries, 0 to 13337282
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   data_evento            object
#  1   ano_evento             int64
#  2   TIPOBITO               float64
#  3   evento_MUNNOMEX        object
#  4   res_MUNNOMEX           object
#  5   evento_CAPITAL         object
#  6   res_CAPITAL            object
#  7   evento_REGIAO          object
#  8   res_REGIAO             object
#  9   evento_SIGLA_UF        object
#  10  res_SIGLA_UF           object
#  11  IDADEMAE               float64
#  12  idademae_faixa         object
#  13  ESCMAE2010             float64
#  14  escolaridade_mae       object
#  15  OBITOGRAV              float64
#  16  GRAVIDEZ               float64
#  17  tipo_gravidez          object
#  18  SEMAGESTAC             float64
#  19  idade_gestacao_faixa   object
#  20  SEXO                   int64
#  21  def_sexo               object
#  22  PESO                   float64
#  23  peso_faixa             object
#  24  OBITOPARTO             float64
#  25  def_obito_parto        object
#  26  CAUSABAS               object
#  27  causabas_capitulo      object
#  28  causabas_categoria     object
#  29  causabas_grupo         object
#  30  causabas_subcategoria  object
#  31  FLAG_BASE              object
#  32  sum_CENTROBS           float64
#  33  sum_QTINST34           float64
#  34  sum_QTINST35           float64
#  35  sum_QTINST36           float64
#  36  sum_QTINST37           float64
#  37  sum_QTLEIT34           float64
#  38  sum_QTLEIT38           float64
#  39  sum_QTLEIT39           float64
#  40  sum_QTLEIT40           float64
#  41  sum_CENTRNEO           float64
#  42  TP_UNID_5              float64
#  43  TP_UNID_7              float64
#  44  TP_UNID_15             float64
#  45  TP_UNID_36             float64
#  46  TP_UNID_61             float64
# dtypes: float64(23), int64(2), object(22)
# memory usage: 4.7+ GB

# %%
df_limpo[df_limpo['FLAG_BASE'] == 'SIM_DOFET'].value_counts(['ano_evento'])
# Out:
# ano_evento
# 2018          20834
# 2019          19957
# 2021          19747
# 2020          19432
# 2022          18487
# dtype: int64

# %%
df_limpo.to_csv('base_limpa/base_unificada_limpa_remocao.csv', index=False)

# %%
#Importing Modules
from Funcoes_auxiliares.func_aux import *
import pandas as pd
import numpy as np
from scipy.stats import chi2
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
#plt.style.use("ggplot")
#from google.colab import drive
from pandas.testing import assert_frame_equal
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from tabulate import tabulate
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\gabri\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\gabri\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %%
df = pd.read_csv('base_limpa/base_unificada_limpa.csv')
periodo='2019-2020-2021-2022'
df = df.loc[df['ano_evento'].isin([2019, 2020, 2021, 2022])]
df['ANO'] = np.where(df['ano_evento']==2019, 0, 1)
# Variável PRM
df['PRM'] = np.where(df['idade_gestacao_faixa'].isin(['entre_37_39', 'entre_40_42']), 0, 1)

# %% [markdown]
# # Modelo zero

# %%
variaveis =  [  
     'ANO'
    , 'PRM'
    , 'evento_REGIAO'
    , 'idademae_faixa'
    , 'escolaridade_mae'
    ,'tipo_gravidez'
    , 'idade_gestacao_faixa'
    , 'def_sexo'
    , 'peso_faixa'
    , 'FLAG_BASE'
]

df_mod = df[variaveis]

# %%
# PRM contagem
NPT = (df_mod['PRM']==1).sum()
NT = (df_mod['PRM']==0).sum()

# %%
df_mod = pd.get_dummies(df_mod)

# %%
df_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10493463 entries, 0 to 10493462
# Data columns (total 32 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   ANO                                int32
#  1   PRM                                int32
#  2   evento_REGIAO_Centro-Oeste         uint8
#  3   evento_REGIAO_Nordeste             uint8
#  4   evento_REGIAO_Norte                uint8
#  5   evento_REGIAO_Sudeste              uint8
#  6   evento_REGIAO_Sul                  uint8
#  7   idademae_faixa_entre_20_34         uint8
#  8   idademae_faixa_entre_35_39         uint8
#  9   idademae_faixa_maior_igual_40      uint8
#  10  idademae_faixa_menor_igual_19      uint8
#  11  escolaridade_mae_Ensino_medio      uint8
#  12  escolaridade_mae_Ensino_superior   uint8
#  13  escolaridade_mae_Fundamental       uint8
#  14  escolaridade_mae_Sem_escolaridade  uint8
#  15  tipo_gravidez_Ignorado             uint8
#  16  tipo_gravidez_Multipla             uint8
#  17  tipo_gravidez_Unica                uint8
#  18  idade_gestacao_faixa_entre_22_27   uint8
#  19  idade_gestacao_faixa_entre_28_36   uint8
#  20  idade_gestacao_faixa_entre_37_39   uint8
#  21  idade_gestacao_faixa_entre_40_42   uint8
#  22  def_sexo_Feminino                  uint8
#  23  def_sexo_Masculino                 uint8
#  24  peso_faixa_entre_1500_2499         uint8
#  25  peso_faixa_entre_2500_3500         uint8
#  26  peso_faixa_entre_3500_3999         uint8
#  27  peso_faixa_entre_500_1499          uint8
#  28  peso_faixa_maior_igual_4000        uint8
#  29  peso_faixa_menor_500               uint8
#  30  FLAG_BASE_SIM_DOFET                uint8
#  31  FLAG_BASE_SINASC                   uint8
# dtypes: int32(2), uint8(30)
# memory usage: 460.3 MB

# %%
df_mod.columns
# Out:
# Index(['ANO', 'PRM', 'evento_REGIAO_Centro-Oeste', 'evento_REGIAO_Nordeste',
#        'evento_REGIAO_Norte', 'evento_REGIAO_Sudeste', 'evento_REGIAO_Sul',
#        'idademae_faixa_entre_20_34', 'idademae_faixa_entre_35_39',
#        'idademae_faixa_maior_igual_40', 'idademae_faixa_menor_igual_19',
#        'escolaridade_mae_Ensino_medio', 'escolaridade_mae_Ensino_superior',
#        'escolaridade_mae_Fundamental', 'escolaridade_mae_Sem_escolaridade',
#        'tipo_gravidez_Ignorado', 'tipo_gravidez_Multipla',
#        'tipo_gravidez_Unica', 'idade_gestacao_faixa_entre_22_27',
#        'idade_gestacao_faixa_entre_28_36', 'idade_gestacao_faixa_entre_37_39',
#        'idade_gestacao_faixa_entre_40_42', 'def_sexo_Feminino',
#        'def_sexo_Masculino', 'peso_faixa_entre_1500_2499',
#        'peso_faixa_entre_2500_3500', 'peso_faixa_entre_3500_3999',
#        'peso_faixa_entre_500_1499', 'peso_faixa_maior_igual_4000',
#        'peso_faixa_menor_500', 'FLAG_BASE_SIM_DOFET', 'FLAG_BASE_SINASC'],
#       dtype='object')

# %%
# Modelo
#Defining covariates
var_model=[
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    , 'idade_gestacao_faixa_entre_22_27'
    , 'idade_gestacao_faixa_entre_28_36'
    #, 'idade_gestacao_faixa_entre_37_39'
    , 'idade_gestacao_faixa_entre_40_42'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    , 'FLAG_BASE_SIM_DOFET'
    #, 'FLAG_BASE_SINASC'
]

X = df_mod[var_model].values

## FIRST REGRESSION
y = df_mod[['ANO']].values
clf = LogisticRegression(random_state=0, max_iter=2000).fit(X, y)
df_mod = df_mod.assign(PROPENSITY_SCORE=clf.predict_proba(X)[:, 1])

#USING PROPENSITY SCORE TO SELECT SAMPLES TO SECOND REGRESSION
psw_base=df_mod[((df_mod['PROPENSITY_SCORE']>df_mod['PROPENSITY_SCORE'].quantile(0.1)) &
                 (df_mod['PROPENSITY_SCORE']<df_mod['PROPENSITY_SCORE'].quantile(0.9)))]

#COUNTING
po=len(df_mod)
tpo=len(df_mod[df_mod['ANO']==1])
cpo=len(df_mod[df_mod['ANO']==0])
pa=len(psw_base)
tpa=len(psw_base[psw_base['ANO']==1])
cpa=len(psw_base[psw_base['ANO']==0])

print('----------------------------------------------------------------')
print('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES')
print('----------------------------------------------------------------')
print('N without missing  :', po)
print('Treated samples    :', tpo,np.round(100*tpo/po,2),'%')
print('Controled samples  :', cpo,np.round(100*cpo/po,2),'%')
print('----------------------------------------------------------------')
print('SELECTED/MATCHET SAMPLES')
print('----------------------------------------------------------------')
print('% Selected         :', np.round(100*pa/po,2),'%')
print('N selected         :', pa)
print('Treated selected   :', tpa,np.round(100*tpa/pa,2),'%')
print('Controled selected :', cpa,np.round(100*cpa/pa,2),'%')
print('----------------------------------------------------------------')
print('')

#PSW weights
w =psw_base['ANO']/psw_base['PROPENSITY_SCORE'] + ((1-psw_base['ANO'])/(1-psw_base['PROPENSITY_SCORE']))
# Out:
# ----------------------------------------------------------------
# USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES
# ----------------------------------------------------------------
# N without missing  : 10493463
# Treated samples    : 7737859 73.74 %
# Controled samples  : 2755604 26.26 %
# ----------------------------------------------------------------
# SELECTED/MATCHET SAMPLES
# ----------------------------------------------------------------
# % Selected         : 79.74 %
# N selected         : 8367082
# Treated selected   : 6184437 73.91 %
# Controled selected : 2182645 26.09 %
# ----------------------------------------------------------------

# %%
## SECOND REGRESSION
aux=['ANO']
var_model_2 = [
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    #, 'idade_gestacao_faixa_entre_22_27'
    #, 'idade_gestacao_faixa_entre_28_36'
    #, 'idade_gestacao_faixa_entre_37_39'
    #, 'idade_gestacao_faixa_entre_40_42'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    , 'FLAG_BASE_SIM_DOFET'
    #, 'FLAG_BASE_SINASC'
]

X = psw_base[aux+var_model_2].values
y = psw_base[['PRM']].values

X_ANO = sm.add_constant(X)
clf_ano = sm.Logit(y, X_ANO,weights=w).fit()
aux=['Intercept','ANO']

print('----------------------------------------------------------------')
print('PSW REPORT',periodo)
print('----------------------------------------------------------------')
print(clf_ano.summary(xname=aux+var_model_2))
print('----------------------------------------------------------------')


IC=np.exp(clf_ano.conf_int(0.05))
odds_ratio=pd.DataFrame(
    data = {
        'Var':aux+var_model_2
        , 'Odds_ratio': np.round(np.exp(clf_ano.params),3)
        , 'Odds_Lim_inf': np.round(IC[:,0],3)
        , 'Odds_Lim_Sup': np.round(IC[:,1],3)
        , 'p-values':np.round(clf_ano.pvalues,3)
    }
)
print(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.221857
#          Iterations 8
# ----------------------------------------------------------------
# PSW REPORT 2019-2020-2021-2022
# ----------------------------------------------------------------
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:              8367082
# Model:                          Logit   Df Residuals:                  8367062
# Method:                           MLE   Df Model:                           19
# Date:                Wed, 03 Jul 2024   Pseudo R-squ.:                  0.3095
# Time:                        00:54:02   Log-Likelihood:            -1.8563e+06
# converged:                       True   LL-Null:                   -2.6881e+06
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -2.8193      0.005   -605.218      0.000      -2.828      -2.810
# ANO                                   0.0354      0.003     10.955      0.000       0.029       0.042
# evento_REGIAO_Centro-Oeste           -0.5698      0.006   -103.316      0.000      -0.581      -0.559
# evento_REGIAO_Nordeste               -0.8784      0.004   -221.674      0.000      -0.886      -0.871
# evento_REGIAO_Norte                  -0.7585      0.006   -132.590      0.000      -0.770      -0.747
# evento_REGIAO_Sul                    -0.6339      0.005   -136.675      0.000      -0.643      -0.625
# idademae_faixa_entre_35_39            0.0591      0.004     14.212      0.000       0.051       0.067
# idademae_faixa_maior_igual_40        -0.3761      0.012    -32.067      0.000      -0.399      -0.353
# idademae_faixa_menor_igual_19         0.9263      0.004    210.190      0.000       0.918       0.935
# escolaridade_mae_Ensino_medio        -0.1172      0.004    -29.977      0.000      -0.125      -0.110
# escolaridade_mae_Fundamental          1.0991      0.004    252.146      0.000       1.091       1.108
# escolaridade_mae_Sem_escolaridade     1.2431      0.018     67.849      0.000       1.207       1.279
# tipo_gravidez_Multipla                1.9540      0.006    317.431      0.000       1.942       1.966
# def_sexo_Masculino                    0.1490      0.003     52.191      0.000       0.143       0.155
# peso_faixa_entre_1500_2499            2.4059      0.003    692.805      0.000       2.399       2.413
# peso_faixa_entre_3500_3999           -0.6817      0.005   -135.437      0.000      -0.692      -0.672
# peso_faixa_entre_500_1499             5.6671      0.014    408.114      0.000       5.640       5.694
# peso_faixa_maior_igual_4000          -0.4298      0.009    -46.756      0.000      -0.448      -0.412
# peso_faixa_menor_500                  2.4654      0.023    107.298      0.000       2.420       2.510
# FLAG_BASE_SIM_DOFET                   1.3415      0.016     85.618      0.000       1.311       1.372
# =====================================================================================================
# ----------------------------------------------------------------
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |    | Var                               |   Odds_ratio |   Odds_Lim_inf |   Odds_Lim_Sup |   p-values |
# +====+===================================+==============+================+================+============+
# |  0 | Intercept                         |        0.06  |          0.059 |          0.06  |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  1 | ANO                               |        1.036 |          1.03  |          1.043 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  2 | evento_REGIAO_Centro-Oeste        |        0.566 |          0.56  |          0.572 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  3 | evento_REGIAO_Nordeste            |        0.415 |          0.412 |          0.419 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  4 | evento_REGIAO_Norte               |        0.468 |          0.463 |          0.474 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  5 | evento_REGIAO_Sul                 |        0.531 |          0.526 |          0.535 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  6 | idademae_faixa_entre_35_39        |        1.061 |          1.052 |          1.07  |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  7 | idademae_faixa_maior_igual_40     |        0.687 |          0.671 |          0.702 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  8 | idademae_faixa_menor_igual_19     |        2.525 |          2.503 |          2.547 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  9 | escolaridade_mae_Ensino_medio     |        0.889 |          0.883 |          0.896 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 10 | escolaridade_mae_Fundamental      |        3.002 |          2.976 |          3.027 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 11 | escolaridade_mae_Sem_escolaridade |        3.466 |          3.344 |          3.593 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 12 | tipo_gravidez_Multipla            |        7.057 |          6.972 |          7.142 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 13 | def_sexo_Masculino                |        1.161 |          1.154 |          1.167 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 14 | peso_faixa_entre_1500_2499        |       11.089 |         11.014 |         11.165 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 15 | peso_faixa_entre_3500_3999        |        0.506 |          0.501 |          0.511 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 16 | peso_faixa_entre_500_1499         |      289.196 |        281.431 |        297.174 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 17 | peso_faixa_maior_igual_4000       |        0.651 |          0.639 |          0.662 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 18 | peso_faixa_menor_500              |       11.768 |         11.25  |         12.31  |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 19 | FLAG_BASE_SIM_DOFET               |        3.825 |          3.709 |          3.944 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+

# %%
with open(f'resultados/modelo_0/{periodo}_modelo_0_PRM.txt', 'w') as f:
    f.write('---------------------------------------------------------------- \n')
    f.write('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES \n')
    f.write('----------------------------------------------------------------\n')
    f.write('N without missing  :' + str(po) +'\n')
    f.write('Treated samples    :' + str([tpo,np.round(100*tpo/po,2)]) + '% \n')
    f.write('Controled samples  :' + str([cpo,np.round(100*cpo/po,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('SELECTED/MATCHET SAMPLES\n')
    f.write('---------------------------------------------------------------- \n')
    f.write('% Selected         :' + str(np.round(100*pa/po,2)) + '% \n')
    f.write('N selected         :' + str(pa) + '\n')
    f.write('Treated selected   :' + str([tpa,np.round(100*tpa/pa,2)]) + '% \n')
    f.write('Controled selected :' + str([cpa,np.round(100*cpa/pa,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('PSW REPORT - ' + periodo+ '\n')
    f.write(str(clf_ano.summary(xname=aux+var_model_2)))
    f.write('\n')
    f.write(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))

# %%
odds_ratio['periodo'] = periodo
odds_ratio.to_csv(f'resultados/modelo_0/{periodo}_modelo_0_PRM.csv', decimal=',', sep=';',index=False)

# %%
fig = sns.kdeplot(df_mod.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="r")
fig = sns.kdeplot(df_mod.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_0/fig1a_{periodo}_modelo_0_PRM.png', format='png', dpi=300)
plt.show()

# %%
fig = sns.kdeplot(psw_base.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="r")
fig = sns.kdeplot(psw_base.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_0/fig1b_{periodo}_modelo_0_PRM.png', format='png', dpi=300)
plt.show()

# %%
#spearm
var_corr = ['PRM'] + var_model_2


plt.figure(figsize=(16, 6))
# define the mask to set the values in the upper triangle to True

mask = np.triu(np.ones_like(psw_base[var_corr].corr(method="spearman"), dtype=np.bool))
heatmap = sns.heatmap(psw_base[var_corr].corr(method='spearman'), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Matrix', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# # Modelo 1

# %%
variaveis_1 = [  
     'ANO'
    , 'PRM'
    , 'evento_REGIAO'
    , 'idademae_faixa'
    , 'escolaridade_mae'
    ,'tipo_gravidez'
    , 'idade_gestacao_faixa'
    , 'def_sexo'
    , 'peso_faixa'
    , 'FLAG_BASE'
    , 'sum_CENTROBS'
    , 'sum_QTINST34'
    , 'sum_QTINST35'
    , 'sum_QTINST36'
    , 'sum_QTINST37'
    , 'sum_QTLEIT34'
    , 'sum_QTLEIT38'
    , 'sum_QTLEIT39'
    , 'sum_QTLEIT40'
    , 'sum_CENTRNEO'
    , 'TP_UNID_5'
    , 'TP_UNID_7'
    , 'TP_UNID_15'
    , 'TP_UNID_36'
    , 'TP_UNID_61'
    ]
df_mod = df[variaveis_1]

# %%
# PRM contagem
NPT = (df_mod['PRM']==1).sum()
NT = (df_mod['PRM']==0).sum()

# %%
# Categorizando as novas variáveis. 
df_mod['cat_CENTROBS'] = [1 if i > 0 else 0 for i in df_mod['sum_CENTROBS']]
df_mod['cat_QTINST34'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST34']]
df_mod['cat_QTINST35'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST35']]
df_mod['cat_QTINST36'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST36']]
df_mod['cat_QTINST37'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST37']]
df_mod['cat_QTLEIT34'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT34']]
df_mod['cat_QTLEIT38'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT38']]
df_mod['cat_QTLEIT39'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT39']]
df_mod['cat_QTLEIT40'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT40']]
df_mod['cat_CENTRNEO'] = [1 if i > 0 else 0 for i in df_mod['sum_CENTRNEO']]
df_mod['cat_TP_UNID_5'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_5']]
df_mod['cat_TP_UNID_7'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_7']]
df_mod['cat_TP_UNID_15'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_15']]
df_mod['cat_TP_UNID_36'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_36']]
df_mod['cat_TP_UNID_61'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_61']]

# %%
df_mod = df_mod.drop(
    columns=[
        'sum_CENTROBS'
        ,'sum_QTINST34'
        ,'sum_QTINST35'
        ,'sum_QTINST36'
        ,'sum_QTINST37'
        ,'sum_QTLEIT34'
        ,'sum_QTLEIT38'
        ,'sum_QTLEIT39'
        ,'sum_QTLEIT40'
        ,'sum_CENTRNEO'
        ,'TP_UNID_5'
        ,'TP_UNID_7'
        ,'TP_UNID_15'
        ,'TP_UNID_36'
        ,'TP_UNID_61'
    ]
)

# %%
df_mod = pd.get_dummies(df_mod)

# %%
df_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10493463 entries, 0 to 10493462
# Data columns (total 47 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   ANO                                int32
#  1   PRM                                int32
#  2   cat_CENTROBS                       int64
#  3   cat_QTINST34                       int64
#  4   cat_QTINST35                       int64
#  5   cat_QTINST36                       int64
#  6   cat_QTINST37                       int64
#  7   cat_QTLEIT34                       int64
#  8   cat_QTLEIT38                       int64
#  9   cat_QTLEIT39                       int64
#  10  cat_QTLEIT40                       int64
#  11  cat_CENTRNEO                       int64
#  12  cat_TP_UNID_5                      int64
#  13  cat_TP_UNID_7                      int64
#  14  cat_TP_UNID_15                     int64
#  15  cat_TP_UNID_36                     int64
#  16  cat_TP_UNID_61                     int64
#  17  evento_REGIAO_Centro-Oeste         uint8
#  18  evento_REGIAO_Nordeste             uint8
#  19  evento_REGIAO_Norte                uint8
#  20  evento_REGIAO_Sudeste              uint8
#  21  evento_REGIAO_Sul                  uint8
#  22  idademae_faixa_entre_20_34         uint8
#  23  idademae_faixa_entre_35_39         uint8
#  24  idademae_faixa_maior_igual_40      uint8
#  25  idademae_faixa_menor_igual_19      uint8
#  26  escolaridade_mae_Ensino_medio      uint8
#  27  escolaridade_mae_Ensino_superior   uint8
#  28  escolaridade_mae_Fundamental       uint8
#  29  escolaridade_mae_Sem_escolaridade  uint8
#  30  tipo_gravidez_Ignorado             uint8
#  31  tipo_gravidez_Multipla             uint8
#  32  tipo_gravidez_Unica                uint8
#  33  idade_gestacao_faixa_entre_22_27   uint8
#  34  idade_gestacao_faixa_entre_28_36   uint8
#  35  idade_gestacao_faixa_entre_37_39   uint8
#  36  idade_gestacao_faixa_entre_40_42   uint8
#  37  def_sexo_Feminino                  uint8
#  38  def_sexo_Masculino                 uint8
#  39  peso_faixa_entre_1500_2499         uint8
#  40  peso_faixa_entre_2500_3500         uint8
#  41  peso_faixa_entre_3500_3999         uint8
#  42  peso_faixa_entre_500_1499          uint8
#  43  peso_faixa_maior_igual_4000        uint8
#  44  peso_faixa_menor_500               uint8
#  45  FLAG_BASE_SIM_DOFET                uint8
#  46  FLAG_BASE_SINASC                   uint8
# dtypes: int32(2), int64(15), uint8(30)
# memory usage: 1.6 GB

# %%
for i in df_mod.columns:
    print(i)
# Out:
# ANO
# PRM
# cat_CENTROBS
# cat_QTINST34
# cat_QTINST35
# cat_QTINST36
# cat_QTINST37
# cat_QTLEIT34
# cat_QTLEIT38
# cat_QTLEIT39
# cat_QTLEIT40
# cat_CENTRNEO
# cat_TP_UNID_5
# cat_TP_UNID_7
# cat_TP_UNID_15
# cat_TP_UNID_36
# cat_TP_UNID_61
# evento_REGIAO_Centro-Oeste
# evento_REGIAO_Nordeste
# evento_REGIAO_Norte
# evento_REGIAO_Sudeste
# evento_REGIAO_Sul
# idademae_faixa_entre_20_34
# idademae_faixa_entre_35_39
# idademae_faixa_maior_igual_40
# idademae_faixa_menor_igual_19
# escolaridade_mae_Ensino_medio
# escolaridade_mae_Ensino_superior
# escolaridade_mae_Fundamental
# escolaridade_mae_Sem_escolaridade
# tipo_gravidez_Ignorado
# tipo_gravidez_Multipla
# tipo_gravidez_Unica
# idade_gestacao_faixa_entre_22_27
# idade_gestacao_faixa_entre_28_36
# idade_gestacao_faixa_entre_37_39
# idade_gestacao_faixa_entre_40_42
# def_sexo_Feminino
# def_sexo_Masculino
# peso_faixa_entre_1500_2499
# peso_faixa_entre_2500_3500
# peso_faixa_entre_3500_3999
# peso_faixa_entre_500_1499
# peso_faixa_maior_igual_4000
# peso_faixa_menor_500
# FLAG_BASE_SIM_DOFET
# FLAG_BASE_SINASC

# %%
# Modelo
#Defining covariates
var_model=[
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    , 'idade_gestacao_faixa_entre_22_27'
    , 'idade_gestacao_faixa_entre_28_36'
    #, 'idade_gestacao_faixa_entre_37_39'
    , 'idade_gestacao_faixa_entre_40_42'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    , 'FLAG_BASE_SIM_DOFET'
    #, 'FLAG_BASE_SINASC'
    #,'cat_CENTROBS'
    #, 'cat_QTINST34'
    #,'cat_QTINST35'
    #,'cat_QTINST36'
    #, 'cat_QTINST37'
    #, 'cat_QTLEIT34'
    #, 'cat_QTLEIT38'
    #, 'cat_QTLEIT39'
    #, 'cat_QTLEIT40'
    #, 'cat_CENTRNEO'
    #, 'cat_TP_UNID_5'
    #, 'cat_TP_UNID_7'
    , 'cat_TP_UNID_15'
    , 'cat_TP_UNID_36'
]

X = df_mod[var_model].values

## FIRST REGRESSION
y = df_mod[['ANO']].values
clf = LogisticRegression(random_state=0, max_iter=2000).fit(X, y)
df_mod = df_mod.assign(PROPENSITY_SCORE=clf.predict_proba(X)[:, 1])

#USING PROPENSITY SCORE TO SELECT SAMPLES TO SECOND REGRESSION
psw_base=df_mod[((df_mod['PROPENSITY_SCORE']>df_mod['PROPENSITY_SCORE'].quantile(0.1)) &
                 (df_mod['PROPENSITY_SCORE']<df_mod['PROPENSITY_SCORE'].quantile(0.9)))]

#COUNTING
po=len(df_mod)
tpo=len(df_mod[df_mod['ANO']==1])
cpo=len(df_mod[df_mod['ANO']==0])
pa=len(psw_base)
tpa=len(psw_base[psw_base['ANO']==1])
cpa=len(psw_base[psw_base['ANO']==0])

print('----------------------------------------------------------------')
print('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES')
print('----------------------------------------------------------------')
print('N without missing  :', po)
print('Treated samples    :', tpo,np.round(100*tpo/po,2),'%')
print('Controled samples  :', cpo,np.round(100*cpo/po,2),'%')
print('----------------------------------------------------------------')
print('SELECTED/MATCHET SAMPLES')
print('----------------------------------------------------------------')
print('% Selected         :', np.round(100*pa/po,2),'%')
print('N selected         :', pa)
print('Treated selected   :', tpa,np.round(100*tpa/pa,2),'%')
print('Controled selected :', cpa,np.round(100*cpa/pa,2),'%')
print('----------------------------------------------------------------')
print('')

#PSW weights
w =psw_base['ANO']/psw_base['PROPENSITY_SCORE'] + ((1-psw_base['ANO'])/(1-psw_base['PROPENSITY_SCORE']))
# Out:
# ----------------------------------------------------------------
# USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES
# ----------------------------------------------------------------
# N without missing  : 10493463
# Treated samples    : 7737859 73.74 %
# Controled samples  : 2755604 26.26 %
# ----------------------------------------------------------------
# SELECTED/MATCHET SAMPLES
# ----------------------------------------------------------------
# % Selected         : 79.75 %
# N selected         : 8368118
# Treated selected   : 6179548 73.85 %
# Controled selected : 2188570 26.15 %
# ----------------------------------------------------------------

# %%
## SECOND REGRESSION
aux=['ANO']
var_model_2 = [
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    #, 'idade_gestacao_faixa_entre_22_27'
    #, 'idade_gestacao_faixa_entre_28_36'
    #, 'idade_gestacao_faixa_entre_37_39'
    #, 'idade_gestacao_faixa_entre_40_42'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    , 'FLAG_BASE_SIM_DOFET'
    #, 'FLAG_BASE_SINASC'
    #,'cat_CENTROBS'
    #,'cat_QTINST34'
    # 'cat_QTINST35'
    #,'cat_QTINST36'
    #, 'cat_QTINST37'
    #, 'cat_QTLEIT34'
    #, 'cat_QTLEIT38'
    #, 'cat_QTLEIT39'
    #, 'cat_QTLEIT40'
    #, 'cat_CENTRNEO'
    #, 'cat_TP_UNID_5'
    #, 'cat_TP_UNID_7'
    , 'cat_TP_UNID_15'
    , 'cat_TP_UNID_36'
]

X = psw_base[aux+var_model_2].values
y = psw_base[['PRM']].values

X_ANO = sm.add_constant(X)
clf_ano = sm.Logit(y, X_ANO,weights=w).fit()
aux=['Intercept','ANO']

print('----------------------------------------------------------------')
print('PSW REPORT',periodo)
print('----------------------------------------------------------------')
print(clf_ano.summary(xname=aux+var_model_2))
print('----------------------------------------------------------------')


IC=np.exp(clf_ano.conf_int(0.05))
odds_ratio=pd.DataFrame(
    data = {
        'Var':aux+var_model_2
        , 'Odds_ratio': np.round(np.exp(clf_ano.params),3)
        , 'Odds_Lim_inf': np.round(IC[:,0],3)
        , 'Odds_Lim_Sup': np.round(IC[:,1],3)
        , 'p-values':np.round(clf_ano.pvalues,3)
    }
)
print(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.260826
#          Iterations 7
# ----------------------------------------------------------------
# PSW REPORT 2019-2020-2021-2022
# ----------------------------------------------------------------
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:              8368118
# Model:                          Logit   Df Residuals:                  8368096
# Method:                           MLE   Df Model:                           21
# Date:                Wed, 03 Jul 2024   Pseudo R-squ.:                  0.2800
# Time:                        01:00:19   Log-Likelihood:            -2.1826e+06
# converged:                       True   LL-Null:                   -3.0316e+06
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -2.4784      0.006   -387.634      0.000      -2.491      -2.466
# ANO                                   0.0314      0.003     10.666      0.000       0.026       0.037
# evento_REGIAO_Centro-Oeste            0.0242      0.005      5.087      0.000       0.015       0.034
# evento_REGIAO_Nordeste                0.0850      0.003     25.375      0.000       0.078       0.092
# evento_REGIAO_Norte                  -0.2771      0.005    -58.498      0.000      -0.286      -0.268
# evento_REGIAO_Sul                     0.0241      0.004      6.045      0.000       0.016       0.032
# idademae_faixa_entre_35_39            0.1977      0.004     53.541      0.000       0.190       0.205
# idademae_faixa_maior_igual_40        -0.3008      0.009    -34.526      0.000      -0.318      -0.284
# idademae_faixa_menor_igual_19         0.4621      0.004    112.459      0.000       0.454       0.470
# escolaridade_mae_Ensino_medio        -0.0676      0.003    -19.794      0.000      -0.074      -0.061
# escolaridade_mae_Fundamental          0.6259      0.004    157.548      0.000       0.618       0.634
# escolaridade_mae_Sem_escolaridade     0.7102      0.019     38.179      0.000       0.674       0.747
# tipo_gravidez_Multipla                1.4937      0.006    243.133      0.000       1.482       1.506
# def_sexo_Masculino                    0.2449      0.003     94.004      0.000       0.240       0.250
# peso_faixa_entre_1500_2499            2.5211      0.003    800.687      0.000       2.515       2.527
# peso_faixa_entre_3500_3999           -0.8703      0.005   -190.231      0.000      -0.879      -0.861
# peso_faixa_entre_500_1499             5.3041      0.014    389.513      0.000       5.277       5.331
# peso_faixa_maior_igual_4000          -0.8379      0.009    -93.184      0.000      -0.856      -0.820
# peso_faixa_menor_500                  2.5334      0.019    130.148      0.000       2.495       2.572
# FLAG_BASE_SIM_DOFET                   1.4867      0.013    111.694      0.000       1.461       1.513
# cat_TP_UNID_15                       -0.8251      0.005   -156.061      0.000      -0.835      -0.815
# cat_TP_UNID_36                       -0.3154      0.005    -65.531      0.000      -0.325      -0.306
# =====================================================================================================
# ----------------------------------------------------------------
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |    | Var                               |   Odds_ratio |   Odds_Lim_inf |   Odds_Lim_Sup |   p-values |
# +====+===================================+==============+================+================+============+
# |  0 | Intercept                         |        0.084 |          0.083 |          0.085 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  1 | ANO                               |        1.032 |          1.026 |          1.038 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  2 | evento_REGIAO_Centro-Oeste        |        1.024 |          1.015 |          1.034 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  3 | evento_REGIAO_Nordeste            |        1.089 |          1.082 |          1.096 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  4 | evento_REGIAO_Norte               |        0.758 |          0.751 |          0.765 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  5 | evento_REGIAO_Sul                 |        1.024 |          1.016 |          1.032 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  6 | idademae_faixa_entre_35_39        |        1.219 |          1.21  |          1.227 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  7 | idademae_faixa_maior_igual_40     |        0.74  |          0.728 |          0.753 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  8 | idademae_faixa_menor_igual_19     |        1.587 |          1.575 |          1.6   |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  9 | escolaridade_mae_Ensino_medio     |        0.935 |          0.928 |          0.941 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 10 | escolaridade_mae_Fundamental      |        1.87  |          1.855 |          1.885 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 11 | escolaridade_mae_Sem_escolaridade |        2.034 |          1.962 |          2.11  |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 12 | tipo_gravidez_Multipla            |        4.453 |          4.4   |          4.507 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 13 | def_sexo_Masculino                |        1.277 |          1.271 |          1.284 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 14 | peso_faixa_entre_1500_2499        |       12.442 |         12.366 |         12.519 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 15 | peso_faixa_entre_3500_3999        |        0.419 |          0.415 |          0.423 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 16 | peso_faixa_entre_500_1499         |      201.153 |        195.856 |        206.594 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 17 | peso_faixa_maior_igual_4000       |        0.433 |          0.425 |          0.44  |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 18 | peso_faixa_menor_500              |       12.596 |         12.124 |         13.086 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 19 | FLAG_BASE_SIM_DOFET               |        4.422 |          4.309 |          4.539 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 20 | cat_TP_UNID_15                    |        0.438 |          0.434 |          0.443 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 21 | cat_TP_UNID_36                    |        0.73  |          0.723 |          0.736 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+

# %%
with open(f'resultados/modelo_1/{periodo}_modelo_1_PRM.txt', 'w') as f:
    f.write('---------------------------------------------------------------- \n')
    f.write('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES \n')
    f.write('----------------------------------------------------------------\n')
    f.write('N without missing  :' + str(po) +'\n')
    f.write('Treated samples    :' + str([tpo,np.round(100*tpo/po,2)]) + '% \n')
    f.write('Controled samples  :' + str([cpo,np.round(100*cpo/po,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('SELECTED/MATCHET SAMPLES\n')
    f.write('---------------------------------------------------------------- \n')
    f.write('% Selected         :' + str(np.round(100*pa/po,2)) + '% \n')
    f.write('N selected         :' + str(pa) + '\n')
    f.write('Treated selected   :' + str([tpa,np.round(100*tpa/pa,2)]) + '% \n')
    f.write('Controled selected :' + str([cpa,np.round(100*cpa/pa,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('PSW REPORT - ' + periodo+ '\n')
    f.write(str(clf_ano.summary(xname=aux+var_model_2)))
    f.write('\n')
    f.write(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))

# %%
odds_ratio['periodo'] = periodo
odds_ratio.to_csv(f'resultados/modelo_1/{periodo}_modelo_1_PRM.csv', decimal=',', sep=';', index=False)

# %%
fig = sns.kdeplot(df_mod.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="r")
fig = sns.kdeplot(df_mod.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_1/fig1a_{periodo}_modelo_1_PRM.png', format='png', dpi=300)
plt.show()

# %%
fig = sns.kdeplot(psw_base.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="r")
fig = sns.kdeplot(psw_base.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_1/fig1b_{periodo}_modelo_1_PRM.png', format='png', dpi=300)
plt.show()

# %%
#spearm
var_corr = ['PRM'] + var_model_2

plt.figure(figsize=(16, 6))
# define the mask to set the values in the upper triangle to True

mask = np.triu(np.ones_like(psw_base[var_corr].corr(method="spearman"), dtype=np.bool))
heatmap = sns.heatmap(psw_base[var_corr].corr(method='spearman'), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Matrix', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# # Modelo 2

# %%
variaveis_1 = [  
     'ANO'
    , 'PRM'
    , 'evento_REGIAO'
    , 'idademae_faixa'
    , 'escolaridade_mae'
    , 'tipo_gravidez'
    , 'idade_gestacao_faixa'
    , 'def_sexo'
    , 'peso_faixa'
    , 'FLAG_BASE'
    , 'sum_CENTROBS'
    , 'sum_QTINST34'
    , 'sum_QTINST35'
    , 'sum_QTINST36'
    , 'sum_QTINST37'
    , 'sum_QTLEIT34'
    , 'sum_QTLEIT38'
    , 'sum_QTLEIT39'
    , 'sum_QTLEIT40'
    , 'sum_CENTRNEO'
    , 'TP_UNID_5'
    , 'TP_UNID_7'
    , 'TP_UNID_15'
    , 'TP_UNID_36'
    , 'TP_UNID_61'
    ]
df_mod = df[variaveis_1]

# %%
# Categorizando as novas variáveis. 
df_mod['cat_CENTROBS'] = [1 if i > 0 else 0 for i in df_mod['sum_CENTROBS']]
df_mod['cat_QTINST34'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST34']]
df_mod['cat_QTINST35'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST35']]
df_mod['cat_QTINST36'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST36']]
df_mod['cat_QTINST37'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST37']]
df_mod['cat_QTLEIT34'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT34']]
df_mod['cat_QTLEIT38'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT38']]
df_mod['cat_QTLEIT39'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT39']]
df_mod['cat_QTLEIT40'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT40']]
df_mod['cat_CENTRNEO'] = [1 if i > 0 else 0 for i in df_mod['sum_CENTRNEO']]
df_mod['cat_TP_UNID_5'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_5']]
df_mod['cat_TP_UNID_7'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_7']]
df_mod['cat_TP_UNID_15'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_15']]
df_mod['cat_TP_UNID_36'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_36']]
df_mod['cat_TP_UNID_61'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_61']]

# %%
df_mod = df_mod.drop(
    columns=[
        'sum_CENTROBS'
        ,'sum_QTINST34'
        ,'sum_QTINST35'
        ,'sum_QTINST36'
        ,'sum_QTINST37'
        ,'sum_QTLEIT34'
        ,'sum_QTLEIT38'
        ,'sum_QTLEIT39'
        ,'sum_QTLEIT40'
        ,'sum_CENTRNEO'
        ,'TP_UNID_5'
        ,'TP_UNID_7'
        ,'TP_UNID_15'
        ,'TP_UNID_36'
        ,'TP_UNID_61'
    ]
)

# %%
df_mod = pd.get_dummies(df_mod)

# %%
# OBITO contagem
NPT = (df_mod['FLAG_BASE_SIM_DOFET']==1).sum()
NT = (df_mod['FLAG_BASE_SIM_DOFET']==0).sum()

# %%
df_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10493463 entries, 0 to 10493462
# Data columns (total 47 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   ANO                                int32
#  1   PRM                                int32
#  2   cat_CENTROBS                       int64
#  3   cat_QTINST34                       int64
#  4   cat_QTINST35                       int64
#  5   cat_QTINST36                       int64
#  6   cat_QTINST37                       int64
#  7   cat_QTLEIT34                       int64
#  8   cat_QTLEIT38                       int64
#  9   cat_QTLEIT39                       int64
#  10  cat_QTLEIT40                       int64
#  11  cat_CENTRNEO                       int64
#  12  cat_TP_UNID_5                      int64
#  13  cat_TP_UNID_7                      int64
#  14  cat_TP_UNID_15                     int64
#  15  cat_TP_UNID_36                     int64
#  16  cat_TP_UNID_61                     int64
#  17  evento_REGIAO_Centro-Oeste         uint8
#  18  evento_REGIAO_Nordeste             uint8
#  19  evento_REGIAO_Norte                uint8
#  20  evento_REGIAO_Sudeste              uint8
#  21  evento_REGIAO_Sul                  uint8
#  22  idademae_faixa_entre_20_34         uint8
#  23  idademae_faixa_entre_35_39         uint8
#  24  idademae_faixa_maior_igual_40      uint8
#  25  idademae_faixa_menor_igual_19      uint8
#  26  escolaridade_mae_Ensino_medio      uint8
#  27  escolaridade_mae_Ensino_superior   uint8
#  28  escolaridade_mae_Fundamental       uint8
#  29  escolaridade_mae_Sem_escolaridade  uint8
#  30  tipo_gravidez_Ignorado             uint8
#  31  tipo_gravidez_Multipla             uint8
#  32  tipo_gravidez_Unica                uint8
#  33  idade_gestacao_faixa_entre_22_27   uint8
#  34  idade_gestacao_faixa_entre_28_36   uint8
#  35  idade_gestacao_faixa_entre_37_39   uint8
#  36  idade_gestacao_faixa_entre_40_42   uint8
#  37  def_sexo_Feminino                  uint8
#  38  def_sexo_Masculino                 uint8
#  39  peso_faixa_entre_1500_2499         uint8
#  40  peso_faixa_entre_2500_3500         uint8
#  41  peso_faixa_entre_3500_3999         uint8
#  42  peso_faixa_entre_500_1499          uint8
#  43  peso_faixa_maior_igual_4000        uint8
#  44  peso_faixa_menor_500               uint8
#  45  FLAG_BASE_SIM_DOFET                uint8
#  46  FLAG_BASE_SINASC                   uint8
# dtypes: int32(2), int64(15), uint8(30)
# memory usage: 1.6 GB

# %%
for i in df_mod.columns:
    print(i)
# Out:
# ANO
# PRM
# cat_CENTROBS
# cat_QTINST34
# cat_QTINST35
# cat_QTINST36
# cat_QTINST37
# cat_QTLEIT34
# cat_QTLEIT38
# cat_QTLEIT39
# cat_QTLEIT40
# cat_CENTRNEO
# cat_TP_UNID_5
# cat_TP_UNID_7
# cat_TP_UNID_15
# cat_TP_UNID_36
# cat_TP_UNID_61
# evento_REGIAO_Centro-Oeste
# evento_REGIAO_Nordeste
# evento_REGIAO_Norte
# evento_REGIAO_Sudeste
# evento_REGIAO_Sul
# idademae_faixa_entre_20_34
# idademae_faixa_entre_35_39
# idademae_faixa_maior_igual_40
# idademae_faixa_menor_igual_19
# escolaridade_mae_Ensino_medio
# escolaridade_mae_Ensino_superior
# escolaridade_mae_Fundamental
# escolaridade_mae_Sem_escolaridade
# tipo_gravidez_Ignorado
# tipo_gravidez_Multipla
# tipo_gravidez_Unica
# idade_gestacao_faixa_entre_22_27
# idade_gestacao_faixa_entre_28_36
# idade_gestacao_faixa_entre_37_39
# idade_gestacao_faixa_entre_40_42
# def_sexo_Feminino
# def_sexo_Masculino
# peso_faixa_entre_1500_2499
# peso_faixa_entre_2500_3500
# peso_faixa_entre_3500_3999
# peso_faixa_entre_500_1499
# peso_faixa_maior_igual_4000
# peso_faixa_menor_500
# FLAG_BASE_SIM_DOFET
# FLAG_BASE_SINASC

# %%
# Modelo
#Defining covariates
var_model=[
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    , 'PRM'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    #,'cat_CENTROBS'
    #, 'cat_QTINST34'
    #,'cat_QTINST35'
    #,'cat_QTINST36'
    #, 'cat_QTINST37'
    #, 'cat_QTLEIT34'
    #, 'cat_QTLEIT38'
    #, 'cat_QTLEIT39'
    #, 'cat_QTLEIT40'
    #, 'cat_CENTRNEO'
    #, 'cat_TP_UNID_5'
    #, 'cat_TP_UNID_7'
    #, 'cat_TP_UNID_15'
    #, 'cat_TP_UNID_36'
]

X = df_mod[var_model].values

## FIRST REGRESSION
y = df_mod[['ANO']].values
clf = LogisticRegression(random_state=0, max_iter=2000).fit(X, y)
df_mod = df_mod.assign(PROPENSITY_SCORE=clf.predict_proba(X)[:, 1])

#USING PROPENSITY SCORE TO SELECT SAMPLES TO SECOND REGRESSION
psw_base=df_mod[((df_mod['PROPENSITY_SCORE']>df_mod['PROPENSITY_SCORE'].quantile(0.1)) &
                 (df_mod['PROPENSITY_SCORE']<df_mod['PROPENSITY_SCORE'].quantile(0.9)))]

#COUNTING
po=len(df_mod)
tpo=len(df_mod[df_mod['ANO']==1])
cpo=len(df_mod[df_mod['ANO']==0])
pa=len(psw_base)
tpa=len(psw_base[psw_base['ANO']==1])
cpa=len(psw_base[psw_base['ANO']==0])

print('----------------------------------------------------------------')
print('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES')
print('----------------------------------------------------------------')
print('N without missing  :', po)
print('Treated samples    :', tpo,np.round(100*tpo/po,2),'%')
print('Controled samples  :', cpo,np.round(100*cpo/po,2),'%')
print('----------------------------------------------------------------')
print('SELECTED/MATCHET SAMPLES')
print('----------------------------------------------------------------')
print('% Selected         :', np.round(100*pa/po,2),'%')
print('N selected         :', pa)
print('Treated selected   :', tpa,np.round(100*tpa/pa,2),'%')
print('Controled selected :', cpa,np.round(100*cpa/pa,2),'%')
print('----------------------------------------------------------------')
print('')

#PSW weights
w =psw_base['ANO']/psw_base['PROPENSITY_SCORE'] + ((1-psw_base['ANO'])/(1-psw_base['PROPENSITY_SCORE']))
# Out:
# ----------------------------------------------------------------
# USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES
# ----------------------------------------------------------------
# N without missing  : 10493463
# Treated samples    : 7737859 73.74 %
# Controled samples  : 2755604 26.26 %
# ----------------------------------------------------------------
# SELECTED/MATCHET SAMPLES
# ----------------------------------------------------------------
# % Selected         : 79.9 %
# N selected         : 8384227
# Treated selected   : 6194683 73.88 %
# Controled selected : 2189544 26.12 %
# ----------------------------------------------------------------

# %%
## SECOND REGRESSION
aux=['ANO']
var_model_2 = [
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    , 'PRM'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    #,'cat_CENTROBS'
    #, 'cat_QTINST34'
    #,'cat_QTINST35'
    #,'cat_QTINST36'
    #, 'cat_QTINST37'
    #, 'cat_QTLEIT34'
    #, 'cat_QTLEIT38'
    #, 'cat_QTLEIT39'
    #, 'cat_QTLEIT40'
    #, 'cat_CENTRNEO'
    #, 'cat_TP_UNID_5'
    #, 'cat_TP_UNID_7'
    #, 'cat_TP_UNID_15'
    #, 'cat_TP_UNID_36'
]

X = psw_base[aux+var_model_2].values
y = psw_base[['FLAG_BASE_SIM_DOFET']].values

X_ANO = sm.add_constant(X)
clf_ano = sm.Logit(y, X_ANO,weights=w).fit()
aux=['Intercept','ANO']

print('----------------------------------------------------------------')
print('PSW REPORT',periodo)
print('----------------------------------------------------------------')
print(clf_ano.summary(xname=aux+var_model_2))
print('----------------------------------------------------------------')


IC=np.exp(clf_ano.conf_int(0.05))
odds_ratio=pd.DataFrame(
    data = {
        'Var':aux+var_model_2
        , 'Odds_ratio': np.round(np.exp(clf_ano.params),3)
        , 'Odds_Lim_inf': np.round(IC[:,0],3)
        , 'Odds_Lim_Sup': np.round(IC[:,1],3)
        , 'p-values':np.round(clf_ano.pvalues,3)
    }
)
print(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))
# Out:
# Optimization terminated successfully.
#          Current function value: inf
#          Iterations 11
# ----------------------------------------------------------------
# PSW REPORT 2019-2020-2021-2022
# ----------------------------------------------------------------
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:              8384227
# Model:                          Logit   Df Residuals:                  8384207
# Method:                           MLE   Df Model:                           19
# Date:                Wed, 03 Jul 2024   Pseudo R-squ.:                     inf
# Time:                        01:08:09   Log-Likelihood:                   -inf
# converged:                       True   LL-Null:                        0.0000
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -6.9917      0.019   -361.081      0.000      -7.030      -6.954
# ANO                                   0.0117      0.011      1.093      0.275      -0.009       0.033
# evento_REGIAO_Centro-Oeste            0.1820      0.018     10.112      0.000       0.147       0.217
# evento_REGIAO_Nordeste                0.3521      0.013     27.625      0.000       0.327       0.377
# evento_REGIAO_Norte                   0.3122      0.019     16.190      0.000       0.274       0.350
# evento_REGIAO_Sul                    -0.1344      0.016     -8.177      0.000      -0.167      -0.102
# idademae_faixa_entre_35_39            0.0966      0.014      7.087      0.000       0.070       0.123
# idademae_faixa_maior_igual_40         0.2971      0.030      9.819      0.000       0.238       0.356
# idademae_faixa_menor_igual_19        -0.1608      0.015    -10.480      0.000      -0.191      -0.131
# escolaridade_mae_Ensino_medio         0.3209      0.015     21.707      0.000       0.292       0.350
# escolaridade_mae_Fundamental          0.8378      0.016     52.895      0.000       0.807       0.869
# escolaridade_mae_Sem_escolaridade     2.2409      0.033     67.306      0.000       2.176       2.306
# tipo_gravidez_Multipla               -1.0130      0.020    -51.658      0.000      -1.051      -0.975
# PRM                                   1.5098      0.014    104.928      0.000       1.482       1.538
# def_sexo_Masculino                    0.1197      0.009     12.704      0.000       0.101       0.138
# peso_faixa_entre_1500_2499            1.6981      0.015    111.311      0.000       1.668       1.728
# peso_faixa_entre_3500_3999           -0.4334      0.023    -19.170      0.000      -0.478      -0.389
# peso_faixa_entre_500_1499             3.5532      0.016    219.983      0.000       3.522       3.585
# peso_faixa_maior_igual_4000           0.6071      0.028     21.328      0.000       0.551       0.663
# peso_faixa_menor_500                  4.3837      0.031    139.298      0.000       4.322       4.445
# =====================================================================================================
# ----------------------------------------------------------------
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |    | Var                               |   Odds_ratio |   Odds_Lim_inf |   Odds_Lim_Sup |   p-values |
# +====+===================================+==============+================+================+============+
# |  0 | Intercept                         |        0.001 |          0.001 |          0.001 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  1 | ANO                               |        1.012 |          0.991 |          1.033 |      0.275 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  2 | evento_REGIAO_Centro-Oeste        |        1.2   |          1.158 |          1.243 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  3 | evento_REGIAO_Nordeste            |        1.422 |          1.387 |          1.458 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  4 | evento_REGIAO_Norte               |        1.366 |          1.316 |          1.419 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  5 | evento_REGIAO_Sul                 |        0.874 |          0.847 |          0.903 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  6 | idademae_faixa_entre_35_39        |        1.101 |          1.072 |          1.131 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  7 | idademae_faixa_maior_igual_40     |        1.346 |          1.268 |          1.428 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  8 | idademae_faixa_menor_igual_19     |        0.851 |          0.826 |          0.877 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  9 | escolaridade_mae_Ensino_medio     |        1.378 |          1.339 |          1.419 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 10 | escolaridade_mae_Fundamental      |        2.311 |          2.241 |          2.384 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 11 | escolaridade_mae_Sem_escolaridade |        9.402 |          8.808 |         10.036 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 12 | tipo_gravidez_Multipla            |        0.363 |          0.349 |          0.377 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 13 | PRM                               |        4.526 |          4.4   |          4.655 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 14 | def_sexo_Masculino                |        1.127 |          1.107 |          1.148 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 15 | peso_faixa_entre_1500_2499        |        5.464 |          5.303 |          5.63  |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 16 | peso_faixa_entre_3500_3999        |        0.648 |          0.62  |          0.678 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 17 | peso_faixa_entre_500_1499         |       34.925 |         33.837 |         36.048 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 18 | peso_faixa_maior_igual_4000       |        1.835 |          1.736 |          1.94  |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 19 | peso_faixa_menor_500              |       80.134 |         75.34  |         85.232 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+

# %%
with open(f'resultados/modelo_2/{periodo}_modelo_2_OBITO.txt', 'w') as f:
    f.write('---------------------------------------------------------------- \n')
    f.write('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES \n')
    f.write('----------------------------------------------------------------\n')
    f.write('N without missing  :' + str(po) +'\n')
    f.write('Treated samples    :' + str([tpo,np.round(100*tpo/po,2)]) + '% \n')
    f.write('Controled samples  :' + str([cpo,np.round(100*cpo/po,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('SELECTED/MATCHET SAMPLES\n')
    f.write('---------------------------------------------------------------- \n')
    f.write('% Selected         :' + str(np.round(100*pa/po,2)) + '% \n')
    f.write('N selected         :' + str(pa) + '\n')
    f.write('Treated selected   :' + str([tpa,np.round(100*tpa/pa,2)]) + '% \n')
    f.write('Controled selected :' + str([cpa,np.round(100*cpa/pa,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('PSW REPORT - ' + periodo+ '\n')
    f.write(str(clf_ano.summary(xname=aux+var_model_2)))
    f.write('\n')
    f.write(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))

# %%
odds_ratio['periodo'] = periodo
odds_ratio.to_csv(f'resultados/modelo_2/{periodo}_modelo_2_OBITO.csv', decimal=',', sep=';', index=False)

# %%
fig = sns.kdeplot(df_mod.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="r")
fig = sns.kdeplot(df_mod.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_2/fig1a_{periodo}_modelo_2_OBITO.png', format='png', dpi=300)
plt.show()

# %%
fig = sns.kdeplot(psw_base.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="r")
fig = sns.kdeplot(psw_base.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_2/fig1b_{periodo}_modelo_2_OBITO.png', format='png', dpi=300)
plt.show()

# %%
#spearm
var_corr = ['FLAG_BASE_SIM_DOFET'] + var_model_2

plt.figure(figsize=(16, 6))
# define the mask to set the values in the upper triangle to True

mask = np.triu(np.ones_like(psw_base[var_corr].corr(method="spearman"), dtype=np.bool))
heatmap = sns.heatmap(psw_base[var_corr].corr(method='spearman'), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Matrix', fontdict={'fontsize':18}, pad=16);

# %%
#Importing Modules
from Funcoes_auxiliares.func_aux import *
import pandas as pd
import numpy as np
from scipy.stats import chi2
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
#plt.style.use("ggplot")
#from google.colab import drive
from pandas.testing import assert_frame_equal
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from tabulate import tabulate
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('base_limpa/base_unificada_limpa.csv')
periodo='2019-2020-2021'
df = df.loc[df['ano_evento'].isin([2019, 2020, 2021])]
df['ANO'] = np.where(df['ano_evento']==2019, 0, 1)
# Variável PRM
df['PRM'] = np.where(df['idade_gestacao_faixa'].isin(['entre_37_39', 'entre_40_42']), 0, 1)

# %% [markdown]
# # Modelo zero

# %%
variaveis =  [  
     'ANO'
    , 'PRM'
    , 'evento_REGIAO'
    , 'idademae_faixa'
    , 'escolaridade_mae'
    ,'tipo_gravidez'
    , 'idade_gestacao_faixa'
    , 'def_sexo'
    , 'peso_faixa'
    , 'FLAG_BASE'
]

df_mod = df[variaveis]

# %%
# PRM contagem
NPT = (df_mod['PRM']==1).sum()
NT = (df_mod['PRM']==0).sum()

# %%
df_mod = pd.get_dummies(df_mod)

# %%
df_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7992615 entries, 0 to 10452700
# Data columns (total 31 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   ANO                                int32
#  1   PRM                                int32
#  2   evento_REGIAO_Centro-Oeste         uint8
#  3   evento_REGIAO_Nordeste             uint8
#  4   evento_REGIAO_Norte                uint8
#  5   evento_REGIAO_Sudeste              uint8
#  6   evento_REGIAO_Sul                  uint8
#  7   idademae_faixa_entre_20_34         uint8
#  8   idademae_faixa_entre_35_39         uint8
#  9   idademae_faixa_maior_igual_40      uint8
#  10  idademae_faixa_menor_igual_19      uint8
#  11  escolaridade_mae_Ensino_medio      uint8
#  12  escolaridade_mae_Ensino_superior   uint8
#  13  escolaridade_mae_Fundamental       uint8
#  14  escolaridade_mae_Sem_escolaridade  uint8
#  15  tipo_gravidez_Multipla             uint8
#  16  tipo_gravidez_Unica                uint8
#  17  idade_gestacao_faixa_entre_22_27   uint8
#  18  idade_gestacao_faixa_entre_28_36   uint8
#  19  idade_gestacao_faixa_entre_37_39   uint8
#  20  idade_gestacao_faixa_entre_40_42   uint8
#  21  def_sexo_Feminino                  uint8
#  22  def_sexo_Masculino                 uint8
#  23  peso_faixa_entre_1500_2499         uint8
#  24  peso_faixa_entre_2500_3500         uint8
#  25  peso_faixa_entre_3500_3999         uint8
#  26  peso_faixa_entre_500_1499          uint8
#  27  peso_faixa_maior_igual_4000        uint8
#  28  peso_faixa_menor_500               uint8
#  29  FLAG_BASE_SIM_DOFET                uint8
#  30  FLAG_BASE_SINASC                   uint8
# dtypes: int32(2), uint8(29)
# memory usage: 343.0 MB

# %%
df_mod.columns
# Out:
# Index(['ANO', 'PRM', 'evento_REGIAO_Centro-Oeste', 'evento_REGIAO_Nordeste',
#        'evento_REGIAO_Norte', 'evento_REGIAO_Sudeste', 'evento_REGIAO_Sul',
#        'idademae_faixa_entre_20_34', 'idademae_faixa_entre_35_39',
#        'idademae_faixa_maior_igual_40', 'idademae_faixa_menor_igual_19',
#        'escolaridade_mae_Ensino_medio', 'escolaridade_mae_Ensino_superior',
#        'escolaridade_mae_Fundamental', 'escolaridade_mae_Sem_escolaridade',
#        'tipo_gravidez_Multipla', 'tipo_gravidez_Unica',
#        'idade_gestacao_faixa_entre_22_27', 'idade_gestacao_faixa_entre_28_36',
#        'idade_gestacao_faixa_entre_37_39', 'idade_gestacao_faixa_entre_40_42',
#        'def_sexo_Feminino', 'def_sexo_Masculino', 'peso_faixa_entre_1500_2499',
#        'peso_faixa_entre_2500_3500', 'peso_faixa_entre_3500_3999',
#        'peso_faixa_entre_500_1499', 'peso_faixa_maior_igual_4000',
#        'peso_faixa_menor_500', 'FLAG_BASE_SIM_DOFET', 'FLAG_BASE_SINASC'],
#       dtype='object')

# %%
# Modelo
#Defining covariates
var_model=[
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    , 'idade_gestacao_faixa_entre_22_27'
    , 'idade_gestacao_faixa_entre_28_36'
    #, 'idade_gestacao_faixa_entre_37_39'
    , 'idade_gestacao_faixa_entre_40_42'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    , 'FLAG_BASE_SIM_DOFET'
    #, 'FLAG_BASE_SINASC'
]

X = df_mod[var_model].values

## FIRST REGRESSION
y = df_mod[['ANO']].values
clf = LogisticRegression(random_state=0, max_iter=2000).fit(X, y)
df_mod = df_mod.assign(PROPENSITY_SCORE=clf.predict_proba(X)[:, 1])

#USING PROPENSITY SCORE TO SELECT SAMPLES TO SECOND REGRESSION
psw_base=df_mod[((df_mod['PROPENSITY_SCORE']>df_mod['PROPENSITY_SCORE'].quantile(0.1)) &
                 (df_mod['PROPENSITY_SCORE']<df_mod['PROPENSITY_SCORE'].quantile(0.9)))]

#COUNTING
po=len(df_mod)
tpo=len(df_mod[df_mod['ANO']==1])
cpo=len(df_mod[df_mod['ANO']==0])
pa=len(psw_base)
tpa=len(psw_base[psw_base['ANO']==1])
cpa=len(psw_base[psw_base['ANO']==0])

print('----------------------------------------------------------------')
print('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES')
print('----------------------------------------------------------------')
print('N without missing  :', po)
print('Treated samples    :', tpo,np.round(100*tpo/po,2),'%')
print('Controled samples  :', cpo,np.round(100*cpo/po,2),'%')
print('----------------------------------------------------------------')
print('SELECTED/MATCHET SAMPLES')
print('----------------------------------------------------------------')
print('% Selected         :', np.round(100*pa/po,2),'%')
print('N selected         :', pa)
print('Treated selected   :', tpa,np.round(100*tpa/pa,2),'%')
print('Controled selected :', cpa,np.round(100*cpa/pa,2),'%')
print('----------------------------------------------------------------')
print('')

#PSW weights
w =psw_base['ANO']/psw_base['PROPENSITY_SCORE'] + ((1-psw_base['ANO'])/(1-psw_base['PROPENSITY_SCORE']))
# Out:
# ----------------------------------------------------------------
# USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES
# ----------------------------------------------------------------
# N without missing  : 7992615
# Treated samples    : 5237013 65.52 %
# Controled samples  : 2755602 34.48 %
# ----------------------------------------------------------------
# SELECTED/MATCHET SAMPLES
# ----------------------------------------------------------------
# % Selected         : 79.48 %
# N selected         : 6352426
# Treated selected   : 4169171 65.63 %
# Controled selected : 2183255 34.37 %
# ----------------------------------------------------------------

# %%
## SECOND REGRESSION
aux=['ANO']
var_model_2 = [
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    #, 'idade_gestacao_faixa_entre_22_27'
    #, 'idade_gestacao_faixa_entre_28_36'
    #, 'idade_gestacao_faixa_entre_37_39'
    #, 'idade_gestacao_faixa_entre_40_42'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    , 'FLAG_BASE_SIM_DOFET'
    #, 'FLAG_BASE_SINASC'
]

X = psw_base[aux+var_model_2].values
y = psw_base[['PRM']].values

X_ANO = sm.add_constant(X)
clf_ano = sm.Logit(y, X_ANO,weights=w).fit()
aux=['Intercept','ANO']

print('----------------------------------------------------------------')
print('PSW REPORT',periodo)
print('----------------------------------------------------------------')
print(clf_ano.summary(xname=aux+var_model_2))
print('----------------------------------------------------------------')


IC=np.exp(clf_ano.conf_int(0.05))
odds_ratio=pd.DataFrame(
    data = {
        'Var':aux+var_model_2
        , 'Odds_ratio': np.round(np.exp(clf_ano.params),3)
        , 'Odds_Lim_inf': np.round(IC[:,0],3)
        , 'Odds_Lim_Sup': np.round(IC[:,1],3)
        , 'p-values':np.round(clf_ano.pvalues,3)
    }
)
print(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.244995
#          Iterations 8
# ----------------------------------------------------------------
# PSW REPORT 2019-2020-2021
# ----------------------------------------------------------------
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:              6352426
# Model:                          Logit   Df Residuals:                  6352406
# Method:                           MLE   Df Model:                           19
# Date:                Tue, 25 Jun 2024   Pseudo R-squ.:                  0.3172
# Time:                        21:44:11   Log-Likelihood:            -1.5563e+06
# converged:                       True   LL-Null:                   -2.2794e+06
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -2.6924      0.005   -571.730      0.000      -2.702      -2.683
# ANO                                   0.0321      0.003      9.995      0.000       0.026       0.038
# evento_REGIAO_Centro-Oeste           -0.2202      0.005    -40.294      0.000      -0.231      -0.209
# evento_REGIAO_Nordeste               -0.5815      0.004   -142.165      0.000      -0.590      -0.574
# evento_REGIAO_Norte                  -0.9584      0.007   -144.723      0.000      -0.971      -0.945
# evento_REGIAO_Sul                    -0.2207      0.005    -48.306      0.000      -0.230      -0.212
# idademae_faixa_entre_35_39            0.1096      0.004     25.274      0.000       0.101       0.118
# idademae_faixa_maior_igual_40        -0.8770      0.014    -64.600      0.000      -0.904      -0.850
# idademae_faixa_menor_igual_19         0.9484      0.005    201.567      0.000       0.939       0.958
# escolaridade_mae_Ensino_medio        -0.3005      0.004    -74.992      0.000      -0.308      -0.293
# escolaridade_mae_Fundamental          1.0771      0.005    233.097      0.000       1.068       1.086
# escolaridade_mae_Sem_escolaridade     0.7653      0.021     35.813      0.000       0.723       0.807
# tipo_gravidez_Multipla                1.4909      0.007    210.819      0.000       1.477       1.505
# def_sexo_Masculino                    0.3797      0.003    122.901      0.000       0.374       0.386
# peso_faixa_entre_1500_2499            2.6773      0.004    720.387      0.000       2.670       2.685
# peso_faixa_entre_3500_3999           -1.3244      0.006   -220.416      0.000      -1.336      -1.313
# peso_faixa_entre_500_1499             5.5140      0.016    355.714      0.000       5.484       5.544
# peso_faixa_maior_igual_4000          -1.4076      0.012   -114.123      0.000      -1.432      -1.383
# peso_faixa_menor_500                  2.7316      0.023    120.743      0.000       2.687       2.776
# FLAG_BASE_SIM_DOFET                   1.0467      0.017     60.446      0.000       1.013       1.081
# =====================================================================================================
# ----------------------------------------------------------------
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |    | Var                               |   Odds_ratio |   Odds_Lim_inf |   Odds_Lim_Sup |   p-values |
# +====+===================================+==============+================+================+============+
# |  0 | Intercept                         |        0.068 |          0.067 |          0.068 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  1 | ANO                               |        1.033 |          1.026 |          1.039 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  2 | evento_REGIAO_Centro-Oeste        |        0.802 |          0.794 |          0.811 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  3 | evento_REGIAO_Nordeste            |        0.559 |          0.555 |          0.564 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  4 | evento_REGIAO_Norte               |        0.384 |          0.379 |          0.389 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  5 | evento_REGIAO_Sul                 |        0.802 |          0.795 |          0.809 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  6 | idademae_faixa_entre_35_39        |        1.116 |          1.106 |          1.125 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  7 | idademae_faixa_maior_igual_40     |        0.416 |          0.405 |          0.427 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  8 | idademae_faixa_menor_igual_19     |        2.582 |          2.558 |          2.605 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  9 | escolaridade_mae_Ensino_medio     |        0.74  |          0.735 |          0.746 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 10 | escolaridade_mae_Fundamental      |        2.936 |          2.91  |          2.963 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 11 | escolaridade_mae_Sem_escolaridade |        2.15  |          2.061 |          2.242 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 12 | tipo_gravidez_Multipla            |        4.441 |          4.38  |          4.503 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 13 | def_sexo_Masculino                |        1.462 |          1.453 |          1.471 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 14 | peso_faixa_entre_1500_2499        |       14.545 |         14.44  |         14.652 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 15 | peso_faixa_entre_3500_3999        |        0.266 |          0.263 |          0.269 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 16 | peso_faixa_entre_500_1499         |      248.152 |        240.726 |        255.807 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 17 | peso_faixa_maior_igual_4000       |        0.245 |          0.239 |          0.251 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 18 | peso_faixa_menor_500              |       15.358 |         14.692 |         16.054 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 19 | FLAG_BASE_SIM_DOFET               |        2.848 |          2.753 |          2.946 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+

# %%
with open(f'{periodo}.txt', 'w') as f:
    f.write('---------------------------------------------------------------- \n')
    f.write('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES \n')
    f.write('----------------------------------------------------------------\n')
    f.write('N without missing  :' + str(po) +'\n')
    f.write('Treated samples    :' + str([tpo,np.round(100*tpo/po,2)]) + '% \n')
    f.write('Controled samples  :' + str([cpo,np.round(100*cpo/po,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('SELECTED/MATCHET SAMPLES\n')
    f.write('---------------------------------------------------------------- \n')
    f.write('% Selected         :' + str(np.round(100*pa/po,2)) + '% \n')
    f.write('N selected         :' + str(pa) + '\n')
    f.write('Treated selected   :' + str([tpa,np.round(100*tpa/pa,2)]) + '% \n')
    f.write('Controled selected :' + str([cpa,np.round(100*cpa/pa,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('PSW REPORT - ' + periodo+ '\n')
    f.write(str(clf_ano.summary(xname=aux+var_model_2)))
    f.write('\n')
    f.write(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))

# %%
fig = sns.kdeplot(df_mod.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="r")
fig = sns.kdeplot(df_mod.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig('fig1a.png', format='png', dpi=300)
plt.show()

# %%
fig = sns.kdeplot(psw_base.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="r")
fig = sns.kdeplot(psw_base.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig('fig1b.png', format='png', dpi=300)
plt.show()

# %%
#spearm
var_corr = ['PRM'] + var_model_2


plt.figure(figsize=(16, 6))
# define the mask to set the values in the upper triangle to True

mask = np.triu(np.ones_like(psw_base[var_corr].corr(method="spearman"), dtype=np.bool))
heatmap = sns.heatmap(psw_base[var_corr].corr(method='spearman'), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Matrix', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# # Modelo 1

# %%
variaveis_1 = [  
     'ANO'
    , 'PRM'
    , 'evento_REGIAO'
    , 'idademae_faixa'
    , 'escolaridade_mae'
    ,'tipo_gravidez'
    , 'idade_gestacao_faixa'
    , 'def_sexo'
    , 'peso_faixa'
    , 'FLAG_BASE'
    , 'sum_CENTROBS'
    , 'sum_QTINST34'
    , 'sum_QTINST35'
    , 'sum_QTINST36'
    , 'sum_QTINST37'
    , 'sum_QTLEIT34'
    , 'sum_QTLEIT38'
    , 'sum_QTLEIT39'
    , 'sum_QTLEIT40'
    , 'sum_CENTRNEO'
    , 'TP_UNID_5'
    , 'TP_UNID_7'
    , 'TP_UNID_15'
    , 'TP_UNID_36'
    , 'TP_UNID_61'
    ]
df_mod = df[variaveis_1]

# %%
# PRM contagem
NPT = (df_mod['PRM']==1).sum()
NT = (df_mod['PRM']==0).sum()

# %%
# Categorizando as novas variáveis. 
df_mod['cat_CENTROBS'] = [1 if i > 0 else 0 for i in df_mod['sum_CENTROBS']]
df_mod['cat_QTINST34'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST34']]
df_mod['cat_QTINST35'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST35']]
df_mod['cat_QTINST36'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST36']]
df_mod['cat_QTINST37'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST37']]
df_mod['cat_QTLEIT34'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT34']]
df_mod['cat_QTLEIT38'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT38']]
df_mod['cat_QTLEIT39'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT39']]
df_mod['cat_QTLEIT40'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT40']]
df_mod['cat_CENTRNEO'] = [1 if i > 0 else 0 for i in df_mod['sum_CENTRNEO']]
df_mod['cat_TP_UNID_5'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_5']]
df_mod['cat_TP_UNID_7'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_7']]
df_mod['cat_TP_UNID_15'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_15']]
df_mod['cat_TP_UNID_36'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_36']]
df_mod['cat_TP_UNID_61'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_61']]

# %%
df_mod = df_mod.drop(
    columns=[
        'sum_CENTROBS'
        ,'sum_QTINST34'
        ,'sum_QTINST35'
        ,'sum_QTINST36'
        ,'sum_QTINST37'
        ,'sum_QTLEIT34'
        ,'sum_QTLEIT38'
        ,'sum_QTLEIT39'
        ,'sum_QTLEIT40'
        ,'sum_CENTRNEO'
        ,'TP_UNID_5'
        ,'TP_UNID_7'
        ,'TP_UNID_15'
        ,'TP_UNID_36'
        ,'TP_UNID_61'
    ]
)

# %%
df_mod = pd.get_dummies(df_mod)

# %%
df_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7992615 entries, 0 to 10452700
# Data columns (total 46 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   ANO                                int32
#  1   PRM                                int32
#  2   cat_CENTROBS                       int64
#  3   cat_QTINST34                       int64
#  4   cat_QTINST35                       int64
#  5   cat_QTINST36                       int64
#  6   cat_QTINST37                       int64
#  7   cat_QTLEIT34                       int64
#  8   cat_QTLEIT38                       int64
#  9   cat_QTLEIT39                       int64
#  10  cat_QTLEIT40                       int64
#  11  cat_CENTRNEO                       int64
#  12  cat_TP_UNID_5                      int64
#  13  cat_TP_UNID_7                      int64
#  14  cat_TP_UNID_15                     int64
#  15  cat_TP_UNID_36                     int64
#  16  cat_TP_UNID_61                     int64
#  17  evento_REGIAO_Centro-Oeste         uint8
#  18  evento_REGIAO_Nordeste             uint8
#  19  evento_REGIAO_Norte                uint8
#  20  evento_REGIAO_Sudeste              uint8
#  21  evento_REGIAO_Sul                  uint8
#  22  idademae_faixa_entre_20_34         uint8
#  23  idademae_faixa_entre_35_39         uint8
#  24  idademae_faixa_maior_igual_40      uint8
#  25  idademae_faixa_menor_igual_19      uint8
#  26  escolaridade_mae_Ensino_medio      uint8
#  27  escolaridade_mae_Ensino_superior   uint8
#  28  escolaridade_mae_Fundamental       uint8
#  29  escolaridade_mae_Sem_escolaridade  uint8
#  30  tipo_gravidez_Multipla             uint8
#  31  tipo_gravidez_Unica                uint8
#  32  idade_gestacao_faixa_entre_22_27   uint8
#  33  idade_gestacao_faixa_entre_28_36   uint8
#  34  idade_gestacao_faixa_entre_37_39   uint8
#  35  idade_gestacao_faixa_entre_40_42   uint8
#  36  def_sexo_Feminino                  uint8
#  37  def_sexo_Masculino                 uint8
#  38  peso_faixa_entre_1500_2499         uint8
#  39  peso_faixa_entre_2500_3500         uint8
#  40  peso_faixa_entre_3500_3999         uint8
#  41  peso_faixa_entre_500_1499          uint8
#  42  peso_faixa_maior_igual_4000        uint8
#  43  peso_faixa_menor_500               uint8
#  44  FLAG_BASE_SIM_DOFET                uint8
#  45  FLAG_BASE_SINASC                   uint8
# dtypes: int32(2), int64(15), uint8(29)
# memory usage: 1.2 GB

# %%
for i in df_mod.columns:
    print(i)
# Out:
# ANO
# PRM
# cat_CENTROBS
# cat_QTINST34
# cat_QTINST35
# cat_QTINST36
# cat_QTINST37
# cat_QTLEIT34
# cat_QTLEIT38
# cat_QTLEIT39
# cat_QTLEIT40
# cat_CENTRNEO
# cat_TP_UNID_5
# cat_TP_UNID_7
# cat_TP_UNID_15
# cat_TP_UNID_36
# cat_TP_UNID_61
# evento_REGIAO_Centro-Oeste
# evento_REGIAO_Nordeste
# evento_REGIAO_Norte
# evento_REGIAO_Sudeste
# evento_REGIAO_Sul
# idademae_faixa_entre_20_34
# idademae_faixa_entre_35_39
# idademae_faixa_maior_igual_40
# idademae_faixa_menor_igual_19
# escolaridade_mae_Ensino_medio
# escolaridade_mae_Ensino_superior
# escolaridade_mae_Fundamental
# escolaridade_mae_Sem_escolaridade
# tipo_gravidez_Multipla
# tipo_gravidez_Unica
# idade_gestacao_faixa_entre_22_27
# idade_gestacao_faixa_entre_28_36
# idade_gestacao_faixa_entre_37_39
# idade_gestacao_faixa_entre_40_42
# def_sexo_Feminino
# def_sexo_Masculino
# peso_faixa_entre_1500_2499
# peso_faixa_entre_2500_3500
# peso_faixa_entre_3500_3999
# peso_faixa_entre_500_1499
# peso_faixa_maior_igual_4000
# peso_faixa_menor_500
# FLAG_BASE_SIM_DOFET
# FLAG_BASE_SINASC

# %%
# Modelo
#Defining covariates
var_model=[
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    , 'idade_gestacao_faixa_entre_22_27'
    , 'idade_gestacao_faixa_entre_28_36'
    #, 'idade_gestacao_faixa_entre_37_39'
    , 'idade_gestacao_faixa_entre_40_42'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    , 'FLAG_BASE_SIM_DOFET'
    #, 'FLAG_BASE_SINASC'
    #,'cat_CENTROBS'
    #, 'cat_QTINST34'
    #,'cat_QTINST35'
    #,'cat_QTINST36'
    #, 'cat_QTINST37'
    #, 'cat_QTLEIT34'
    #, 'cat_QTLEIT38'
    #, 'cat_QTLEIT39'
    #, 'cat_QTLEIT40'
    #, 'cat_CENTRNEO'
    #, 'cat_TP_UNID_5'
    #, 'cat_TP_UNID_7'
    , 'cat_TP_UNID_15'
    , 'cat_TP_UNID_36'
]

X = df_mod[var_model].values

## FIRST REGRESSION
y = df_mod[['ANO']].values
clf = LogisticRegression(random_state=0, max_iter=2000).fit(X, y)
df_mod = df_mod.assign(PROPENSITY_SCORE=clf.predict_proba(X)[:, 1])

#USING PROPENSITY SCORE TO SELECT SAMPLES TO SECOND REGRESSION
psw_base=df_mod[((df_mod['PROPENSITY_SCORE']>df_mod['PROPENSITY_SCORE'].quantile(0.1)) &
                 (df_mod['PROPENSITY_SCORE']<df_mod['PROPENSITY_SCORE'].quantile(0.9)))]

#COUNTING
po=len(df_mod)
tpo=len(df_mod[df_mod['ANO']==1])
cpo=len(df_mod[df_mod['ANO']==0])
pa=len(psw_base)
tpa=len(psw_base[psw_base['ANO']==1])
cpa=len(psw_base[psw_base['ANO']==0])

print('----------------------------------------------------------------')
print('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES')
print('----------------------------------------------------------------')
print('N without missing  :', po)
print('Treated samples    :', tpo,np.round(100*tpo/po,2),'%')
print('Controled samples  :', cpo,np.round(100*cpo/po,2),'%')
print('----------------------------------------------------------------')
print('SELECTED/MATCHET SAMPLES')
print('----------------------------------------------------------------')
print('% Selected         :', np.round(100*pa/po,2),'%')
print('N selected         :', pa)
print('Treated selected   :', tpa,np.round(100*tpa/pa,2),'%')
print('Controled selected :', cpa,np.round(100*cpa/pa,2),'%')
print('----------------------------------------------------------------')
print('')

#PSW weights
w =psw_base['ANO']/psw_base['PROPENSITY_SCORE'] + ((1-psw_base['ANO'])/(1-psw_base['PROPENSITY_SCORE']))
# Out:
# ----------------------------------------------------------------
# USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES
# ----------------------------------------------------------------
# N without missing  : 7992615
# Treated samples    : 5237013 65.52 %
# Controled samples  : 2755602 34.48 %
# ----------------------------------------------------------------
# SELECTED/MATCHET SAMPLES
# ----------------------------------------------------------------
# % Selected         : 79.5 %
# N selected         : 6354400
# Treated selected   : 4172917 65.67 %
# Controled selected : 2181483 34.33 %
# ----------------------------------------------------------------

# %%
## SECOND REGRESSION
aux=['ANO']
var_model_2 = [
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    #, 'idade_gestacao_faixa_entre_22_27'
    #, 'idade_gestacao_faixa_entre_28_36'
    #, 'idade_gestacao_faixa_entre_37_39'
    #, 'idade_gestacao_faixa_entre_40_42'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    , 'FLAG_BASE_SIM_DOFET'
    #, 'FLAG_BASE_SINASC'
    #,'cat_CENTROBS'
    #,'cat_QTINST34'
    # 'cat_QTINST35'
    #,'cat_QTINST36'
    #, 'cat_QTINST37'
    #, 'cat_QTLEIT34'
    #, 'cat_QTLEIT38'
    #, 'cat_QTLEIT39'
    #, 'cat_QTLEIT40'
    #, 'cat_CENTRNEO'
    #, 'cat_TP_UNID_5'
    #, 'cat_TP_UNID_7'
    , 'cat_TP_UNID_15'
    , 'cat_TP_UNID_36'
]

X = psw_base[aux+var_model_2].values
y = psw_base[['PRM']].values

X_ANO = sm.add_constant(X)
clf_ano = sm.Logit(y, X_ANO,weights=w).fit()
aux=['Intercept','ANO']

print('----------------------------------------------------------------')
print('PSW REPORT',periodo)
print('----------------------------------------------------------------')
print(clf_ano.summary(xname=aux+var_model_2))
print('----------------------------------------------------------------')


IC=np.exp(clf_ano.conf_int(0.05))
odds_ratio=pd.DataFrame(
    data = {
        'Var':aux+var_model_2
        , 'Odds_ratio': np.round(np.exp(clf_ano.params),3)
        , 'Odds_Lim_inf': np.round(IC[:,0],3)
        , 'Odds_Lim_Sup': np.round(IC[:,1],3)
        , 'p-values':np.round(clf_ano.pvalues,3)
    }
)
print(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.253387
#          Iterations 8
# ----------------------------------------------------------------
# PSW REPORT 2019-2020-2021
# ----------------------------------------------------------------
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:              6354400
# Model:                          Logit   Df Residuals:                  6354378
# Method:                           MLE   Df Model:                           21
# Date:                Tue, 25 Jun 2024   Pseudo R-squ.:                  0.3022
# Time:                        21:49:42   Log-Likelihood:            -1.6101e+06
# converged:                       True   LL-Null:                   -2.3075e+06
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -2.2023      0.007   -312.319      0.000      -2.216      -2.189
# ANO                                   0.0359      0.003     11.371      0.000       0.030       0.042
# evento_REGIAO_Centro-Oeste           -0.1717      0.006    -30.720      0.000      -0.183      -0.161
# evento_REGIAO_Nordeste               -0.1366      0.004    -34.920      0.000      -0.144      -0.129
# evento_REGIAO_Norte                  -0.7191      0.006   -115.464      0.000      -0.731      -0.707
# evento_REGIAO_Sul                    -0.1737      0.005    -37.322      0.000      -0.183      -0.165
# idademae_faixa_entre_35_39            0.1538      0.004     35.812      0.000       0.145       0.162
# idademae_faixa_maior_igual_40        -0.8659      0.012    -72.191      0.000      -0.889      -0.842
# idademae_faixa_menor_igual_19         0.7036      0.005    154.155      0.000       0.695       0.713
# escolaridade_mae_Ensino_medio        -0.0986      0.004    -24.614      0.000      -0.106      -0.091
# escolaridade_mae_Fundamental          1.0237      0.005    221.896      0.000       1.015       1.033
# escolaridade_mae_Sem_escolaridade     0.6640      0.021     31.465      0.000       0.623       0.705
# tipo_gravidez_Multipla                1.4207      0.007    200.725      0.000       1.407       1.435
# def_sexo_Masculino                    0.3230      0.003    106.831      0.000       0.317       0.329
# peso_faixa_entre_1500_2499            2.6249      0.004    707.622      0.000       2.618       2.632
# peso_faixa_entre_3500_3999           -1.2623      0.006   -224.492      0.000      -1.273      -1.251
# peso_faixa_entre_500_1499             5.4133      0.016    348.797      0.000       5.383       5.444
# peso_faixa_maior_igual_4000          -1.4954      0.012   -124.788      0.000      -1.519      -1.472
# peso_faixa_menor_500                  2.6824      0.022    119.260      0.000       2.638       2.726
# FLAG_BASE_SIM_DOFET                   1.0002      0.017     60.604      0.000       0.968       1.033
# cat_TP_UNID_15                       -0.9064      0.005   -174.421      0.000      -0.917      -0.896
# cat_TP_UNID_36                       -0.5314      0.005   -100.336      0.000      -0.542      -0.521
# =====================================================================================================
# ----------------------------------------------------------------
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |    | Var                               |   Odds_ratio |   Odds_Lim_inf |   Odds_Lim_Sup |   p-values |
# +====+===================================+==============+================+================+============+
# |  0 | Intercept                         |        0.111 |          0.109 |          0.112 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  1 | ANO                               |        1.037 |          1.03  |          1.043 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  2 | evento_REGIAO_Centro-Oeste        |        0.842 |          0.833 |          0.852 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  3 | evento_REGIAO_Nordeste            |        0.872 |          0.866 |          0.879 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  4 | evento_REGIAO_Norte               |        0.487 |          0.481 |          0.493 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  5 | evento_REGIAO_Sul                 |        0.841 |          0.833 |          0.848 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  6 | idademae_faixa_entre_35_39        |        1.166 |          1.156 |          1.176 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  7 | idademae_faixa_maior_igual_40     |        0.421 |          0.411 |          0.431 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  8 | idademae_faixa_menor_igual_19     |        2.021 |          2.003 |          2.039 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  9 | escolaridade_mae_Ensino_medio     |        0.906 |          0.899 |          0.913 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 10 | escolaridade_mae_Fundamental      |        2.784 |          2.759 |          2.809 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 11 | escolaridade_mae_Sem_escolaridade |        1.943 |          1.864 |          2.025 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 12 | tipo_gravidez_Multipla            |        4.14  |          4.083 |          4.198 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 13 | def_sexo_Masculino                |        1.381 |          1.373 |          1.389 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 14 | peso_faixa_entre_1500_2499        |       13.803 |         13.703 |         13.904 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 15 | peso_faixa_entre_3500_3999        |        0.283 |          0.28  |          0.286 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 16 | peso_faixa_entre_500_1499         |      224.376 |        217.653 |        231.306 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 17 | peso_faixa_maior_igual_4000       |        0.224 |          0.219 |          0.229 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 18 | peso_faixa_menor_500              |       14.62  |         13.99  |         15.279 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 19 | FLAG_BASE_SIM_DOFET               |        2.719 |          2.632 |          2.808 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 20 | cat_TP_UNID_15                    |        0.404 |          0.4   |          0.408 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 21 | cat_TP_UNID_36                    |        0.588 |          0.582 |          0.594 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+

# %%
with open(f'{periodo}.txt', 'w') as f:
    f.write('---------------------------------------------------------------- \n')
    f.write('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES \n')
    f.write('----------------------------------------------------------------\n')
    f.write('N without missing  :' + str(po) +'\n')
    f.write('Treated samples    :' + str([tpo,np.round(100*tpo/po,2)]) + '% \n')
    f.write('Controled samples  :' + str([cpo,np.round(100*cpo/po,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('SELECTED/MATCHET SAMPLES\n')
    f.write('---------------------------------------------------------------- \n')
    f.write('% Selected         :' + str(np.round(100*pa/po,2)) + '% \n')
    f.write('N selected         :' + str(pa) + '\n')
    f.write('Treated selected   :' + str([tpa,np.round(100*tpa/pa,2)]) + '% \n')
    f.write('Controled selected :' + str([cpa,np.round(100*cpa/pa,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('PSW REPORT - ' + periodo+ '\n')
    f.write(str(clf_ano.summary(xname=aux+var_model_2)))
    f.write('\n')
    f.write(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))

# %%
fig = sns.kdeplot(df_mod.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="r")
fig = sns.kdeplot(df_mod.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig('fig1a.png', format='png', dpi=300)
plt.show()

# %%
fig = sns.kdeplot(psw_base.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="r")
fig = sns.kdeplot(psw_base.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig('fig1b.png', format='png', dpi=300)
plt.show()

# %%
#spearm
var_corr = ['PRM'] + var_model_2

plt.figure(figsize=(16, 6))
# define the mask to set the values in the upper triangle to True

mask = np.triu(np.ones_like(psw_base[var_corr].corr(method="spearman"), dtype=np.bool))
heatmap = sns.heatmap(psw_base[var_corr].corr(method='spearman'), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Matrix', fontdict={'fontsize':18}, pad=16);

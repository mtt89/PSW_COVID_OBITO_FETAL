# %%
#Importing Modules
from Funcoes_auxiliares.func_aux import *
import pandas as pd
import numpy as np
from scipy.stats import chi2
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
#plt.style.use("ggplot")
#from google.colab import drive
from pandas.testing import assert_frame_equal
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from tabulate import tabulate
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\gabri\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\gabri\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %%
df = pd.read_csv('base_limpa/base_unificada_limpa.csv')
periodo='2019-2022'
df = df.loc[df['ano_evento'].isin([2019, 2022])]
df['ANO'] = np.where(df['ano_evento']==2019, 0, 1)
# Variável PRM
df['PRM'] = np.where(df['idade_gestacao_faixa'].isin(['entre_37_39', 'entre_40_42']), 0, 1)

# %% [markdown]
# # Modelo zero

# %%
variaveis =  [  
     'ANO'
    , 'PRM'
    , 'evento_REGIAO'
    , 'idademae_faixa'
    , 'escolaridade_mae'
    ,'tipo_gravidez'
    , 'idade_gestacao_faixa'
    , 'def_sexo'
    , 'peso_faixa'
    , 'FLAG_BASE'
]

df_mod = df[variaveis]

# %%
# PRM contagem
NPT = (df_mod['PRM']==1).sum()
NT = (df_mod['PRM']==0).sum()

# %%
df_mod = pd.get_dummies(df_mod)

# %%
df_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5256448 entries, 0 to 10493462
# Data columns (total 32 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   ANO                                int32
#  1   PRM                                int32
#  2   evento_REGIAO_Centro-Oeste         uint8
#  3   evento_REGIAO_Nordeste             uint8
#  4   evento_REGIAO_Norte                uint8
#  5   evento_REGIAO_Sudeste              uint8
#  6   evento_REGIAO_Sul                  uint8
#  7   idademae_faixa_entre_20_34         uint8
#  8   idademae_faixa_entre_35_39         uint8
#  9   idademae_faixa_maior_igual_40      uint8
#  10  idademae_faixa_menor_igual_19      uint8
#  11  escolaridade_mae_Ensino_medio      uint8
#  12  escolaridade_mae_Ensino_superior   uint8
#  13  escolaridade_mae_Fundamental       uint8
#  14  escolaridade_mae_Sem_escolaridade  uint8
#  15  tipo_gravidez_Ignorado             uint8
#  16  tipo_gravidez_Multipla             uint8
#  17  tipo_gravidez_Unica                uint8
#  18  idade_gestacao_faixa_entre_22_27   uint8
#  19  idade_gestacao_faixa_entre_28_36   uint8
#  20  idade_gestacao_faixa_entre_37_39   uint8
#  21  idade_gestacao_faixa_entre_40_42   uint8
#  22  def_sexo_Feminino                  uint8
#  23  def_sexo_Masculino                 uint8
#  24  peso_faixa_entre_1500_2499         uint8
#  25  peso_faixa_entre_2500_3500         uint8
#  26  peso_faixa_entre_3500_3999         uint8
#  27  peso_faixa_entre_500_1499          uint8
#  28  peso_faixa_maior_igual_4000        uint8
#  29  peso_faixa_menor_500               uint8
#  30  FLAG_BASE_SIM_DOFET                uint8
#  31  FLAG_BASE_SINASC                   uint8
# dtypes: int32(2), uint8(30)
# memory usage: 230.6 MB

# %%
df_mod.columns
# Out:
# Index(['ANO', 'PRM', 'evento_REGIAO_Centro-Oeste', 'evento_REGIAO_Nordeste',
#        'evento_REGIAO_Norte', 'evento_REGIAO_Sudeste', 'evento_REGIAO_Sul',
#        'idademae_faixa_entre_20_34', 'idademae_faixa_entre_35_39',
#        'idademae_faixa_maior_igual_40', 'idademae_faixa_menor_igual_19',
#        'escolaridade_mae_Ensino_medio', 'escolaridade_mae_Ensino_superior',
#        'escolaridade_mae_Fundamental', 'escolaridade_mae_Sem_escolaridade',
#        'tipo_gravidez_Ignorado', 'tipo_gravidez_Multipla',
#        'tipo_gravidez_Unica', 'idade_gestacao_faixa_entre_22_27',
#        'idade_gestacao_faixa_entre_28_36', 'idade_gestacao_faixa_entre_37_39',
#        'idade_gestacao_faixa_entre_40_42', 'def_sexo_Feminino',
#        'def_sexo_Masculino', 'peso_faixa_entre_1500_2499',
#        'peso_faixa_entre_2500_3500', 'peso_faixa_entre_3500_3999',
#        'peso_faixa_entre_500_1499', 'peso_faixa_maior_igual_4000',
#        'peso_faixa_menor_500', 'FLAG_BASE_SIM_DOFET', 'FLAG_BASE_SINASC'],
#       dtype='object')

# %%
# Modelo
#Defining covariates
var_model=[
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    , 'idade_gestacao_faixa_entre_22_27'
    , 'idade_gestacao_faixa_entre_28_36'
    #, 'idade_gestacao_faixa_entre_37_39'
    , 'idade_gestacao_faixa_entre_40_42'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    , 'FLAG_BASE_SIM_DOFET'
    #, 'FLAG_BASE_SINASC'
]

X = df_mod[var_model].values

## FIRST REGRESSION
y = df_mod[['ANO']].values
clf = LogisticRegression(random_state=0, max_iter=2000).fit(X, y)
df_mod = df_mod.assign(PROPENSITY_SCORE=clf.predict_proba(X)[:, 1])

#USING PROPENSITY SCORE TO SELECT SAMPLES TO SECOND REGRESSION
psw_base=df_mod[((df_mod['PROPENSITY_SCORE']>df_mod['PROPENSITY_SCORE'].quantile(0.1)) &
                 (df_mod['PROPENSITY_SCORE']<df_mod['PROPENSITY_SCORE'].quantile(0.9)))]

#COUNTING
po=len(df_mod)
tpo=len(df_mod[df_mod['ANO']==1])
cpo=len(df_mod[df_mod['ANO']==0])
pa=len(psw_base)
tpa=len(psw_base[psw_base['ANO']==1])
cpa=len(psw_base[psw_base['ANO']==0])

print('----------------------------------------------------------------')
print('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES')
print('----------------------------------------------------------------')
print('N without missing  :', po)
print('Treated samples    :', tpo,np.round(100*tpo/po,2),'%')
print('Controled samples  :', cpo,np.round(100*cpo/po,2),'%')
print('----------------------------------------------------------------')
print('SELECTED/MATCHET SAMPLES')
print('----------------------------------------------------------------')
print('% Selected         :', np.round(100*pa/po,2),'%')
print('N selected         :', pa)
print('Treated selected   :', tpa,np.round(100*tpa/pa,2),'%')
print('Controled selected :', cpa,np.round(100*cpa/pa,2),'%')
print('----------------------------------------------------------------')
print('')

#PSW weights
w =psw_base['ANO']/psw_base['PROPENSITY_SCORE'] + ((1-psw_base['ANO'])/(1-psw_base['PROPENSITY_SCORE']))
# Out:
# ----------------------------------------------------------------
# USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES
# ----------------------------------------------------------------
# N without missing  : 5256448
# Treated samples    : 2500844 47.58 %
# Controled samples  : 2755604 52.42 %
# ----------------------------------------------------------------
# SELECTED/MATCHET SAMPLES
# ----------------------------------------------------------------
# % Selected         : 79.82 %
# N selected         : 4195519
# Treated selected   : 2013262 47.99 %
# Controled selected : 2182257 52.01 %
# ----------------------------------------------------------------

# %%
## SECOND REGRESSION
aux=['ANO']
var_model_2 = [
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    #, 'idade_gestacao_faixa_entre_22_27'
    #, 'idade_gestacao_faixa_entre_28_36'
    #, 'idade_gestacao_faixa_entre_37_39'
    #, 'idade_gestacao_faixa_entre_40_42'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    , 'FLAG_BASE_SIM_DOFET'
    #, 'FLAG_BASE_SINASC'
]

X = psw_base[aux+var_model_2].values
y = psw_base[['PRM']].values

X_ANO = sm.add_constant(X)
clf_ano = sm.Logit(y, X_ANO,weights=w).fit()
aux=['Intercept','ANO']

print('----------------------------------------------------------------')
print('PSW REPORT',periodo)
print('----------------------------------------------------------------')
print(clf_ano.summary(xname=aux+var_model_2))
print('----------------------------------------------------------------')


IC=np.exp(clf_ano.conf_int(0.05))
odds_ratio=pd.DataFrame(
    data = {
        'Var':aux+var_model_2
        , 'Odds_ratio': np.round(np.exp(clf_ano.params),3)
        , 'Odds_Lim_inf': np.round(IC[:,0],3)
        , 'Odds_Lim_Sup': np.round(IC[:,1],3)
        , 'p-values':np.round(clf_ano.pvalues,3)
    }
)
print(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.248725
#          Iterations 7
# ----------------------------------------------------------------
# PSW REPORT 2019-2022
# ----------------------------------------------------------------
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:              4195519
# Model:                          Logit   Df Residuals:                  4195499
# Method:                           MLE   Df Model:                           19
# Date:                Tue, 02 Jul 2024   Pseudo R-squ.:                  0.2490
# Time:                        22:47:23   Log-Likelihood:            -1.0435e+06
# converged:                       True   LL-Null:                   -1.3895e+06
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -2.8116      0.006   -488.346      0.000      -2.823      -2.800
# ANO                                   0.0416      0.004     11.000      0.000       0.034       0.049
# evento_REGIAO_Centro-Oeste           -0.1261      0.007    -17.601      0.000      -0.140      -0.112
# evento_REGIAO_Nordeste               -0.1139      0.005    -23.702      0.000      -0.123      -0.104
# evento_REGIAO_Norte                  -0.0289      0.007     -3.932      0.000      -0.043      -0.015
# evento_REGIAO_Sul                    -0.4991      0.007    -74.366      0.000      -0.512      -0.486
# idademae_faixa_entre_35_39           -0.0899      0.006    -14.530      0.000      -0.102      -0.078
# idademae_faixa_maior_igual_40        -0.0923      0.016     -5.921      0.000      -0.123      -0.062
# idademae_faixa_menor_igual_19         0.5101      0.006     86.035      0.000       0.498       0.522
# escolaridade_mae_Ensino_medio         0.0229      0.005      4.354      0.000       0.013       0.033
# escolaridade_mae_Fundamental          0.6363      0.006    105.130      0.000       0.624       0.648
# escolaridade_mae_Sem_escolaridade     0.7343      0.026     27.727      0.000       0.682       0.786
# tipo_gravidez_Multipla                1.6559      0.009    194.150      0.000       1.639       1.673
# def_sexo_Masculino                    0.2078      0.004     54.624      0.000       0.200       0.215
# peso_faixa_entre_1500_2499            2.3152      0.005    457.694      0.000       2.305       2.325
# peso_faixa_entre_3500_3999           -0.7419      0.006   -114.464      0.000      -0.755      -0.729
# peso_faixa_entre_500_1499             4.9740      0.020    254.424      0.000       4.936       5.012
# peso_faixa_maior_igual_4000          -0.7643      0.015    -51.407      0.000      -0.793      -0.735
# peso_faixa_menor_500                  1.9401      0.041     47.859      0.000       1.861       2.020
# FLAG_BASE_SIM_DOFET                   1.5449      0.020     76.941      0.000       1.506       1.584
# =====================================================================================================
# ----------------------------------------------------------------
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |    | Var                               |   Odds_ratio |   Odds_Lim_inf |   Odds_Lim_Sup |   p-values |
# +====+===================================+==============+================+================+============+
# |  0 | Intercept                         |        0.06  |          0.059 |          0.061 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  1 | ANO                               |        1.042 |          1.035 |          1.05  |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  2 | evento_REGIAO_Centro-Oeste        |        0.882 |          0.869 |          0.894 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  3 | evento_REGIAO_Nordeste            |        0.892 |          0.884 |          0.901 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  4 | evento_REGIAO_Norte               |        0.971 |          0.958 |          0.986 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  5 | evento_REGIAO_Sul                 |        0.607 |          0.599 |          0.615 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  6 | idademae_faixa_entre_35_39        |        0.914 |          0.903 |          0.925 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  7 | idademae_faixa_maior_igual_40     |        0.912 |          0.884 |          0.94  |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  8 | idademae_faixa_menor_igual_19     |        1.665 |          1.646 |          1.685 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  9 | escolaridade_mae_Ensino_medio     |        1.023 |          1.013 |          1.034 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 10 | escolaridade_mae_Fundamental      |        1.889 |          1.867 |          1.912 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 11 | escolaridade_mae_Sem_escolaridade |        2.084 |          1.979 |          2.195 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 12 | tipo_gravidez_Multipla            |        5.238 |          5.151 |          5.326 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 13 | def_sexo_Masculino                |        1.231 |          1.222 |          1.24  |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 14 | peso_faixa_entre_1500_2499        |       10.126 |         10.027 |         10.227 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 15 | peso_faixa_entre_3500_3999        |        0.476 |          0.47  |          0.482 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 16 | peso_faixa_entre_500_1499         |      144.604 |        139.168 |        150.252 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 17 | peso_faixa_maior_igual_4000       |        0.466 |          0.452 |          0.479 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 18 | peso_faixa_menor_500              |        6.96  |          6.428 |          7.535 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 19 | FLAG_BASE_SIM_DOFET               |        4.687 |          4.506 |          4.875 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+

# %%
with open(f'resultados/modelo_0/{periodo}_modelo_0_PRM.txt', 'w') as f:
    f.write('---------------------------------------------------------------- \n')
    f.write('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES \n')
    f.write('----------------------------------------------------------------\n')
    f.write('N without missing  :' + str(po) +'\n')
    f.write('Treated samples    :' + str([tpo,np.round(100*tpo/po,2)]) + '% \n')
    f.write('Controled samples  :' + str([cpo,np.round(100*cpo/po,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('SELECTED/MATCHET SAMPLES\n')
    f.write('---------------------------------------------------------------- \n')
    f.write('% Selected         :' + str(np.round(100*pa/po,2)) + '% \n')
    f.write('N selected         :' + str(pa) + '\n')
    f.write('Treated selected   :' + str([tpa,np.round(100*tpa/pa,2)]) + '% \n')
    f.write('Controled selected :' + str([cpa,np.round(100*cpa/pa,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('PSW REPORT - ' + periodo+ '\n')
    f.write(str(clf_ano.summary(xname=aux+var_model_2)))
    f.write('\n')
    f.write(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))

# %%
odds_ratio['periodo'] = periodo
odds_ratio.to_csv(f'resultados/modelo_0/{periodo}_modelo_0_PRM.csv', decimal=',', sep=';',index=False)

# %%
fig = sns.kdeplot(df_mod.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="r")
fig = sns.kdeplot(df_mod.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_0/fig1a_{periodo}_modelo_0_PRM.png', format='png', dpi=300)
plt.show()

# %%
fig = sns.kdeplot(psw_base.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="r")
fig = sns.kdeplot(psw_base.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_0/fig1b_{periodo}_modelo_0_PRM.png', format='png', dpi=300)
plt.show()

# %%
#spearm
var_corr = ['PRM'] + var_model_2


plt.figure(figsize=(16, 6))
# define the mask to set the values in the upper triangle to True

mask = np.triu(np.ones_like(psw_base[var_corr].corr(method="spearman"), dtype=np.bool))
heatmap = sns.heatmap(psw_base[var_corr].corr(method='spearman'), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Matrix', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# # Modelo 1

# %%
variaveis_1 = [  
     'ANO'
    , 'PRM'
    , 'evento_REGIAO'
    , 'idademae_faixa'
    , 'escolaridade_mae'
    ,'tipo_gravidez'
    , 'idade_gestacao_faixa'
    , 'def_sexo'
    , 'peso_faixa'
    , 'FLAG_BASE'
    , 'sum_CENTROBS'
    , 'sum_QTINST34'
    , 'sum_QTINST35'
    , 'sum_QTINST36'
    , 'sum_QTINST37'
    , 'sum_QTLEIT34'
    , 'sum_QTLEIT38'
    , 'sum_QTLEIT39'
    , 'sum_QTLEIT40'
    , 'sum_CENTRNEO'
    , 'TP_UNID_5'
    , 'TP_UNID_7'
    , 'TP_UNID_15'
    , 'TP_UNID_36'
    , 'TP_UNID_61'
    ]
df_mod = df[variaveis_1]

# %%
# PRM contagem
NPT = (df_mod['PRM']==1).sum()
NT = (df_mod['PRM']==0).sum()

# %%
# Categorizando as novas variáveis. 
df_mod['cat_CENTROBS'] = [1 if i > 0 else 0 for i in df_mod['sum_CENTROBS']]
df_mod['cat_QTINST34'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST34']]
df_mod['cat_QTINST35'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST35']]
df_mod['cat_QTINST36'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST36']]
df_mod['cat_QTINST37'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST37']]
df_mod['cat_QTLEIT34'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT34']]
df_mod['cat_QTLEIT38'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT38']]
df_mod['cat_QTLEIT39'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT39']]
df_mod['cat_QTLEIT40'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT40']]
df_mod['cat_CENTRNEO'] = [1 if i > 0 else 0 for i in df_mod['sum_CENTRNEO']]
df_mod['cat_TP_UNID_5'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_5']]
df_mod['cat_TP_UNID_7'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_7']]
df_mod['cat_TP_UNID_15'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_15']]
df_mod['cat_TP_UNID_36'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_36']]
df_mod['cat_TP_UNID_61'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_61']]

# %%
df_mod = df_mod.drop(
    columns=[
        'sum_CENTROBS'
        ,'sum_QTINST34'
        ,'sum_QTINST35'
        ,'sum_QTINST36'
        ,'sum_QTINST37'
        ,'sum_QTLEIT34'
        ,'sum_QTLEIT38'
        ,'sum_QTLEIT39'
        ,'sum_QTLEIT40'
        ,'sum_CENTRNEO'
        ,'TP_UNID_5'
        ,'TP_UNID_7'
        ,'TP_UNID_15'
        ,'TP_UNID_36'
        ,'TP_UNID_61'
    ]
)

# %%
df_mod = pd.get_dummies(df_mod)

# %%
df_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5256448 entries, 0 to 10493462
# Data columns (total 47 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   ANO                                int32
#  1   PRM                                int32
#  2   cat_CENTROBS                       int64
#  3   cat_QTINST34                       int64
#  4   cat_QTINST35                       int64
#  5   cat_QTINST36                       int64
#  6   cat_QTINST37                       int64
#  7   cat_QTLEIT34                       int64
#  8   cat_QTLEIT38                       int64
#  9   cat_QTLEIT39                       int64
#  10  cat_QTLEIT40                       int64
#  11  cat_CENTRNEO                       int64
#  12  cat_TP_UNID_5                      int64
#  13  cat_TP_UNID_7                      int64
#  14  cat_TP_UNID_15                     int64
#  15  cat_TP_UNID_36                     int64
#  16  cat_TP_UNID_61                     int64
#  17  evento_REGIAO_Centro-Oeste         uint8
#  18  evento_REGIAO_Nordeste             uint8
#  19  evento_REGIAO_Norte                uint8
#  20  evento_REGIAO_Sudeste              uint8
#  21  evento_REGIAO_Sul                  uint8
#  22  idademae_faixa_entre_20_34         uint8
#  23  idademae_faixa_entre_35_39         uint8
#  24  idademae_faixa_maior_igual_40      uint8
#  25  idademae_faixa_menor_igual_19      uint8
#  26  escolaridade_mae_Ensino_medio      uint8
#  27  escolaridade_mae_Ensino_superior   uint8
#  28  escolaridade_mae_Fundamental       uint8
#  29  escolaridade_mae_Sem_escolaridade  uint8
#  30  tipo_gravidez_Ignorado             uint8
#  31  tipo_gravidez_Multipla             uint8
#  32  tipo_gravidez_Unica                uint8
#  33  idade_gestacao_faixa_entre_22_27   uint8
#  34  idade_gestacao_faixa_entre_28_36   uint8
#  35  idade_gestacao_faixa_entre_37_39   uint8
#  36  idade_gestacao_faixa_entre_40_42   uint8
#  37  def_sexo_Feminino                  uint8
#  38  def_sexo_Masculino                 uint8
#  39  peso_faixa_entre_1500_2499         uint8
#  40  peso_faixa_entre_2500_3500         uint8
#  41  peso_faixa_entre_3500_3999         uint8
#  42  peso_faixa_entre_500_1499          uint8
#  43  peso_faixa_maior_igual_4000        uint8
#  44  peso_faixa_menor_500               uint8
#  45  FLAG_BASE_SIM_DOFET                uint8
#  46  FLAG_BASE_SINASC                   uint8
# dtypes: int32(2), int64(15), uint8(30)
# memory usage: 832.1 MB

# %%
for i in df_mod.columns:
    print(i)
# Out:
# ANO
# PRM
# cat_CENTROBS
# cat_QTINST34
# cat_QTINST35
# cat_QTINST36
# cat_QTINST37
# cat_QTLEIT34
# cat_QTLEIT38
# cat_QTLEIT39
# cat_QTLEIT40
# cat_CENTRNEO
# cat_TP_UNID_5
# cat_TP_UNID_7
# cat_TP_UNID_15
# cat_TP_UNID_36
# cat_TP_UNID_61
# evento_REGIAO_Centro-Oeste
# evento_REGIAO_Nordeste
# evento_REGIAO_Norte
# evento_REGIAO_Sudeste
# evento_REGIAO_Sul
# idademae_faixa_entre_20_34
# idademae_faixa_entre_35_39
# idademae_faixa_maior_igual_40
# idademae_faixa_menor_igual_19
# escolaridade_mae_Ensino_medio
# escolaridade_mae_Ensino_superior
# escolaridade_mae_Fundamental
# escolaridade_mae_Sem_escolaridade
# tipo_gravidez_Ignorado
# tipo_gravidez_Multipla
# tipo_gravidez_Unica
# idade_gestacao_faixa_entre_22_27
# idade_gestacao_faixa_entre_28_36
# idade_gestacao_faixa_entre_37_39
# idade_gestacao_faixa_entre_40_42
# def_sexo_Feminino
# def_sexo_Masculino
# peso_faixa_entre_1500_2499
# peso_faixa_entre_2500_3500
# peso_faixa_entre_3500_3999
# peso_faixa_entre_500_1499
# peso_faixa_maior_igual_4000
# peso_faixa_menor_500
# FLAG_BASE_SIM_DOFET
# FLAG_BASE_SINASC

# %%
# Modelo
#Defining covariates
var_model=[
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    , 'idade_gestacao_faixa_entre_22_27'
    , 'idade_gestacao_faixa_entre_28_36'
    #, 'idade_gestacao_faixa_entre_37_39'
    , 'idade_gestacao_faixa_entre_40_42'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    , 'FLAG_BASE_SIM_DOFET'
    #, 'FLAG_BASE_SINASC'
    #,'cat_CENTROBS'
    #, 'cat_QTINST34'
    #,'cat_QTINST35'
    #,'cat_QTINST36'
    #, 'cat_QTINST37'
    #, 'cat_QTLEIT34'
    #, 'cat_QTLEIT38'
    #, 'cat_QTLEIT39'
    #, 'cat_QTLEIT40'
    #, 'cat_CENTRNEO'
    #, 'cat_TP_UNID_5'
    #, 'cat_TP_UNID_7'
    , 'cat_TP_UNID_15'
    , 'cat_TP_UNID_36'
]

X = df_mod[var_model].values

## FIRST REGRESSION
y = df_mod[['ANO']].values
clf = LogisticRegression(random_state=0, max_iter=2000).fit(X, y)
df_mod = df_mod.assign(PROPENSITY_SCORE=clf.predict_proba(X)[:, 1])

#USING PROPENSITY SCORE TO SELECT SAMPLES TO SECOND REGRESSION
psw_base=df_mod[((df_mod['PROPENSITY_SCORE']>df_mod['PROPENSITY_SCORE'].quantile(0.1)) &
                 (df_mod['PROPENSITY_SCORE']<df_mod['PROPENSITY_SCORE'].quantile(0.9)))]

#COUNTING
po=len(df_mod)
tpo=len(df_mod[df_mod['ANO']==1])
cpo=len(df_mod[df_mod['ANO']==0])
pa=len(psw_base)
tpa=len(psw_base[psw_base['ANO']==1])
cpa=len(psw_base[psw_base['ANO']==0])

print('----------------------------------------------------------------')
print('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES')
print('----------------------------------------------------------------')
print('N without missing  :', po)
print('Treated samples    :', tpo,np.round(100*tpo/po,2),'%')
print('Controled samples  :', cpo,np.round(100*cpo/po,2),'%')
print('----------------------------------------------------------------')
print('SELECTED/MATCHET SAMPLES')
print('----------------------------------------------------------------')
print('% Selected         :', np.round(100*pa/po,2),'%')
print('N selected         :', pa)
print('Treated selected   :', tpa,np.round(100*tpa/pa,2),'%')
print('Controled selected :', cpa,np.round(100*cpa/pa,2),'%')
print('----------------------------------------------------------------')
print('')

#PSW weights
w =psw_base['ANO']/psw_base['PROPENSITY_SCORE'] + ((1-psw_base['ANO'])/(1-psw_base['PROPENSITY_SCORE']))
# Out:
# ----------------------------------------------------------------
# USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES
# ----------------------------------------------------------------
# N without missing  : 5256448
# Treated samples    : 2500844 47.58 %
# Controled samples  : 2755604 52.42 %
# ----------------------------------------------------------------
# SELECTED/MATCHET SAMPLES
# ----------------------------------------------------------------
# % Selected         : 79.98 %
# N selected         : 4204041
# Treated selected   : 2004822 47.69 %
# Controled selected : 2199219 52.31 %
# ----------------------------------------------------------------

# %%
## SECOND REGRESSION
aux=['ANO']
var_model_2 = [
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    #, 'idade_gestacao_faixa_entre_22_27'
    #, 'idade_gestacao_faixa_entre_28_36'
    #, 'idade_gestacao_faixa_entre_37_39'
    #, 'idade_gestacao_faixa_entre_40_42'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    , 'FLAG_BASE_SIM_DOFET'
    #, 'FLAG_BASE_SINASC'
    #,'cat_CENTROBS'
    #,'cat_QTINST34'
    # 'cat_QTINST35'
    #,'cat_QTINST36'
    #, 'cat_QTINST37'
    #, 'cat_QTLEIT34'
    #, 'cat_QTLEIT38'
    #, 'cat_QTLEIT39'
    #, 'cat_QTLEIT40'
    #, 'cat_CENTRNEO'
    #, 'cat_TP_UNID_5'
    #, 'cat_TP_UNID_7'
    , 'cat_TP_UNID_15'
    , 'cat_TP_UNID_36'
]

X = psw_base[aux+var_model_2].values
y = psw_base[['PRM']].values

X_ANO = sm.add_constant(X)
clf_ano = sm.Logit(y, X_ANO,weights=w).fit()
aux=['Intercept','ANO']

print('----------------------------------------------------------------')
print('PSW REPORT',periodo)
print('----------------------------------------------------------------')
print(clf_ano.summary(xname=aux+var_model_2))
print('----------------------------------------------------------------')


IC=np.exp(clf_ano.conf_int(0.05))
odds_ratio=pd.DataFrame(
    data = {
        'Var':aux+var_model_2
        , 'Odds_ratio': np.round(np.exp(clf_ano.params),3)
        , 'Odds_Lim_inf': np.round(IC[:,0],3)
        , 'Odds_Lim_Sup': np.round(IC[:,1],3)
        , 'p-values':np.round(clf_ano.pvalues,3)
    }
)
print(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.269875
#          Iterations 7
# ----------------------------------------------------------------
# PSW REPORT 2019-2022
# ----------------------------------------------------------------
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:              4204041
# Model:                          Logit   Df Residuals:                  4204019
# Method:                           MLE   Df Model:                           21
# Date:                Tue, 02 Jul 2024   Pseudo R-squ.:                  0.2670
# Time:                        22:50:34   Log-Likelihood:            -1.1346e+06
# converged:                       True   LL-Null:                   -1.5478e+06
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -2.6426      0.009   -303.988      0.000      -2.660      -2.626
# ANO                                   0.0300      0.004      8.381      0.000       0.023       0.037
# evento_REGIAO_Centro-Oeste            0.0289      0.007      4.372      0.000       0.016       0.042
# evento_REGIAO_Nordeste                0.0865      0.005     18.432      0.000       0.077       0.096
# evento_REGIAO_Norte                   0.1828      0.006     30.172      0.000       0.171       0.195
# evento_REGIAO_Sul                     0.0169      0.006      3.026      0.002       0.006       0.028
# idademae_faixa_entre_35_39            0.2108      0.005     40.721      0.000       0.201       0.221
# idademae_faixa_maior_igual_40         0.0602      0.011      5.693      0.000       0.039       0.081
# idademae_faixa_menor_igual_19         0.2246      0.006     39.155      0.000       0.213       0.236
# escolaridade_mae_Ensino_medio         0.0119      0.005      2.517      0.012       0.003       0.021
# escolaridade_mae_Fundamental          0.3279      0.006     58.340      0.000       0.317       0.339
# escolaridade_mae_Sem_escolaridade     0.4237      0.027     15.909      0.000       0.371       0.476
# tipo_gravidez_Multipla                1.3837      0.009    160.064      0.000       1.367       1.401
# def_sexo_Masculino                    0.2542      0.004     70.579      0.000       0.247       0.261
# peso_faixa_entre_1500_2499            2.5041      0.004    577.356      0.000       2.496       2.513
# peso_faixa_entre_3500_3999           -0.9276      0.007   -141.089      0.000      -0.940      -0.915
# peso_faixa_entre_500_1499             5.2566      0.019    273.525      0.000       5.219       5.294
# peso_faixa_maior_igual_4000          -0.8473      0.014    -58.829      0.000      -0.876      -0.819
# peso_faixa_menor_500                  2.5277      0.027     93.615      0.000       2.475       2.581
# FLAG_BASE_SIM_DOFET                   1.5423      0.019     82.653      0.000       1.506       1.579
# cat_TP_UNID_15                       -0.4271      0.007    -58.427      0.000      -0.441      -0.413
# cat_TP_UNID_36                       -0.1440      0.007    -21.036      0.000      -0.157      -0.131
# =====================================================================================================
# ----------------------------------------------------------------
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |    | Var                               |   Odds_ratio |   Odds_Lim_inf |   Odds_Lim_Sup |   p-values |
# +====+===================================+==============+================+================+============+
# |  0 | Intercept                         |        0.071 |          0.07  |          0.072 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  1 | ANO                               |        1.03  |          1.023 |          1.038 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  2 | evento_REGIAO_Centro-Oeste        |        1.029 |          1.016 |          1.043 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  3 | evento_REGIAO_Nordeste            |        1.09  |          1.08  |          1.1   |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  4 | evento_REGIAO_Norte               |        1.201 |          1.186 |          1.215 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  5 | evento_REGIAO_Sul                 |        1.017 |          1.006 |          1.028 |      0.002 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  6 | idademae_faixa_entre_35_39        |        1.235 |          1.222 |          1.247 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  7 | idademae_faixa_maior_igual_40     |        1.062 |          1.04  |          1.084 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  8 | idademae_faixa_menor_igual_19     |        1.252 |          1.238 |          1.266 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  9 | escolaridade_mae_Ensino_medio     |        1.012 |          1.003 |          1.021 |      0.012 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 10 | escolaridade_mae_Fundamental      |        1.388 |          1.373 |          1.403 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 11 | escolaridade_mae_Sem_escolaridade |        1.528 |          1.45  |          1.609 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 12 | tipo_gravidez_Multipla            |        3.99  |          3.923 |          4.058 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 13 | def_sexo_Masculino                |        1.289 |          1.28  |          1.299 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 14 | peso_faixa_entre_1500_2499        |       12.233 |         12.129 |         12.337 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 15 | peso_faixa_entre_3500_3999        |        0.396 |          0.39  |          0.401 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 16 | peso_faixa_entre_500_1499         |      191.823 |        184.732 |        199.186 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 17 | peso_faixa_maior_igual_4000       |        0.429 |          0.417 |          0.441 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 18 | peso_faixa_menor_500              |       12.525 |         11.879 |         13.205 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 19 | FLAG_BASE_SIM_DOFET               |        4.675 |          4.507 |          4.849 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 20 | cat_TP_UNID_15                    |        0.652 |          0.643 |          0.662 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 21 | cat_TP_UNID_36                    |        0.866 |          0.854 |          0.878 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+

# %%
with open(f'resultados/modelo_1/{periodo}_modelo_1_PRM.txt', 'w') as f:
    f.write('---------------------------------------------------------------- \n')
    f.write('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES \n')
    f.write('----------------------------------------------------------------\n')
    f.write('N without missing  :' + str(po) +'\n')
    f.write('Treated samples    :' + str([tpo,np.round(100*tpo/po,2)]) + '% \n')
    f.write('Controled samples  :' + str([cpo,np.round(100*cpo/po,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('SELECTED/MATCHET SAMPLES\n')
    f.write('---------------------------------------------------------------- \n')
    f.write('% Selected         :' + str(np.round(100*pa/po,2)) + '% \n')
    f.write('N selected         :' + str(pa) + '\n')
    f.write('Treated selected   :' + str([tpa,np.round(100*tpa/pa,2)]) + '% \n')
    f.write('Controled selected :' + str([cpa,np.round(100*cpa/pa,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('PSW REPORT - ' + periodo+ '\n')
    f.write(str(clf_ano.summary(xname=aux+var_model_2)))
    f.write('\n')
    f.write(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))

# %%
odds_ratio['periodo'] = periodo
odds_ratio.to_csv(f'resultados/modelo_1/{periodo}_modelo_1_PRM.csv', decimal=',', sep=';', index=False)

# %%
fig = sns.kdeplot(df_mod.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="r")
fig = sns.kdeplot(df_mod.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_1/fig1a_{periodo}_modelo_1_PRM.png', format='png', dpi=300)
plt.show()

# %%
fig = sns.kdeplot(psw_base.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="r")
fig = sns.kdeplot(psw_base.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_1/fig1b_{periodo}_modelo_1_PRM.png', format='png', dpi=300)
plt.show()

# %%
#spearm
var_corr = ['PRM'] + var_model_2

plt.figure(figsize=(16, 6))
# define the mask to set the values in the upper triangle to True

mask = np.triu(np.ones_like(psw_base[var_corr].corr(method="spearman"), dtype=np.bool))
heatmap = sns.heatmap(psw_base[var_corr].corr(method='spearman'), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Matrix', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# # Modelo 2

# %%
variaveis_1 = [  
     'ANO'
    , 'PRM'
    , 'evento_REGIAO'
    , 'idademae_faixa'
    , 'escolaridade_mae'
    , 'tipo_gravidez'
    , 'idade_gestacao_faixa'
    , 'def_sexo'
    , 'peso_faixa'
    , 'FLAG_BASE'
    , 'sum_CENTROBS'
    , 'sum_QTINST34'
    , 'sum_QTINST35'
    , 'sum_QTINST36'
    , 'sum_QTINST37'
    , 'sum_QTLEIT34'
    , 'sum_QTLEIT38'
    , 'sum_QTLEIT39'
    , 'sum_QTLEIT40'
    , 'sum_CENTRNEO'
    , 'TP_UNID_5'
    , 'TP_UNID_7'
    , 'TP_UNID_15'
    , 'TP_UNID_36'
    , 'TP_UNID_61'
    ]
df_mod = df[variaveis_1]

# %%
# Categorizando as novas variáveis. 
df_mod['cat_CENTROBS'] = [1 if i > 0 else 0 for i in df_mod['sum_CENTROBS']]
df_mod['cat_QTINST34'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST34']]
df_mod['cat_QTINST35'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST35']]
df_mod['cat_QTINST36'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST36']]
df_mod['cat_QTINST37'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST37']]
df_mod['cat_QTLEIT34'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT34']]
df_mod['cat_QTLEIT38'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT38']]
df_mod['cat_QTLEIT39'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT39']]
df_mod['cat_QTLEIT40'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT40']]
df_mod['cat_CENTRNEO'] = [1 if i > 0 else 0 for i in df_mod['sum_CENTRNEO']]
df_mod['cat_TP_UNID_5'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_5']]
df_mod['cat_TP_UNID_7'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_7']]
df_mod['cat_TP_UNID_15'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_15']]
df_mod['cat_TP_UNID_36'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_36']]
df_mod['cat_TP_UNID_61'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_61']]

# %%
df_mod = df_mod.drop(
    columns=[
        'sum_CENTROBS'
        ,'sum_QTINST34'
        ,'sum_QTINST35'
        ,'sum_QTINST36'
        ,'sum_QTINST37'
        ,'sum_QTLEIT34'
        ,'sum_QTLEIT38'
        ,'sum_QTLEIT39'
        ,'sum_QTLEIT40'
        ,'sum_CENTRNEO'
        ,'TP_UNID_5'
        ,'TP_UNID_7'
        ,'TP_UNID_15'
        ,'TP_UNID_36'
        ,'TP_UNID_61'
    ]
)

# %%
df_mod = pd.get_dummies(df_mod)

# %%
# OBITO contagem
NPT = (df_mod['FLAG_BASE_SIM_DOFET']==1).sum()
NT = (df_mod['FLAG_BASE_SIM_DOFET']==0).sum()

# %%
df_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5256448 entries, 0 to 10493462
# Data columns (total 47 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   ANO                                int32
#  1   PRM                                int32
#  2   cat_CENTROBS                       int64
#  3   cat_QTINST34                       int64
#  4   cat_QTINST35                       int64
#  5   cat_QTINST36                       int64
#  6   cat_QTINST37                       int64
#  7   cat_QTLEIT34                       int64
#  8   cat_QTLEIT38                       int64
#  9   cat_QTLEIT39                       int64
#  10  cat_QTLEIT40                       int64
#  11  cat_CENTRNEO                       int64
#  12  cat_TP_UNID_5                      int64
#  13  cat_TP_UNID_7                      int64
#  14  cat_TP_UNID_15                     int64
#  15  cat_TP_UNID_36                     int64
#  16  cat_TP_UNID_61                     int64
#  17  evento_REGIAO_Centro-Oeste         uint8
#  18  evento_REGIAO_Nordeste             uint8
#  19  evento_REGIAO_Norte                uint8
#  20  evento_REGIAO_Sudeste              uint8
#  21  evento_REGIAO_Sul                  uint8
#  22  idademae_faixa_entre_20_34         uint8
#  23  idademae_faixa_entre_35_39         uint8
#  24  idademae_faixa_maior_igual_40      uint8
#  25  idademae_faixa_menor_igual_19      uint8
#  26  escolaridade_mae_Ensino_medio      uint8
#  27  escolaridade_mae_Ensino_superior   uint8
#  28  escolaridade_mae_Fundamental       uint8
#  29  escolaridade_mae_Sem_escolaridade  uint8
#  30  tipo_gravidez_Ignorado             uint8
#  31  tipo_gravidez_Multipla             uint8
#  32  tipo_gravidez_Unica                uint8
#  33  idade_gestacao_faixa_entre_22_27   uint8
#  34  idade_gestacao_faixa_entre_28_36   uint8
#  35  idade_gestacao_faixa_entre_37_39   uint8
#  36  idade_gestacao_faixa_entre_40_42   uint8
#  37  def_sexo_Feminino                  uint8
#  38  def_sexo_Masculino                 uint8
#  39  peso_faixa_entre_1500_2499         uint8
#  40  peso_faixa_entre_2500_3500         uint8
#  41  peso_faixa_entre_3500_3999         uint8
#  42  peso_faixa_entre_500_1499          uint8
#  43  peso_faixa_maior_igual_4000        uint8
#  44  peso_faixa_menor_500               uint8
#  45  FLAG_BASE_SIM_DOFET                uint8
#  46  FLAG_BASE_SINASC                   uint8
# dtypes: int32(2), int64(15), uint8(30)
# memory usage: 832.1 MB

# %%
for i in df_mod.columns:
    print(i)
# Out:
# ANO
# PRM
# cat_CENTROBS
# cat_QTINST34
# cat_QTINST35
# cat_QTINST36
# cat_QTINST37
# cat_QTLEIT34
# cat_QTLEIT38
# cat_QTLEIT39
# cat_QTLEIT40
# cat_CENTRNEO
# cat_TP_UNID_5
# cat_TP_UNID_7
# cat_TP_UNID_15
# cat_TP_UNID_36
# cat_TP_UNID_61
# evento_REGIAO_Centro-Oeste
# evento_REGIAO_Nordeste
# evento_REGIAO_Norte
# evento_REGIAO_Sudeste
# evento_REGIAO_Sul
# idademae_faixa_entre_20_34
# idademae_faixa_entre_35_39
# idademae_faixa_maior_igual_40
# idademae_faixa_menor_igual_19
# escolaridade_mae_Ensino_medio
# escolaridade_mae_Ensino_superior
# escolaridade_mae_Fundamental
# escolaridade_mae_Sem_escolaridade
# tipo_gravidez_Ignorado
# tipo_gravidez_Multipla
# tipo_gravidez_Unica
# idade_gestacao_faixa_entre_22_27
# idade_gestacao_faixa_entre_28_36
# idade_gestacao_faixa_entre_37_39
# idade_gestacao_faixa_entre_40_42
# def_sexo_Feminino
# def_sexo_Masculino
# peso_faixa_entre_1500_2499
# peso_faixa_entre_2500_3500
# peso_faixa_entre_3500_3999
# peso_faixa_entre_500_1499
# peso_faixa_maior_igual_4000
# peso_faixa_menor_500
# FLAG_BASE_SIM_DOFET
# FLAG_BASE_SINASC

# %%
# Modelo
#Defining covariates
var_model=[
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    , 'PRM'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    #,'cat_CENTROBS'
    #, 'cat_QTINST34'
    #,'cat_QTINST35'
    #,'cat_QTINST36'
    #, 'cat_QTINST37'
    #, 'cat_QTLEIT34'
    #, 'cat_QTLEIT38'
    #, 'cat_QTLEIT39'
    #, 'cat_QTLEIT40'
    #, 'cat_CENTRNEO'
    #, 'cat_TP_UNID_5'
    #, 'cat_TP_UNID_7'
    #, 'cat_TP_UNID_15'
    #, 'cat_TP_UNID_36'
]

X = df_mod[var_model].values

## FIRST REGRESSION
y = df_mod[['ANO']].values
clf = LogisticRegression(random_state=0, max_iter=2000).fit(X, y)
df_mod = df_mod.assign(PROPENSITY_SCORE=clf.predict_proba(X)[:, 1])

#USING PROPENSITY SCORE TO SELECT SAMPLES TO SECOND REGRESSION
psw_base=df_mod[((df_mod['PROPENSITY_SCORE']>df_mod['PROPENSITY_SCORE'].quantile(0.1)) &
                 (df_mod['PROPENSITY_SCORE']<df_mod['PROPENSITY_SCORE'].quantile(0.9)))]

#COUNTING
po=len(df_mod)
tpo=len(df_mod[df_mod['ANO']==1])
cpo=len(df_mod[df_mod['ANO']==0])
pa=len(psw_base)
tpa=len(psw_base[psw_base['ANO']==1])
cpa=len(psw_base[psw_base['ANO']==0])

print('----------------------------------------------------------------')
print('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES')
print('----------------------------------------------------------------')
print('N without missing  :', po)
print('Treated samples    :', tpo,np.round(100*tpo/po,2),'%')
print('Controled samples  :', cpo,np.round(100*cpo/po,2),'%')
print('----------------------------------------------------------------')
print('SELECTED/MATCHET SAMPLES')
print('----------------------------------------------------------------')
print('% Selected         :', np.round(100*pa/po,2),'%')
print('N selected         :', pa)
print('Treated selected   :', tpa,np.round(100*tpa/pa,2),'%')
print('Controled selected :', cpa,np.round(100*cpa/pa,2),'%')
print('----------------------------------------------------------------')
print('')

#PSW weights
w =psw_base['ANO']/psw_base['PROPENSITY_SCORE'] + ((1-psw_base['ANO'])/(1-psw_base['PROPENSITY_SCORE']))
# Out:
# ----------------------------------------------------------------
# USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES
# ----------------------------------------------------------------
# N without missing  : 5256448
# Treated samples    : 2500844 47.58 %
# Controled samples  : 2755604 52.42 %
# ----------------------------------------------------------------
# SELECTED/MATCHET SAMPLES
# ----------------------------------------------------------------
# % Selected         : 78.77 %
# N selected         : 4140614
# Treated selected   : 1988999 48.04 %
# Controled selected : 2151615 51.96 %
# ----------------------------------------------------------------

# %%
## SECOND REGRESSION
aux=['ANO']
var_model_2 = [
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    , 'PRM'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    #,'cat_CENTROBS'
    #, 'cat_QTINST34'
    #,'cat_QTINST35'
    #,'cat_QTINST36'
    #, 'cat_QTINST37'
    #, 'cat_QTLEIT34'
    #, 'cat_QTLEIT38'
    #, 'cat_QTLEIT39'
    #, 'cat_QTLEIT40'
    #, 'cat_CENTRNEO'
    #, 'cat_TP_UNID_5'
    #, 'cat_TP_UNID_7'
    #, 'cat_TP_UNID_15'
    #, 'cat_TP_UNID_36'
]

X = psw_base[aux+var_model_2].values
y = psw_base[['FLAG_BASE_SIM_DOFET']].values

X_ANO = sm.add_constant(X)
clf_ano = sm.Logit(y, X_ANO,weights=w).fit()
aux=['Intercept','ANO']

print('----------------------------------------------------------------')
print('PSW REPORT',periodo)
print('----------------------------------------------------------------')
print(clf_ano.summary(xname=aux+var_model_2))
print('----------------------------------------------------------------')


IC=np.exp(clf_ano.conf_int(0.05))
odds_ratio=pd.DataFrame(
    data = {
        'Var':aux+var_model_2
        , 'Odds_ratio': np.round(np.exp(clf_ano.params),3)
        , 'Odds_Lim_inf': np.round(IC[:,0],3)
        , 'Odds_Lim_Sup': np.round(IC[:,1],3)
        , 'p-values':np.round(clf_ano.pvalues,3)
    }
)
print(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))
# Out:
# Optimization terminated successfully.
#          Current function value: inf
#          Iterations 11
# ----------------------------------------------------------------
# PSW REPORT 2019-2022
# ----------------------------------------------------------------
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:              4140614
# Model:                          Logit   Df Residuals:                  4140594
# Method:                           MLE   Df Model:                           19
# Date:                Tue, 02 Jul 2024   Pseudo R-squ.:                     inf
# Time:                        22:54:21   Log-Likelihood:                   -inf
# converged:                       True   LL-Null:                        0.0000
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -6.9702      0.027   -261.674      0.000      -7.022      -6.918
# ANO                                  -0.0279      0.014     -2.049      0.040      -0.055      -0.001
# evento_REGIAO_Centro-Oeste            0.1430      0.028      5.117      0.000       0.088       0.198
# evento_REGIAO_Nordeste                0.2950      0.017     16.961      0.000       0.261       0.329
# evento_REGIAO_Norte                   0.2946      0.027     10.889      0.000       0.242       0.348
# evento_REGIAO_Sul                    -0.1551      0.025     -6.156      0.000      -0.204      -0.106
# idademae_faixa_entre_35_39            0.1145      0.020      5.592      0.000       0.074       0.155
# idademae_faixa_maior_igual_40         0.3500      0.040      8.720      0.000       0.271       0.429
# idademae_faixa_menor_igual_19        -0.0887      0.022     -4.007      0.000      -0.132      -0.045
# escolaridade_mae_Ensino_medio         0.3446      0.023     15.050      0.000       0.300       0.389
# escolaridade_mae_Fundamental          0.8707      0.025     35.117      0.000       0.822       0.919
# escolaridade_mae_Sem_escolaridade     2.2003      0.051     43.452      0.000       2.101       2.300
# tipo_gravidez_Multipla               -0.9895      0.028    -35.239      0.000      -1.045      -0.934
# PRM                                   1.5372      0.020     76.027      0.000       1.498       1.577
# def_sexo_Masculino                    0.1002      0.014      7.283      0.000       0.073       0.127
# peso_faixa_entre_1500_2499            1.6222      0.022     72.579      0.000       1.578       1.666
# peso_faixa_entre_3500_3999           -0.4430      0.035    -12.784      0.000      -0.511      -0.375
# peso_faixa_entre_500_1499             3.4991      0.022    156.838      0.000       3.455       3.543
# peso_faixa_maior_igual_4000           0.5589      0.047     12.011      0.000       0.468       0.650
# peso_faixa_menor_500                  4.3947      0.047     94.019      0.000       4.303       4.486
# =====================================================================================================
# ----------------------------------------------------------------
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |    | Var                               |   Odds_ratio |   Odds_Lim_inf |   Odds_Lim_Sup |   p-values |
# +====+===================================+==============+================+================+============+
# |  0 | Intercept                         |        0.001 |          0.001 |          0.001 |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  1 | ANO                               |        0.973 |          0.947 |          0.999 |       0.04 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  2 | evento_REGIAO_Centro-Oeste        |        1.154 |          1.092 |          1.219 |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  3 | evento_REGIAO_Nordeste            |        1.343 |          1.298 |          1.39  |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  4 | evento_REGIAO_Norte               |        1.343 |          1.273 |          1.416 |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  5 | evento_REGIAO_Sul                 |        0.856 |          0.815 |          0.9   |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  6 | idademae_faixa_entre_35_39        |        1.121 |          1.077 |          1.167 |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  7 | idademae_faixa_maior_igual_40     |        1.419 |          1.312 |          1.535 |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  8 | idademae_faixa_menor_igual_19     |        0.915 |          0.876 |          0.956 |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  9 | escolaridade_mae_Ensino_medio     |        1.411 |          1.349 |          1.476 |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 10 | escolaridade_mae_Fundamental      |        2.389 |          2.275 |          2.508 |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 11 | escolaridade_mae_Sem_escolaridade |        9.028 |          8.175 |          9.97  |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 12 | tipo_gravidez_Multipla            |        0.372 |          0.352 |          0.393 |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 13 | PRM                               |        4.651 |          4.471 |          4.839 |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 14 | def_sexo_Masculino                |        1.105 |          1.076 |          1.136 |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 15 | peso_faixa_entre_1500_2499        |        5.064 |          4.847 |          5.291 |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 16 | peso_faixa_entre_3500_3999        |        0.642 |          0.6   |          0.687 |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 17 | peso_faixa_entre_500_1499         |       33.086 |         31.671 |         34.565 |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 18 | peso_faixa_maior_igual_4000       |        1.749 |          1.596 |          1.916 |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 19 | peso_faixa_menor_500              |       81.02  |         73.928 |         88.794 |       0    |
# +----+-----------------------------------+--------------+----------------+----------------+------------+

# %%
with open(f'resultados/modelo_2/{periodo}_modelo_2_OBITO.txt', 'w') as f:
    f.write('---------------------------------------------------------------- \n')
    f.write('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES \n')
    f.write('----------------------------------------------------------------\n')
    f.write('N without missing  :' + str(po) +'\n')
    f.write('Treated samples    :' + str([tpo,np.round(100*tpo/po,2)]) + '% \n')
    f.write('Controled samples  :' + str([cpo,np.round(100*cpo/po,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('SELECTED/MATCHET SAMPLES\n')
    f.write('---------------------------------------------------------------- \n')
    f.write('% Selected         :' + str(np.round(100*pa/po,2)) + '% \n')
    f.write('N selected         :' + str(pa) + '\n')
    f.write('Treated selected   :' + str([tpa,np.round(100*tpa/pa,2)]) + '% \n')
    f.write('Controled selected :' + str([cpa,np.round(100*cpa/pa,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('PSW REPORT - ' + periodo+ '\n')
    f.write(str(clf_ano.summary(xname=aux+var_model_2)))
    f.write('\n')
    f.write(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))

# %%
odds_ratio['periodo'] = periodo
odds_ratio.to_csv(f'resultados/modelo_2/{periodo}_modelo_2_OBITO.csv', decimal=',', sep=';', index=False)

# %%
fig = sns.kdeplot(df_mod.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="r")
fig = sns.kdeplot(df_mod.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_2/fig1a_{periodo}_modelo_2_OBITO.png', format='png', dpi=300)
plt.show()

# %%
fig = sns.kdeplot(psw_base.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="r")
fig = sns.kdeplot(psw_base.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_2/fig1b_{periodo}_modelo_2_OBITO.png', format='png', dpi=300)
plt.show()

# %%
#spearm
var_corr = ['FLAG_BASE_SIM_DOFET'] + var_model_2

plt.figure(figsize=(16, 6))
# define the mask to set the values in the upper triangle to True

mask = np.triu(np.ones_like(psw_base[var_corr].corr(method="spearman"), dtype=np.bool))
heatmap = sns.heatmap(psw_base[var_corr].corr(method='spearman'), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Matrix', fontdict={'fontsize':18}, pad=16);

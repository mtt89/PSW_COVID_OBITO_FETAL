# %%
#Importing Modules
from Funcoes_auxiliares.func_aux import *
import pandas as pd
import numpy as np
from scipy.stats import chi2
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt
#plt.style.use("ggplot")
#from google.colab import drive
from pandas.testing import assert_frame_equal
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from tabulate import tabulate
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\gabri\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\gabri\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %%
df = pd.read_csv('base_limpa/base_unificada_limpa.csv')
periodo='2019-2021-2022'
df = df.loc[df['ano_evento'].isin([2019, 2021, 2022])]
df['ANO'] = np.where(df['ano_evento']==2019, 0, 1)
# Variável PRM
df['PRM'] = np.where(df['idade_gestacao_faixa'].isin(['entre_37_39', 'entre_40_42']), 0, 1)

# %% [markdown]
# # Modelo zero

# %%
variaveis =  [  
     'ANO'
    , 'PRM'
    , 'evento_REGIAO'
    , 'idademae_faixa'
    , 'escolaridade_mae'
    ,'tipo_gravidez'
    , 'idade_gestacao_faixa'
    , 'def_sexo'
    , 'peso_faixa'
    , 'FLAG_BASE'
]

df_mod = df[variaveis]

# %%
# PRM contagem
NPT = (df_mod['PRM']==1).sum()
NT = (df_mod['PRM']==0).sum()

# %%
df_mod = pd.get_dummies(df_mod)

# %%
df_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7847402 entries, 0 to 10493462
# Data columns (total 32 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   ANO                                int32
#  1   PRM                                int32
#  2   evento_REGIAO_Centro-Oeste         uint8
#  3   evento_REGIAO_Nordeste             uint8
#  4   evento_REGIAO_Norte                uint8
#  5   evento_REGIAO_Sudeste              uint8
#  6   evento_REGIAO_Sul                  uint8
#  7   idademae_faixa_entre_20_34         uint8
#  8   idademae_faixa_entre_35_39         uint8
#  9   idademae_faixa_maior_igual_40      uint8
#  10  idademae_faixa_menor_igual_19      uint8
#  11  escolaridade_mae_Ensino_medio      uint8
#  12  escolaridade_mae_Ensino_superior   uint8
#  13  escolaridade_mae_Fundamental       uint8
#  14  escolaridade_mae_Sem_escolaridade  uint8
#  15  tipo_gravidez_Ignorado             uint8
#  16  tipo_gravidez_Multipla             uint8
#  17  tipo_gravidez_Unica                uint8
#  18  idade_gestacao_faixa_entre_22_27   uint8
#  19  idade_gestacao_faixa_entre_28_36   uint8
#  20  idade_gestacao_faixa_entre_37_39   uint8
#  21  idade_gestacao_faixa_entre_40_42   uint8
#  22  def_sexo_Feminino                  uint8
#  23  def_sexo_Masculino                 uint8
#  24  peso_faixa_entre_1500_2499         uint8
#  25  peso_faixa_entre_2500_3500         uint8
#  26  peso_faixa_entre_3500_3999         uint8
#  27  peso_faixa_entre_500_1499          uint8
#  28  peso_faixa_maior_igual_4000        uint8
#  29  peso_faixa_menor_500               uint8
#  30  FLAG_BASE_SIM_DOFET                uint8
#  31  FLAG_BASE_SINASC                   uint8
# dtypes: int32(2), uint8(30)
# memory usage: 344.3 MB

# %%
df_mod.columns
# Out:
# Index(['ANO', 'PRM', 'evento_REGIAO_Centro-Oeste', 'evento_REGIAO_Nordeste',
#        'evento_REGIAO_Norte', 'evento_REGIAO_Sudeste', 'evento_REGIAO_Sul',
#        'idademae_faixa_entre_20_34', 'idademae_faixa_entre_35_39',
#        'idademae_faixa_maior_igual_40', 'idademae_faixa_menor_igual_19',
#        'escolaridade_mae_Ensino_medio', 'escolaridade_mae_Ensino_superior',
#        'escolaridade_mae_Fundamental', 'escolaridade_mae_Sem_escolaridade',
#        'tipo_gravidez_Ignorado', 'tipo_gravidez_Multipla',
#        'tipo_gravidez_Unica', 'idade_gestacao_faixa_entre_22_27',
#        'idade_gestacao_faixa_entre_28_36', 'idade_gestacao_faixa_entre_37_39',
#        'idade_gestacao_faixa_entre_40_42', 'def_sexo_Feminino',
#        'def_sexo_Masculino', 'peso_faixa_entre_1500_2499',
#        'peso_faixa_entre_2500_3500', 'peso_faixa_entre_3500_3999',
#        'peso_faixa_entre_500_1499', 'peso_faixa_maior_igual_4000',
#        'peso_faixa_menor_500', 'FLAG_BASE_SIM_DOFET', 'FLAG_BASE_SINASC'],
#       dtype='object')

# %%
# Modelo
#Defining covariates
var_model=[
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    , 'idade_gestacao_faixa_entre_22_27'
    , 'idade_gestacao_faixa_entre_28_36'
    #, 'idade_gestacao_faixa_entre_37_39'
    , 'idade_gestacao_faixa_entre_40_42'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    , 'FLAG_BASE_SIM_DOFET'
    #, 'FLAG_BASE_SINASC'
]

X = df_mod[var_model].values

## FIRST REGRESSION
y = df_mod[['ANO']].values
clf = LogisticRegression(random_state=0, max_iter=2000).fit(X, y)
df_mod = df_mod.assign(PROPENSITY_SCORE=clf.predict_proba(X)[:, 1])

#USING PROPENSITY SCORE TO SELECT SAMPLES TO SECOND REGRESSION
psw_base=df_mod[((df_mod['PROPENSITY_SCORE']>df_mod['PROPENSITY_SCORE'].quantile(0.1)) &
                 (df_mod['PROPENSITY_SCORE']<df_mod['PROPENSITY_SCORE'].quantile(0.9)))]

#COUNTING
po=len(df_mod)
tpo=len(df_mod[df_mod['ANO']==1])
cpo=len(df_mod[df_mod['ANO']==0])
pa=len(psw_base)
tpa=len(psw_base[psw_base['ANO']==1])
cpa=len(psw_base[psw_base['ANO']==0])

print('----------------------------------------------------------------')
print('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES')
print('----------------------------------------------------------------')
print('N without missing  :', po)
print('Treated samples    :', tpo,np.round(100*tpo/po,2),'%')
print('Controled samples  :', cpo,np.round(100*cpo/po,2),'%')
print('----------------------------------------------------------------')
print('SELECTED/MATCHET SAMPLES')
print('----------------------------------------------------------------')
print('% Selected         :', np.round(100*pa/po,2),'%')
print('N selected         :', pa)
print('Treated selected   :', tpa,np.round(100*tpa/pa,2),'%')
print('Controled selected :', cpa,np.round(100*cpa/pa,2),'%')
print('----------------------------------------------------------------')
print('')

#PSW weights
w =psw_base['ANO']/psw_base['PROPENSITY_SCORE'] + ((1-psw_base['ANO'])/(1-psw_base['PROPENSITY_SCORE']))
# Out:
# ----------------------------------------------------------------
# USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES
# ----------------------------------------------------------------
# N without missing  : 7847402
# Treated samples    : 5091798 64.89 %
# Controled samples  : 2755604 35.11 %
# ----------------------------------------------------------------
# SELECTED/MATCHET SAMPLES
# ----------------------------------------------------------------
# % Selected         : 79.39 %
# N selected         : 6229990
# Treated selected   : 4058846 65.15 %
# Controled selected : 2171144 34.85 %
# ----------------------------------------------------------------

# %%
## SECOND REGRESSION
aux=['ANO']
var_model_2 = [
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    #, 'idade_gestacao_faixa_entre_22_27'
    #, 'idade_gestacao_faixa_entre_28_36'
    #, 'idade_gestacao_faixa_entre_37_39'
    #, 'idade_gestacao_faixa_entre_40_42'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    , 'FLAG_BASE_SIM_DOFET'
    #, 'FLAG_BASE_SINASC'
]

X = psw_base[aux+var_model_2].values
y = psw_base[['PRM']].values

X_ANO = sm.add_constant(X)
clf_ano = sm.Logit(y, X_ANO,weights=w).fit()
aux=['Intercept','ANO']

print('----------------------------------------------------------------')
print('PSW REPORT',periodo)
print('----------------------------------------------------------------')
print(clf_ano.summary(xname=aux+var_model_2))
print('----------------------------------------------------------------')


IC=np.exp(clf_ano.conf_int(0.05))
odds_ratio=pd.DataFrame(
    data = {
        'Var':aux+var_model_2
        , 'Odds_ratio': np.round(np.exp(clf_ano.params),3)
        , 'Odds_Lim_inf': np.round(IC[:,0],3)
        , 'Odds_Lim_Sup': np.round(IC[:,1],3)
        , 'p-values':np.round(clf_ano.pvalues,3)
    }
)
print(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.237761
#          Iterations 7
# ----------------------------------------------------------------
# PSW REPORT 2019-2021-2022
# ----------------------------------------------------------------
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:              6229990
# Model:                          Logit   Df Residuals:                  6229970
# Method:                           MLE   Df Model:                           19
# Date:                Wed, 03 Jul 2024   Pseudo R-squ.:                  0.2777
# Time:                        00:20:31   Log-Likelihood:            -1.4812e+06
# converged:                       True   LL-Null:                   -2.0507e+06
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -2.7133      0.005   -546.538      0.000      -2.723      -2.704
# ANO                                   0.0313      0.003      9.373      0.000       0.025       0.038
# evento_REGIAO_Centro-Oeste           -0.2551      0.006    -42.763      0.000      -0.267      -0.243
# evento_REGIAO_Nordeste               -0.5902      0.004   -133.419      0.000      -0.599      -0.581
# evento_REGIAO_Norte                  -0.5038      0.007    -76.460      0.000      -0.517      -0.491
# evento_REGIAO_Sul                    -0.3053      0.005    -60.434      0.000      -0.315      -0.295
# idademae_faixa_entre_35_39            0.0194      0.005      4.094      0.000       0.010       0.029
# idademae_faixa_maior_igual_40        -0.1842      0.013    -13.848      0.000      -0.210      -0.158
# idademae_faixa_menor_igual_19         0.6319      0.005    126.812      0.000       0.622       0.642
# escolaridade_mae_Ensino_medio        -0.1473      0.004    -34.569      0.000      -0.156      -0.139
# escolaridade_mae_Fundamental          0.7834      0.005    155.802      0.000       0.774       0.793
# escolaridade_mae_Sem_escolaridade     0.9096      0.021     43.757      0.000       0.869       0.950
# tipo_gravidez_Multipla                1.6876      0.007    235.934      0.000       1.674       1.702
# def_sexo_Masculino                    0.2041      0.003     63.619      0.000       0.198       0.210
# peso_faixa_entre_1500_2499            2.4644      0.004    600.066      0.000       2.456       2.472
# peso_faixa_entre_3500_3999           -0.7154      0.006   -129.379      0.000      -0.726      -0.705
# peso_faixa_entre_500_1499             5.1723      0.016    329.426      0.000       5.142       5.203
# peso_faixa_maior_igual_4000          -0.6109      0.012    -53.027      0.000      -0.633      -0.588
# peso_faixa_menor_500                  1.9495      0.030     65.073      0.000       1.891       2.008
# FLAG_BASE_SIM_DOFET                   1.3822      0.018     78.545      0.000       1.348       1.417
# =====================================================================================================
# ----------------------------------------------------------------
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |    | Var                               |   Odds_ratio |   Odds_Lim_inf |   Odds_Lim_Sup |   p-values |
# +====+===================================+==============+================+================+============+
# |  0 | Intercept                         |        0.066 |          0.066 |          0.067 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  1 | ANO                               |        1.032 |          1.025 |          1.039 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  2 | evento_REGIAO_Centro-Oeste        |        0.775 |          0.766 |          0.784 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  3 | evento_REGIAO_Nordeste            |        0.554 |          0.549 |          0.559 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  4 | evento_REGIAO_Norte               |        0.604 |          0.596 |          0.612 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  5 | evento_REGIAO_Sul                 |        0.737 |          0.73  |          0.744 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  6 | idademae_faixa_entre_35_39        |        1.02  |          1.01  |          1.029 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  7 | idademae_faixa_maior_igual_40     |        0.832 |          0.81  |          0.854 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  8 | idademae_faixa_menor_igual_19     |        1.881 |          1.863 |          1.9   |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  9 | escolaridade_mae_Ensino_medio     |        0.863 |          0.856 |          0.87  |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 10 | escolaridade_mae_Fundamental      |        2.189 |          2.168 |          2.211 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 11 | escolaridade_mae_Sem_escolaridade |        2.483 |          2.384 |          2.587 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 12 | tipo_gravidez_Multipla            |        5.406 |          5.331 |          5.483 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 13 | def_sexo_Masculino                |        1.226 |          1.219 |          1.234 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 14 | peso_faixa_entre_1500_2499        |       11.757 |         11.662 |         11.852 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 15 | peso_faixa_entre_3500_3999        |        0.489 |          0.484 |          0.494 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 16 | peso_faixa_entre_500_1499         |      176.318 |        170.975 |        181.828 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 17 | peso_faixa_maior_igual_4000       |        0.543 |          0.531 |          0.555 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 18 | peso_faixa_menor_500              |        7.025 |          6.625 |          7.45  |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 19 | FLAG_BASE_SIM_DOFET               |        3.984 |          3.849 |          4.124 |          0 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+

# %%
with open(f'resultados/modelo_0/{periodo}_modelo_0_PRM.txt', 'w') as f:
    f.write('---------------------------------------------------------------- \n')
    f.write('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES \n')
    f.write('----------------------------------------------------------------\n')
    f.write('N without missing  :' + str(po) +'\n')
    f.write('Treated samples    :' + str([tpo,np.round(100*tpo/po,2)]) + '% \n')
    f.write('Controled samples  :' + str([cpo,np.round(100*cpo/po,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('SELECTED/MATCHET SAMPLES\n')
    f.write('---------------------------------------------------------------- \n')
    f.write('% Selected         :' + str(np.round(100*pa/po,2)) + '% \n')
    f.write('N selected         :' + str(pa) + '\n')
    f.write('Treated selected   :' + str([tpa,np.round(100*tpa/pa,2)]) + '% \n')
    f.write('Controled selected :' + str([cpa,np.round(100*cpa/pa,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('PSW REPORT - ' + periodo+ '\n')
    f.write(str(clf_ano.summary(xname=aux+var_model_2)))
    f.write('\n')
    f.write(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))

# %%
odds_ratio['periodo'] = periodo
odds_ratio.to_csv(f'resultados/modelo_0/{periodo}_modelo_0_PRM.csv', decimal=',', sep=';',index=False)

# %%
fig = sns.kdeplot(df_mod.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="r")
fig = sns.kdeplot(df_mod.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_0/fig1a_{periodo}_modelo_0_PRM.png', format='png', dpi=300)
plt.show()

# %%
fig = sns.kdeplot(psw_base.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="r")
fig = sns.kdeplot(psw_base.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_0/fig1b_{periodo}_modelo_0_PRM.png', format='png', dpi=300)
plt.show()

# %%
#spearm
var_corr = ['PRM'] + var_model_2


plt.figure(figsize=(16, 6))
# define the mask to set the values in the upper triangle to True

mask = np.triu(np.ones_like(psw_base[var_corr].corr(method="spearman"), dtype=np.bool))
heatmap = sns.heatmap(psw_base[var_corr].corr(method='spearman'), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Matrix', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# # Modelo 1

# %%
variaveis_1 = [  
     'ANO'
    , 'PRM'
    , 'evento_REGIAO'
    , 'idademae_faixa'
    , 'escolaridade_mae'
    ,'tipo_gravidez'
    , 'idade_gestacao_faixa'
    , 'def_sexo'
    , 'peso_faixa'
    , 'FLAG_BASE'
    , 'sum_CENTROBS'
    , 'sum_QTINST34'
    , 'sum_QTINST35'
    , 'sum_QTINST36'
    , 'sum_QTINST37'
    , 'sum_QTLEIT34'
    , 'sum_QTLEIT38'
    , 'sum_QTLEIT39'
    , 'sum_QTLEIT40'
    , 'sum_CENTRNEO'
    , 'TP_UNID_5'
    , 'TP_UNID_7'
    , 'TP_UNID_15'
    , 'TP_UNID_36'
    , 'TP_UNID_61'
    ]
df_mod = df[variaveis_1]

# %%
# PRM contagem
NPT = (df_mod['PRM']==1).sum()
NT = (df_mod['PRM']==0).sum()

# %%
# Categorizando as novas variáveis. 
df_mod['cat_CENTROBS'] = [1 if i > 0 else 0 for i in df_mod['sum_CENTROBS']]
df_mod['cat_QTINST34'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST34']]
df_mod['cat_QTINST35'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST35']]
df_mod['cat_QTINST36'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST36']]
df_mod['cat_QTINST37'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST37']]
df_mod['cat_QTLEIT34'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT34']]
df_mod['cat_QTLEIT38'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT38']]
df_mod['cat_QTLEIT39'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT39']]
df_mod['cat_QTLEIT40'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT40']]
df_mod['cat_CENTRNEO'] = [1 if i > 0 else 0 for i in df_mod['sum_CENTRNEO']]
df_mod['cat_TP_UNID_5'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_5']]
df_mod['cat_TP_UNID_7'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_7']]
df_mod['cat_TP_UNID_15'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_15']]
df_mod['cat_TP_UNID_36'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_36']]
df_mod['cat_TP_UNID_61'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_61']]

# %%
df_mod = df_mod.drop(
    columns=[
        'sum_CENTROBS'
        ,'sum_QTINST34'
        ,'sum_QTINST35'
        ,'sum_QTINST36'
        ,'sum_QTINST37'
        ,'sum_QTLEIT34'
        ,'sum_QTLEIT38'
        ,'sum_QTLEIT39'
        ,'sum_QTLEIT40'
        ,'sum_CENTRNEO'
        ,'TP_UNID_5'
        ,'TP_UNID_7'
        ,'TP_UNID_15'
        ,'TP_UNID_36'
        ,'TP_UNID_61'
    ]
)

# %%
df_mod = pd.get_dummies(df_mod)

# %%
df_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7847402 entries, 0 to 10493462
# Data columns (total 47 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   ANO                                int32
#  1   PRM                                int32
#  2   cat_CENTROBS                       int64
#  3   cat_QTINST34                       int64
#  4   cat_QTINST35                       int64
#  5   cat_QTINST36                       int64
#  6   cat_QTINST37                       int64
#  7   cat_QTLEIT34                       int64
#  8   cat_QTLEIT38                       int64
#  9   cat_QTLEIT39                       int64
#  10  cat_QTLEIT40                       int64
#  11  cat_CENTRNEO                       int64
#  12  cat_TP_UNID_5                      int64
#  13  cat_TP_UNID_7                      int64
#  14  cat_TP_UNID_15                     int64
#  15  cat_TP_UNID_36                     int64
#  16  cat_TP_UNID_61                     int64
#  17  evento_REGIAO_Centro-Oeste         uint8
#  18  evento_REGIAO_Nordeste             uint8
#  19  evento_REGIAO_Norte                uint8
#  20  evento_REGIAO_Sudeste              uint8
#  21  evento_REGIAO_Sul                  uint8
#  22  idademae_faixa_entre_20_34         uint8
#  23  idademae_faixa_entre_35_39         uint8
#  24  idademae_faixa_maior_igual_40      uint8
#  25  idademae_faixa_menor_igual_19      uint8
#  26  escolaridade_mae_Ensino_medio      uint8
#  27  escolaridade_mae_Ensino_superior   uint8
#  28  escolaridade_mae_Fundamental       uint8
#  29  escolaridade_mae_Sem_escolaridade  uint8
#  30  tipo_gravidez_Ignorado             uint8
#  31  tipo_gravidez_Multipla             uint8
#  32  tipo_gravidez_Unica                uint8
#  33  idade_gestacao_faixa_entre_22_27   uint8
#  34  idade_gestacao_faixa_entre_28_36   uint8
#  35  idade_gestacao_faixa_entre_37_39   uint8
#  36  idade_gestacao_faixa_entre_40_42   uint8
#  37  def_sexo_Feminino                  uint8
#  38  def_sexo_Masculino                 uint8
#  39  peso_faixa_entre_1500_2499         uint8
#  40  peso_faixa_entre_2500_3500         uint8
#  41  peso_faixa_entre_3500_3999         uint8
#  42  peso_faixa_entre_500_1499          uint8
#  43  peso_faixa_maior_igual_4000        uint8
#  44  peso_faixa_menor_500               uint8
#  45  FLAG_BASE_SIM_DOFET                uint8
#  46  FLAG_BASE_SINASC                   uint8
# dtypes: int32(2), int64(15), uint8(30)
# memory usage: 1.2 GB

# %%
for i in df_mod.columns:
    print(i)
# Out:
# ANO
# PRM
# cat_CENTROBS
# cat_QTINST34
# cat_QTINST35
# cat_QTINST36
# cat_QTINST37
# cat_QTLEIT34
# cat_QTLEIT38
# cat_QTLEIT39
# cat_QTLEIT40
# cat_CENTRNEO
# cat_TP_UNID_5
# cat_TP_UNID_7
# cat_TP_UNID_15
# cat_TP_UNID_36
# cat_TP_UNID_61
# evento_REGIAO_Centro-Oeste
# evento_REGIAO_Nordeste
# evento_REGIAO_Norte
# evento_REGIAO_Sudeste
# evento_REGIAO_Sul
# idademae_faixa_entre_20_34
# idademae_faixa_entre_35_39
# idademae_faixa_maior_igual_40
# idademae_faixa_menor_igual_19
# escolaridade_mae_Ensino_medio
# escolaridade_mae_Ensino_superior
# escolaridade_mae_Fundamental
# escolaridade_mae_Sem_escolaridade
# tipo_gravidez_Ignorado
# tipo_gravidez_Multipla
# tipo_gravidez_Unica
# idade_gestacao_faixa_entre_22_27
# idade_gestacao_faixa_entre_28_36
# idade_gestacao_faixa_entre_37_39
# idade_gestacao_faixa_entre_40_42
# def_sexo_Feminino
# def_sexo_Masculino
# peso_faixa_entre_1500_2499
# peso_faixa_entre_2500_3500
# peso_faixa_entre_3500_3999
# peso_faixa_entre_500_1499
# peso_faixa_maior_igual_4000
# peso_faixa_menor_500
# FLAG_BASE_SIM_DOFET
# FLAG_BASE_SINASC

# %%
# Modelo
#Defining covariates
var_model=[
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    , 'idade_gestacao_faixa_entre_22_27'
    , 'idade_gestacao_faixa_entre_28_36'
    #, 'idade_gestacao_faixa_entre_37_39'
    , 'idade_gestacao_faixa_entre_40_42'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    , 'FLAG_BASE_SIM_DOFET'
    #, 'FLAG_BASE_SINASC'
    #,'cat_CENTROBS'
    #, 'cat_QTINST34'
    #,'cat_QTINST35'
    #,'cat_QTINST36'
    #, 'cat_QTINST37'
    #, 'cat_QTLEIT34'
    #, 'cat_QTLEIT38'
    #, 'cat_QTLEIT39'
    #, 'cat_QTLEIT40'
    #, 'cat_CENTRNEO'
    #, 'cat_TP_UNID_5'
    #, 'cat_TP_UNID_7'
    , 'cat_TP_UNID_15'
    , 'cat_TP_UNID_36'
]

X = df_mod[var_model].values

## FIRST REGRESSION
y = df_mod[['ANO']].values
clf = LogisticRegression(random_state=0, max_iter=2000).fit(X, y)
df_mod = df_mod.assign(PROPENSITY_SCORE=clf.predict_proba(X)[:, 1])

#USING PROPENSITY SCORE TO SELECT SAMPLES TO SECOND REGRESSION
psw_base=df_mod[((df_mod['PROPENSITY_SCORE']>df_mod['PROPENSITY_SCORE'].quantile(0.1)) &
                 (df_mod['PROPENSITY_SCORE']<df_mod['PROPENSITY_SCORE'].quantile(0.9)))]

#COUNTING
po=len(df_mod)
tpo=len(df_mod[df_mod['ANO']==1])
cpo=len(df_mod[df_mod['ANO']==0])
pa=len(psw_base)
tpa=len(psw_base[psw_base['ANO']==1])
cpa=len(psw_base[psw_base['ANO']==0])

print('----------------------------------------------------------------')
print('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES')
print('----------------------------------------------------------------')
print('N without missing  :', po)
print('Treated samples    :', tpo,np.round(100*tpo/po,2),'%')
print('Controled samples  :', cpo,np.round(100*cpo/po,2),'%')
print('----------------------------------------------------------------')
print('SELECTED/MATCHET SAMPLES')
print('----------------------------------------------------------------')
print('% Selected         :', np.round(100*pa/po,2),'%')
print('N selected         :', pa)
print('Treated selected   :', tpa,np.round(100*tpa/pa,2),'%')
print('Controled selected :', cpa,np.round(100*cpa/pa,2),'%')
print('----------------------------------------------------------------')
print('')

#PSW weights
w =psw_base['ANO']/psw_base['PROPENSITY_SCORE'] + ((1-psw_base['ANO'])/(1-psw_base['PROPENSITY_SCORE']))
# Out:
# ----------------------------------------------------------------
# USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES
# ----------------------------------------------------------------
# N without missing  : 7847402
# Treated samples    : 5091798 64.89 %
# Controled samples  : 2755604 35.11 %
# ----------------------------------------------------------------
# SELECTED/MATCHET SAMPLES
# ----------------------------------------------------------------
# % Selected         : 79.48 %
# N selected         : 6237055
# Treated selected   : 4054799 65.01 %
# Controled selected : 2182256 34.99 %
# ----------------------------------------------------------------

# %%
## SECOND REGRESSION
aux=['ANO']
var_model_2 = [
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    #, 'idade_gestacao_faixa_entre_22_27'
    #, 'idade_gestacao_faixa_entre_28_36'
    #, 'idade_gestacao_faixa_entre_37_39'
    #, 'idade_gestacao_faixa_entre_40_42'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    , 'FLAG_BASE_SIM_DOFET'
    #, 'FLAG_BASE_SINASC'
    #,'cat_CENTROBS'
    #,'cat_QTINST34'
    # 'cat_QTINST35'
    #,'cat_QTINST36'
    #, 'cat_QTINST37'
    #, 'cat_QTLEIT34'
    #, 'cat_QTLEIT38'
    #, 'cat_QTLEIT39'
    #, 'cat_QTLEIT40'
    #, 'cat_CENTRNEO'
    #, 'cat_TP_UNID_5'
    #, 'cat_TP_UNID_7'
    , 'cat_TP_UNID_15'
    , 'cat_TP_UNID_36'
]

X = psw_base[aux+var_model_2].values
y = psw_base[['PRM']].values

X_ANO = sm.add_constant(X)
clf_ano = sm.Logit(y, X_ANO,weights=w).fit()
aux=['Intercept','ANO']

print('----------------------------------------------------------------')
print('PSW REPORT',periodo)
print('----------------------------------------------------------------')
print(clf_ano.summary(xname=aux+var_model_2))
print('----------------------------------------------------------------')


IC=np.exp(clf_ano.conf_int(0.05))
odds_ratio=pd.DataFrame(
    data = {
        'Var':aux+var_model_2
        , 'Odds_ratio': np.round(np.exp(clf_ano.params),3)
        , 'Odds_Lim_inf': np.round(IC[:,0],3)
        , 'Odds_Lim_Sup': np.round(IC[:,1],3)
        , 'p-values':np.round(clf_ano.pvalues,3)
    }
)
print(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.269675
#          Iterations 7
# ----------------------------------------------------------------
# PSW REPORT 2019-2021-2022
# ----------------------------------------------------------------
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:              6237055
# Model:                          Logit   Df Residuals:                  6237033
# Method:                           MLE   Df Model:                           21
# Date:                Wed, 03 Jul 2024   Pseudo R-squ.:                  0.2692
# Time:                        00:25:16   Log-Likelihood:            -1.6820e+06
# converged:                       True   LL-Null:                   -2.3015e+06
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -2.5875      0.007   -356.131      0.000      -2.602      -2.573
# ANO                                   0.0242      0.003      7.839      0.000       0.018       0.030
# evento_REGIAO_Centro-Oeste           -0.0129      0.005     -2.364      0.018      -0.024      -0.002
# evento_REGIAO_Nordeste                0.0456      0.004     11.778      0.000       0.038       0.053
# evento_REGIAO_Norte                   0.1055      0.005     20.809      0.000       0.096       0.115
# evento_REGIAO_Sul                    -0.0104      0.005     -2.257      0.024      -0.019      -0.001
# idademae_faixa_entre_35_39            0.1930      0.004     45.457      0.000       0.185       0.201
# idademae_faixa_maior_igual_40         0.1108      0.009     12.745      0.000       0.094       0.128
# idademae_faixa_menor_igual_19         0.2629      0.005     56.031      0.000       0.254       0.272
# escolaridade_mae_Ensino_medio        -0.0012      0.004     -0.314      0.754      -0.009       0.006
# escolaridade_mae_Fundamental          0.4204      0.005     90.308      0.000       0.411       0.429
# escolaridade_mae_Sem_escolaridade     0.4120      0.021     19.438      0.000       0.370       0.454
# tipo_gravidez_Multipla                1.4321      0.007    201.721      0.000       1.418       1.446
# def_sexo_Masculino                    0.2459      0.003     83.039      0.000       0.240       0.252
# peso_faixa_entre_1500_2499            2.5108      0.004    697.776      0.000       2.504       2.518
# peso_faixa_entre_3500_3999           -0.9246      0.005   -174.147      0.000      -0.935      -0.914
# peso_faixa_entre_500_1499             5.2144      0.016    335.297      0.000       5.184       5.245
# peso_faixa_maior_igual_4000          -0.9371      0.011    -82.307      0.000      -0.959      -0.915
# peso_faixa_menor_500                  2.5468      0.022    113.887      0.000       2.503       2.591
# FLAG_BASE_SIM_DOFET                   1.4865      0.015     97.034      0.000       1.456       1.517
# cat_TP_UNID_15                       -0.4699      0.006    -78.488      0.000      -0.482      -0.458
# cat_TP_UNID_36                       -0.1649      0.006    -29.642      0.000      -0.176      -0.154
# =====================================================================================================
# ----------------------------------------------------------------
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |    | Var                               |   Odds_ratio |   Odds_Lim_inf |   Odds_Lim_Sup |   p-values |
# +====+===================================+==============+================+================+============+
# |  0 | Intercept                         |        0.075 |          0.074 |          0.076 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  1 | ANO                               |        1.024 |          1.018 |          1.031 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  2 | evento_REGIAO_Centro-Oeste        |        0.987 |          0.977 |          0.998 |      0.018 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  3 | evento_REGIAO_Nordeste            |        1.047 |          1.039 |          1.055 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  4 | evento_REGIAO_Norte               |        1.111 |          1.1   |          1.122 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  5 | evento_REGIAO_Sul                 |        0.99  |          0.981 |          0.999 |      0.024 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  6 | idademae_faixa_entre_35_39        |        1.213 |          1.203 |          1.223 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  7 | idademae_faixa_maior_igual_40     |        1.117 |          1.098 |          1.136 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  8 | idademae_faixa_menor_igual_19     |        1.301 |          1.289 |          1.313 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  9 | escolaridade_mae_Ensino_medio     |        0.999 |          0.991 |          1.006 |      0.754 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 10 | escolaridade_mae_Fundamental      |        1.523 |          1.509 |          1.536 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 11 | escolaridade_mae_Sem_escolaridade |        1.51  |          1.448 |          1.574 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 12 | tipo_gravidez_Multipla            |        4.187 |          4.13  |          4.246 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 13 | def_sexo_Masculino                |        1.279 |          1.271 |          1.286 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 14 | peso_faixa_entre_1500_2499        |       12.315 |         12.228 |         12.402 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 15 | peso_faixa_entre_3500_3999        |        0.397 |          0.393 |          0.401 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 16 | peso_faixa_entre_500_1499         |      183.901 |        178.38  |        189.592 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 17 | peso_faixa_maior_igual_4000       |        0.392 |          0.383 |          0.401 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 18 | peso_faixa_menor_500              |       12.767 |         12.219 |         13.339 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 19 | FLAG_BASE_SIM_DOFET               |        4.422 |          4.291 |          4.556 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 20 | cat_TP_UNID_15                    |        0.625 |          0.618 |          0.632 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 21 | cat_TP_UNID_36                    |        0.848 |          0.839 |          0.857 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+

# %%
with open(f'resultados/modelo_1/{periodo}_modelo_1_PRM.txt', 'w') as f:
    f.write('---------------------------------------------------------------- \n')
    f.write('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES \n')
    f.write('----------------------------------------------------------------\n')
    f.write('N without missing  :' + str(po) +'\n')
    f.write('Treated samples    :' + str([tpo,np.round(100*tpo/po,2)]) + '% \n')
    f.write('Controled samples  :' + str([cpo,np.round(100*cpo/po,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('SELECTED/MATCHET SAMPLES\n')
    f.write('---------------------------------------------------------------- \n')
    f.write('% Selected         :' + str(np.round(100*pa/po,2)) + '% \n')
    f.write('N selected         :' + str(pa) + '\n')
    f.write('Treated selected   :' + str([tpa,np.round(100*tpa/pa,2)]) + '% \n')
    f.write('Controled selected :' + str([cpa,np.round(100*cpa/pa,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('PSW REPORT - ' + periodo+ '\n')
    f.write(str(clf_ano.summary(xname=aux+var_model_2)))
    f.write('\n')
    f.write(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))

# %%
odds_ratio['periodo'] = periodo
odds_ratio.to_csv(f'resultados/modelo_1/{periodo}_modelo_1_PRM.csv', decimal=',', sep=';', index=False)

# %%
fig = sns.kdeplot(df_mod.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="r")
fig = sns.kdeplot(df_mod.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_1/fig1a_{periodo}_modelo_1_PRM.png', format='png', dpi=300)
plt.show()

# %%
fig = sns.kdeplot(psw_base.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="r")
fig = sns.kdeplot(psw_base.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_1/fig1b_{periodo}_modelo_1_PRM.png', format='png', dpi=300)
plt.show()

# %%
#spearm
var_corr = ['PRM'] + var_model_2

plt.figure(figsize=(16, 6))
# define the mask to set the values in the upper triangle to True

mask = np.triu(np.ones_like(psw_base[var_corr].corr(method="spearman"), dtype=np.bool))
heatmap = sns.heatmap(psw_base[var_corr].corr(method='spearman'), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Matrix', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# # Modelo 2

# %%
variaveis_1 = [  
     'ANO'
    , 'PRM'
    , 'evento_REGIAO'
    , 'idademae_faixa'
    , 'escolaridade_mae'
    , 'tipo_gravidez'
    , 'idade_gestacao_faixa'
    , 'def_sexo'
    , 'peso_faixa'
    , 'FLAG_BASE'
    , 'sum_CENTROBS'
    , 'sum_QTINST34'
    , 'sum_QTINST35'
    , 'sum_QTINST36'
    , 'sum_QTINST37'
    , 'sum_QTLEIT34'
    , 'sum_QTLEIT38'
    , 'sum_QTLEIT39'
    , 'sum_QTLEIT40'
    , 'sum_CENTRNEO'
    , 'TP_UNID_5'
    , 'TP_UNID_7'
    , 'TP_UNID_15'
    , 'TP_UNID_36'
    , 'TP_UNID_61'
    ]
df_mod = df[variaveis_1]

# %%
# Categorizando as novas variáveis. 
df_mod['cat_CENTROBS'] = [1 if i > 0 else 0 for i in df_mod['sum_CENTROBS']]
df_mod['cat_QTINST34'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST34']]
df_mod['cat_QTINST35'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST35']]
df_mod['cat_QTINST36'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST36']]
df_mod['cat_QTINST37'] = [1 if i > 0 else 0 for i in df_mod['sum_QTINST37']]
df_mod['cat_QTLEIT34'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT34']]
df_mod['cat_QTLEIT38'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT38']]
df_mod['cat_QTLEIT39'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT39']]
df_mod['cat_QTLEIT40'] = [1 if i > 0 else 0 for i in df_mod['sum_QTLEIT40']]
df_mod['cat_CENTRNEO'] = [1 if i > 0 else 0 for i in df_mod['sum_CENTRNEO']]
df_mod['cat_TP_UNID_5'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_5']]
df_mod['cat_TP_UNID_7'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_7']]
df_mod['cat_TP_UNID_15'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_15']]
df_mod['cat_TP_UNID_36'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_36']]
df_mod['cat_TP_UNID_61'] = [1 if i > 0 else 0 for i in df_mod['TP_UNID_61']]

# %%
df_mod = df_mod.drop(
    columns=[
        'sum_CENTROBS'
        ,'sum_QTINST34'
        ,'sum_QTINST35'
        ,'sum_QTINST36'
        ,'sum_QTINST37'
        ,'sum_QTLEIT34'
        ,'sum_QTLEIT38'
        ,'sum_QTLEIT39'
        ,'sum_QTLEIT40'
        ,'sum_CENTRNEO'
        ,'TP_UNID_5'
        ,'TP_UNID_7'
        ,'TP_UNID_15'
        ,'TP_UNID_36'
        ,'TP_UNID_61'
    ]
)

# %%
df_mod = pd.get_dummies(df_mod)

# %%
# OBITO contagem
NPT = (df_mod['FLAG_BASE_SIM_DOFET']==1).sum()
NT = (df_mod['FLAG_BASE_SIM_DOFET']==0).sum()

# %%
df_mod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7847402 entries, 0 to 10493462
# Data columns (total 47 columns):
#  #   Column                             Dtype
# ---  ------                             -----
#  0   ANO                                int32
#  1   PRM                                int32
#  2   cat_CENTROBS                       int64
#  3   cat_QTINST34                       int64
#  4   cat_QTINST35                       int64
#  5   cat_QTINST36                       int64
#  6   cat_QTINST37                       int64
#  7   cat_QTLEIT34                       int64
#  8   cat_QTLEIT38                       int64
#  9   cat_QTLEIT39                       int64
#  10  cat_QTLEIT40                       int64
#  11  cat_CENTRNEO                       int64
#  12  cat_TP_UNID_5                      int64
#  13  cat_TP_UNID_7                      int64
#  14  cat_TP_UNID_15                     int64
#  15  cat_TP_UNID_36                     int64
#  16  cat_TP_UNID_61                     int64
#  17  evento_REGIAO_Centro-Oeste         uint8
#  18  evento_REGIAO_Nordeste             uint8
#  19  evento_REGIAO_Norte                uint8
#  20  evento_REGIAO_Sudeste              uint8
#  21  evento_REGIAO_Sul                  uint8
#  22  idademae_faixa_entre_20_34         uint8
#  23  idademae_faixa_entre_35_39         uint8
#  24  idademae_faixa_maior_igual_40      uint8
#  25  idademae_faixa_menor_igual_19      uint8
#  26  escolaridade_mae_Ensino_medio      uint8
#  27  escolaridade_mae_Ensino_superior   uint8
#  28  escolaridade_mae_Fundamental       uint8
#  29  escolaridade_mae_Sem_escolaridade  uint8
#  30  tipo_gravidez_Ignorado             uint8
#  31  tipo_gravidez_Multipla             uint8
#  32  tipo_gravidez_Unica                uint8
#  33  idade_gestacao_faixa_entre_22_27   uint8
#  34  idade_gestacao_faixa_entre_28_36   uint8
#  35  idade_gestacao_faixa_entre_37_39   uint8
#  36  idade_gestacao_faixa_entre_40_42   uint8
#  37  def_sexo_Feminino                  uint8
#  38  def_sexo_Masculino                 uint8
#  39  peso_faixa_entre_1500_2499         uint8
#  40  peso_faixa_entre_2500_3500         uint8
#  41  peso_faixa_entre_3500_3999         uint8
#  42  peso_faixa_entre_500_1499          uint8
#  43  peso_faixa_maior_igual_4000        uint8
#  44  peso_faixa_menor_500               uint8
#  45  FLAG_BASE_SIM_DOFET                uint8
#  46  FLAG_BASE_SINASC                   uint8
# dtypes: int32(2), int64(15), uint8(30)
# memory usage: 1.2 GB

# %%
for i in df_mod.columns:
    print(i)
# Out:
# ANO
# PRM
# cat_CENTROBS
# cat_QTINST34
# cat_QTINST35
# cat_QTINST36
# cat_QTINST37
# cat_QTLEIT34
# cat_QTLEIT38
# cat_QTLEIT39
# cat_QTLEIT40
# cat_CENTRNEO
# cat_TP_UNID_5
# cat_TP_UNID_7
# cat_TP_UNID_15
# cat_TP_UNID_36
# cat_TP_UNID_61
# evento_REGIAO_Centro-Oeste
# evento_REGIAO_Nordeste
# evento_REGIAO_Norte
# evento_REGIAO_Sudeste
# evento_REGIAO_Sul
# idademae_faixa_entre_20_34
# idademae_faixa_entre_35_39
# idademae_faixa_maior_igual_40
# idademae_faixa_menor_igual_19
# escolaridade_mae_Ensino_medio
# escolaridade_mae_Ensino_superior
# escolaridade_mae_Fundamental
# escolaridade_mae_Sem_escolaridade
# tipo_gravidez_Ignorado
# tipo_gravidez_Multipla
# tipo_gravidez_Unica
# idade_gestacao_faixa_entre_22_27
# idade_gestacao_faixa_entre_28_36
# idade_gestacao_faixa_entre_37_39
# idade_gestacao_faixa_entre_40_42
# def_sexo_Feminino
# def_sexo_Masculino
# peso_faixa_entre_1500_2499
# peso_faixa_entre_2500_3500
# peso_faixa_entre_3500_3999
# peso_faixa_entre_500_1499
# peso_faixa_maior_igual_4000
# peso_faixa_menor_500
# FLAG_BASE_SIM_DOFET
# FLAG_BASE_SINASC

# %%
# Modelo
#Defining covariates
var_model=[
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    , 'PRM'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    #,'cat_CENTROBS'
    #, 'cat_QTINST34'
    #,'cat_QTINST35'
    #,'cat_QTINST36'
    #, 'cat_QTINST37'
    #, 'cat_QTLEIT34'
    #, 'cat_QTLEIT38'
    #, 'cat_QTLEIT39'
    #, 'cat_QTLEIT40'
    #, 'cat_CENTRNEO'
    #, 'cat_TP_UNID_5'
    #, 'cat_TP_UNID_7'
    #, 'cat_TP_UNID_15'
    #, 'cat_TP_UNID_36'
]

X = df_mod[var_model].values

## FIRST REGRESSION
y = df_mod[['ANO']].values
clf = LogisticRegression(random_state=0, max_iter=2000).fit(X, y)
df_mod = df_mod.assign(PROPENSITY_SCORE=clf.predict_proba(X)[:, 1])

#USING PROPENSITY SCORE TO SELECT SAMPLES TO SECOND REGRESSION
psw_base=df_mod[((df_mod['PROPENSITY_SCORE']>df_mod['PROPENSITY_SCORE'].quantile(0.1)) &
                 (df_mod['PROPENSITY_SCORE']<df_mod['PROPENSITY_SCORE'].quantile(0.9)))]

#COUNTING
po=len(df_mod)
tpo=len(df_mod[df_mod['ANO']==1])
cpo=len(df_mod[df_mod['ANO']==0])
pa=len(psw_base)
tpa=len(psw_base[psw_base['ANO']==1])
cpa=len(psw_base[psw_base['ANO']==0])

print('----------------------------------------------------------------')
print('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES')
print('----------------------------------------------------------------')
print('N without missing  :', po)
print('Treated samples    :', tpo,np.round(100*tpo/po,2),'%')
print('Controled samples  :', cpo,np.round(100*cpo/po,2),'%')
print('----------------------------------------------------------------')
print('SELECTED/MATCHET SAMPLES')
print('----------------------------------------------------------------')
print('% Selected         :', np.round(100*pa/po,2),'%')
print('N selected         :', pa)
print('Treated selected   :', tpa,np.round(100*tpa/pa,2),'%')
print('Controled selected :', cpa,np.round(100*cpa/pa,2),'%')
print('----------------------------------------------------------------')
print('')

#PSW weights
w =psw_base['ANO']/psw_base['PROPENSITY_SCORE'] + ((1-psw_base['ANO'])/(1-psw_base['PROPENSITY_SCORE']))
# Out:
# ----------------------------------------------------------------
# USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES
# ----------------------------------------------------------------
# N without missing  : 7847402
# Treated samples    : 5091798 64.89 %
# Controled samples  : 2755604 35.11 %
# ----------------------------------------------------------------
# SELECTED/MATCHET SAMPLES
# ----------------------------------------------------------------
# % Selected         : 79.9 %
# N selected         : 6270139
# Treated selected   : 4083129 65.12 %
# Controled selected : 2187010 34.88 %
# ----------------------------------------------------------------

# %%
## SECOND REGRESSION
aux=['ANO']
var_model_2 = [
     'evento_REGIAO_Centro-Oeste'
    , 'evento_REGIAO_Nordeste'
    , 'evento_REGIAO_Norte'
    #, 'evento_REGIAO_Sudeste'
    , 'evento_REGIAO_Sul'
    #, 'idademae_faixa_entre_20_34'
    , 'idademae_faixa_entre_35_39'
    , 'idademae_faixa_maior_igual_40'
    , 'idademae_faixa_menor_igual_19'
    , 'escolaridade_mae_Ensino_medio'
    #, 'escolaridade_mae_Ensino_superior'
    , 'escolaridade_mae_Fundamental'
    , 'escolaridade_mae_Sem_escolaridade'
    , 'tipo_gravidez_Multipla'
    #, 'tipo_gravidez_Unica'
    , 'PRM'
    #, 'def_sexo_Feminino'
    , 'def_sexo_Masculino'
    , 'peso_faixa_entre_1500_2499'
    #, 'peso_faixa_entre_2500_3500'
    , 'peso_faixa_entre_3500_3999'
    , 'peso_faixa_entre_500_1499'
    , 'peso_faixa_maior_igual_4000'
    , 'peso_faixa_menor_500'
    #,'cat_CENTROBS'
    #, 'cat_QTINST34'
    #,'cat_QTINST35'
    #,'cat_QTINST36'
    #, 'cat_QTINST37'
    #, 'cat_QTLEIT34'
    #, 'cat_QTLEIT38'
    #, 'cat_QTLEIT39'
    #, 'cat_QTLEIT40'
    #, 'cat_CENTRNEO'
    #, 'cat_TP_UNID_5'
    #, 'cat_TP_UNID_7'
    #, 'cat_TP_UNID_15'
    #, 'cat_TP_UNID_36'
]

X = psw_base[aux+var_model_2].values
y = psw_base[['FLAG_BASE_SIM_DOFET']].values

X_ANO = sm.add_constant(X)
clf_ano = sm.Logit(y, X_ANO,weights=w).fit()
aux=['Intercept','ANO']

print('----------------------------------------------------------------')
print('PSW REPORT',periodo)
print('----------------------------------------------------------------')
print(clf_ano.summary(xname=aux+var_model_2))
print('----------------------------------------------------------------')


IC=np.exp(clf_ano.conf_int(0.05))
odds_ratio=pd.DataFrame(
    data = {
        'Var':aux+var_model_2
        , 'Odds_ratio': np.round(np.exp(clf_ano.params),3)
        , 'Odds_Lim_inf': np.round(IC[:,0],3)
        , 'Odds_Lim_Sup': np.round(IC[:,1],3)
        , 'p-values':np.round(clf_ano.pvalues,3)
    }
)
print(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))
# Out:
# Optimization terminated successfully.
#          Current function value: inf
#          Iterations 11
# ----------------------------------------------------------------
# PSW REPORT 2019-2021-2022
# ----------------------------------------------------------------
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:              6270139
# Model:                          Logit   Df Residuals:                  6270119
# Method:                           MLE   Df Model:                           19
# Date:                Wed, 03 Jul 2024   Pseudo R-squ.:                     inf
# Time:                        00:30:46   Log-Likelihood:                   -inf
# converged:                       True   LL-Null:                        0.0000
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -6.9852      0.022   -313.630      0.000      -7.029      -6.942
# ANO                                   0.0041      0.012      0.350      0.727      -0.019       0.027
# evento_REGIAO_Centro-Oeste            0.1432      0.023      6.147      0.000       0.098       0.189
# evento_REGIAO_Nordeste                0.3089      0.015     19.957      0.000       0.279       0.339
# evento_REGIAO_Norte                   0.2675      0.023     11.763      0.000       0.223       0.312
# evento_REGIAO_Sul                    -0.1290      0.019     -6.851      0.000      -0.166      -0.092
# idademae_faixa_entre_35_39            0.0899      0.016      5.513      0.000       0.058       0.122
# idademae_faixa_maior_igual_40         0.2681      0.035      7.639      0.000       0.199       0.337
# idademae_faixa_menor_igual_19        -0.1335      0.018     -7.441      0.000      -0.169      -0.098
# escolaridade_mae_Ensino_medio         0.3263      0.018     17.940      0.000       0.291       0.362
# escolaridade_mae_Fundamental          0.8585      0.020     43.434      0.000       0.820       0.897
# escolaridade_mae_Sem_escolaridade     2.2670      0.039     57.805      0.000       2.190       2.344
# tipo_gravidez_Multipla               -0.9855      0.023    -42.947      0.000      -1.031      -0.941
# PRM                                   1.5665      0.017     94.369      0.000       1.534       1.599
# def_sexo_Masculino                    0.1148      0.011     10.285      0.000       0.093       0.137
# peso_faixa_entre_1500_2499            1.6185      0.018     88.951      0.000       1.583       1.654
# peso_faixa_entre_3500_3999           -0.4039      0.026    -15.448      0.000      -0.455      -0.353
# peso_faixa_entre_500_1499             3.4973      0.018    189.409      0.000       3.461       3.533
# peso_faixa_maior_igual_4000           0.5567      0.037     15.099      0.000       0.484       0.629
# peso_faixa_menor_500                  4.3616      0.037    119.265      0.000       4.290       4.433
# =====================================================================================================
# ----------------------------------------------------------------
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |    | Var                               |   Odds_ratio |   Odds_Lim_inf |   Odds_Lim_Sup |   p-values |
# +====+===================================+==============+================+================+============+
# |  0 | Intercept                         |        0.001 |          0.001 |          0.001 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  1 | ANO                               |        1.004 |          0.981 |          1.027 |      0.727 |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  2 | evento_REGIAO_Centro-Oeste        |        1.154 |          1.102 |          1.208 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  3 | evento_REGIAO_Nordeste            |        1.362 |          1.321 |          1.404 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  4 | evento_REGIAO_Norte               |        1.307 |          1.25  |          1.366 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  5 | evento_REGIAO_Sul                 |        0.879 |          0.847 |          0.912 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  6 | idademae_faixa_entre_35_39        |        1.094 |          1.06  |          1.13  |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  7 | idademae_faixa_maior_igual_40     |        1.308 |          1.221 |          1.401 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  8 | idademae_faixa_menor_igual_19     |        0.875 |          0.845 |          0.906 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# |  9 | escolaridade_mae_Ensino_medio     |        1.386 |          1.337 |          1.436 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 10 | escolaridade_mae_Fundamental      |        2.36  |          2.27  |          2.453 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 11 | escolaridade_mae_Sem_escolaridade |        9.65  |          8.936 |         10.421 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 12 | tipo_gravidez_Multipla            |        0.373 |          0.357 |          0.39  |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 13 | PRM                               |        4.79  |          4.637 |          4.948 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 14 | def_sexo_Masculino                |        1.122 |          1.097 |          1.146 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 15 | peso_faixa_entre_1500_2499        |        5.046 |          4.869 |          5.229 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 16 | peso_faixa_entre_3500_3999        |        0.668 |          0.634 |          0.703 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 17 | peso_faixa_entre_500_1499         |       33.026 |         31.853 |         34.244 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 18 | peso_faixa_maior_igual_4000       |        1.745 |          1.623 |          1.876 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+
# | 19 | peso_faixa_menor_500              |       78.386 |         72.964 |         84.211 |      0     |
# +----+-----------------------------------+--------------+----------------+----------------+------------+

# %%
with open(f'resultados/modelo_2/{periodo}_modelo_2_OBITO.txt', 'w') as f:
    f.write('---------------------------------------------------------------- \n')
    f.write('USING PROPENSITY SCORE TO SELECT/MATCH SAMPLES \n')
    f.write('----------------------------------------------------------------\n')
    f.write('N without missing  :' + str(po) +'\n')
    f.write('Treated samples    :' + str([tpo,np.round(100*tpo/po,2)]) + '% \n')
    f.write('Controled samples  :' + str([cpo,np.round(100*cpo/po,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('SELECTED/MATCHET SAMPLES\n')
    f.write('---------------------------------------------------------------- \n')
    f.write('% Selected         :' + str(np.round(100*pa/po,2)) + '% \n')
    f.write('N selected         :' + str(pa) + '\n')
    f.write('Treated selected   :' + str([tpa,np.round(100*tpa/pa,2)]) + '% \n')
    f.write('Controled selected :' + str([cpa,np.round(100*cpa/pa,2)]) + '% \n')
    f.write('---------------------------------------------------------------- \n')
    f.write('PSW REPORT - ' + periodo+ '\n')
    f.write(str(clf_ano.summary(xname=aux+var_model_2)))
    f.write('\n')
    f.write(tabulate(odds_ratio, headers = 'keys', tablefmt = 'grid'))

# %%
odds_ratio['periodo'] = periodo
odds_ratio.to_csv(f'resultados/modelo_2/{periodo}_modelo_2_OBITO.csv', decimal=',', sep=';', index=False)

# %%
fig = sns.kdeplot(df_mod.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="r")
fig = sns.kdeplot(df_mod.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_2/fig1a_{periodo}_modelo_2_OBITO.png', format='png', dpi=300)
plt.show()

# %%
fig = sns.kdeplot(psw_base.query("ANO==0")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="r")
fig = sns.kdeplot(psw_base.query("ANO==1")["PROPENSITY_SCORE"],bw_adjust=0.7, shade=False, color="b")
plt.legend(['Control','Treatment'])
plt.savefig(f'resultados/modelo_2/fig1b_{periodo}_modelo_2_OBITO.png', format='png', dpi=300)
plt.show()

# %%
#spearm
var_corr = ['FLAG_BASE_SIM_DOFET'] + var_model_2

plt.figure(figsize=(16, 6))
# define the mask to set the values in the upper triangle to True

mask = np.triu(np.ones_like(psw_base[var_corr].corr(method="spearman"), dtype=np.bool))
heatmap = sns.heatmap(psw_base[var_corr].corr(method='spearman'), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Matrix', fontdict={'fontsize':18}, pad=16);
